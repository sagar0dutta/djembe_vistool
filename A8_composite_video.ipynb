# %%
import os
import pickle
import subprocess
# import pandas as pd
from utils_mocap_viz.generate_views import (    # organize this
    # get_output_dir,
    prepare_videos
)

from utils_mocap_viz.animated_merged_phase_analysis import animate_merged_phase_analysis
from utils_dance_anim.dance_dot import animate_dance_phase_analysis


from utils_pipeline.pipeline_B import *

# %% [markdown]
# ### Config

# %%
file_name = "BKO_E1_D1_02_Maraka"
traj_dir  = "traj_files_presentation"
status    = "included"   # or "excluded"
traj_threshold = "0.001"        # or any other threshold

bvh_dir = os.path.join("data", "bvh_files")
bvh_file = os.path.join(bvh_dir, file_name + "_T")

# path to onsets and cycles csv files
cycles_csv_path = f"data/virtual_cycles/{file_name}_C.csv"
onsets_csv_path = f"data/drum_onsets/{file_name}.csv"
dance_csv_path = f"data/dance_onsets/{file_name}_T_dance_onsets.csv"

cycle_segs, windows = compute_windows(traj_dir, file_name, status, traj_threshold)
# Out:
# Loaded cycle_segments from BKO_E1_D1_02_Maraka_included_0.001.pkl
# cycle_segments: [(23.740333333, 26.174999999666667), (26.174999999666667, 28.663888888666666), (28.663888888666666, 31.07633333333333), (31.07633333333333, 33.48166666633333), (33.48166666633333, 35.851444444), (35.851444444, 38.19277777766667), (38.19277777766667, 40.538555555), (40.538555555, 42.90566666666667), (42.90566666666667, 45.23455555533334), (45.23455555533334, 47.571), (47.571, 49.90033333333333), (49.90033333333333, 52.17588888866667), (52.17588888866667, 54.4496666665), (54.4496666665, 56.688777777666665), (56.688777777666665, 58.955), (58.955, 61.175), (61.175, 63.60966666666667)]
# Number of windows for each beat/subdivision:
#   beat_1: 17 windows
#   beat_2: 17 windows
#   beat_3: 17 windows
#   beat_4: 17 windows
#   subdiv_2: 17 windows
#   subdiv_3: 17 windows
#   subdiv_5: 17 windows
#   subdiv_6: 17 windows
#   subdiv_8: 17 windows
#   subdiv_9: 17 windows
#   subdiv_11: 17 windows
#   subdiv_12: 17 windows

# %% [markdown]
# ### Generate trajectory video + trimmed dance video plots

# %%
w_key = "beat_1"
vid_plot_path = f"cycle_videos/{file_name}/{w_key}/"

# traj_tuples = random.sample(windows[w_key], 2)  # Randomly sample 2 tuples from the list

traj_tuples = windows[w_key][:6]

# 'beat_1', 'beat_2', 'beat_3', 'beat_4', 
# 'subdiv_2', 'subdiv_3', 'subdiv_5', 'subdiv_6', 
# 'subdiv_8', 'subdiv_9', 'subdiv_11', 'subdiv_12'

# %%
extract_cycle_videos_and_plots(
    file_name = file_name,
    windows = traj_tuples,  # List of (win_start, win_end, t_poi) tuples
    window_key = w_key,
    base_path_logs = "data/logs_v4_0.007_foot_jun3",            # logs_v4_0.007_foot_jun3       logs_v2_may
    figsize = (10, 3),
    dpi = 200,
    save_dir = "composite_videos",
    )
# Out:
# Windows data:
# Window 1:
#   Start: 21.306
#   End: 26.175
#   POI: 23.740
#   Duration: 4.869
# Window 2:
#   Start: 23.686
#   End: 28.664
#   POI: 26.175
#   Duration: 4.978
# Window 3:
#   Start: 26.251
#   End: 31.076
#   POI: 28.664
#   Duration: 4.825
# Window 4:
#   Start: 28.671
#   End: 33.482
#   POI: 31.076
#   Duration: 4.811
# Window 5:
#   Start: 31.112
#   End: 35.851
#   POI: 33.482
#   Duration: 4.740
# Window 6:
#   Start: 33.510
#   End: 38.193
#   POI: 35.851
#   Duration: 4.683
#
# Foot data ranges:
# Left foot time range: 0.733 to 340.450
# Right foot time range: 0.267 to 339.721
# Number of left foot onsets: 240
# Number of right foot onsets: 234
#
# Processing 6 windows
# Total frames in trajectory data: 81793
# Time range in trajectory data: 0.000 to 340.800
#
# Processing window 1:
#   Window time range: 21.306 to 26.175
#   Found 3 left foot onsets and 3 right foot onsets
#   Left foot onset times: [21.8875     22.47916667 24.95416667]
#   Right foot onset times: [21.325      23.72916667 26.17083333]
#   Video frames: 1065 to 1308 (50fps)
#   Trajectory frames: 5113 to 6281 (240fps)
#   Trajectory data points: 1168
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_001_21.31_26.17.mp4
# Start time: 21.30566666633333
# Duration: 4.869333333333337
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 21.30566666633333 -t 4.869333333333337 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_001_21.31_26.17.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_001_21.31_26.17.mp4
# File size: 2621556 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_001_21.31_26.17.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\plots\BKO_E1_D1_02_Maraka_window_001_21.31_26.17.mp4
#   Video duration: 4.869s
#   Plot duration: 4.833s
#
# Processing window 2:
#   Window time range: 23.686 to 28.664
#   Found 2 left foot onsets and 2 right foot onsets
#   Left foot onset times: [24.95416667 27.42083333]
#   Right foot onset times: [23.72916667 26.17083333]
#   Video frames: 1184 to 1433 (50fps)
#   Trajectory frames: 5684 to 6879 (240fps)
#   Trajectory data points: 1195
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_002_23.69_28.66.mp4
# Start time: 23.68611111066667
# Duration: 4.9777777779999965
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 23.68611111066667 -t 4.9777777779999965 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_002_23.69_28.66.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_002_23.69_28.66.mp4
# File size: 2851957 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_002_23.69_28.66.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\plots\BKO_E1_D1_02_Maraka_window_002_23.69_28.66.mp4
#   Video duration: 4.978s
#   Plot duration: 4.958s
#
# Processing window 3:
#   Window time range: 26.251 to 31.076
#   Found 2 left foot onsets and 1 right foot onsets
#   Left foot onset times: [27.42083333 29.89166667]
#   Right foot onset times: [28.66666667]
#   Video frames: 1312 to 1553 (50fps)
#   Trajectory frames: 6300 to 7458 (240fps)
#   Trajectory data points: 1158
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_003_26.25_31.08.mp4
# Start time: 26.251444444
# Duration: 4.82488888933333
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 26.251444444 -t 4.82488888933333 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_003_26.25_31.08.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_003_26.25_31.08.mp4
# File size: 2887535 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_003_26.25_31.08.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\plots\BKO_E1_D1_02_Maraka_window_003_26.25_31.08.mp4
#   Video duration: 4.825s
#   Plot duration: 4.792s
#
# Processing window 4:
#   Window time range: 28.671 to 33.482
#   Found 2 left foot onsets and 1 right foot onsets
#   Left foot onset times: [29.89166667 32.29583333]
#   Right foot onset times: [31.125]
#   Video frames: 1433 to 1674 (50fps)
#   Trajectory frames: 6881 to 8035 (240fps)
#   Trajectory data points: 1154
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_004_28.67_33.48.mp4
# Start time: 28.67100000033333
# Duration: 4.810666666000003
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 28.67100000033333 -t 4.810666666000003 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_004_28.67_33.48.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_004_28.67_33.48.mp4
# File size: 3027723 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_004_28.67_33.48.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\plots\BKO_E1_D1_02_Maraka_window_004_28.67_33.48.mp4
#   Video duration: 4.811s
#   Plot duration: 4.792s
#
# Processing window 5:
#   Window time range: 31.112 to 35.851
#   Found 2 left foot onsets and 2 right foot onsets
#   Left foot onset times: [32.29583333 34.6625    ]
#   Right foot onset times: [31.125      33.52083333]
#   Video frames: 1555 to 1792 (50fps)
#   Trajectory frames: 7466 to 8604 (240fps)
#   Trajectory data points: 1138
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_005_31.11_35.85.mp4
# Start time: 31.111888888666662
# Duration: 4.7395555553333395
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 31.111888888666662 -t 4.7395555553333395 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_005_31.11_35.85.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_005_31.11_35.85.mp4
# File size: 3006292 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_005_31.11_35.85.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\plots\BKO_E1_D1_02_Maraka_window_005_31.11_35.85.mp4
#   Video duration: 4.740s
#   Plot duration: 4.708s
#
# Processing window 6:
#   Window time range: 33.510 to 38.193
#   Found 2 left foot onsets and 2 right foot onsets
#   Left foot onset times: [34.6625 36.9875]
#   Right foot onset times: [33.52083333 35.9       ]
#   Video frames: 1675 to 1909 (50fps)
#   Trajectory frames: 8042 to 9166 (240fps)
#   Trajectory data points: 1124
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_006_33.51_38.19.mp4
# Start time: 33.510111110333334
# Duration: 4.682666667333336
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 33.510111110333334 -t 4.682666667333336 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_006_33.51_38.19.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_006_33.51_38.19.mp4
# File size: 3014540 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\videos\BKO_E1_D1_02_Maraka_window_006_33.51_38.19.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\plots\BKO_E1_D1_02_Maraka_window_006_33.51_38.19.mp4
#   Video duration: 4.683s
#   Plot duration: 4.667s
#
# Processing complete!

# %% [markdown]
# ### Generate Skeletal video + trimmed_video_mix

# %%
video_path = os.path.join("data", "videos", f"{file_name}_pre_R_Mix.mp4")

output_dir1 = os.path.join("composite_videos", file_name, w_key, "video_skeleton")
os.makedirs(output_dir1, exist_ok=True)

output_dir3 = os.path.join("composite_videos", file_name, w_key, "drum_dot_merged")
os.makedirs(output_dir3, exist_ok=True)

output_dir4 = os.path.join("composite_videos", file_name, w_key, "dance_dot")
os.makedirs(output_dir4, exist_ok=True)

for start_time, end_time, _ in traj_tuples:

    save_fname = f"drum_dot_merged_{start_time:.2f}_{end_time:.2f}.mp4"
    animate_merged_phase_analysis(
        file_name, start_time, end_time,
        cycles_csv_path, onsets_csv_path,
        figsize=(10, 3), dpi=200,
        save_fname = save_fname,
        save_dir=output_dir3
        )
    
    animate_dance_phase_analysis(
        file_name, start_time, end_time,
        cycles_csv_path, dance_csv_path,
        figsize= (10, 3), dpi= 200, save_dir= output_dir4
    )

    view_videos = prepare_videos(
        filename= bvh_file,
        start_time= start_time,
        end_time= end_time,
        views_to_generate = ['front'],
        video_path= None,             # video_path, wonr generate video
        video_size= (1280, 720),
        fps= 24,
        output_dir = output_dir1
    )
# Out:
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 21.30566666633333s - 26.174999999666667s: 13
# Total onsets: 1830
# Onsets in window 21.30566666633333s - 26.174999999666667s: 26
# Total onsets: 1830
# Onsets in window 21.30566666633333s - 26.174999999666667s: 15
#
# Creating animation...
# Animation will have 117 frames
# Time range: 21.31s - 26.14s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\drum_dot_merged\drum_dot_merged_21.31_26.17.mp4
# Animation saved successfully!
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\dance_dot\dance_21.31_26.17.mp4
# Animation saved successfully!
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# Position columns: ['Time', 'Hips.X', 'Hips.Y', 'Hips.Z', 'LeftHip.X', 'LeftHip.Y', 'LeftHip.Z', 'LeftKnee.X', 'LeftKnee.Y', 'LeftKnee.Z', 'LeftAnkle.X', 'LeftAnkle.Y', 'LeftAnkle.Z', 'LeftToe.X', 'LeftToe.Y', 'LeftToe.Z', 'LeftToeEnd.X', 'LeftToeEnd.Y', 'LeftToeEnd.Z', 'RightHip.X', 'RightHip.Y', 'RightHip.Z', 'RightKnee.X', 'RightKnee.Y', 'RightKnee.Z', 'RightAnkle.X', 'RightAnkle.Y', 'RightAnkle.Z', 'RightToe.X', 'RightToe.Y', 'RightToe.Z', 'RightToeEnd.X', 'RightToeEnd.Y', 'RightToeEnd.Z', 'Chest.X', 'Chest.Y', 'Chest.Z', 'Chest2.X', 'Chest2.Y', 'Chest2.Z', 'Chest3.X', 'Chest3.Y', 'Chest3.Z', 'Chest4.X', 'Chest4.Y', 'Chest4.Z', 'LeftCollar.X', 'LeftCollar.Y', 'LeftCollar.Z', 'LeftShoulder.X', 'LeftShoulder.Y', 'LeftShoulder.Z', 'LeftElbow.X', 'LeftElbow.Y', 'LeftElbow.Z', 'LeftWrist.X', 'LeftWrist.Y', 'LeftWrist.Z', 'LeftWristEnd.X', 'LeftWristEnd.Y', 'LeftWristEnd.Z', 'RightCollar.X', 'RightCollar.Y', 'RightCollar.Z', 'RightShoulder.X', 'RightShoulder.Y', 'RightShoulder.Z', 'RightElbow.X', 'RightElbow.Y', 'RightElbow.Z', 'RightWrist.X', 'RightWrist.Y', 'RightWrist.Z', 'RightWristEnd.X', 'RightWristEnd.Y', 'RightWristEnd.Z', 'Neck.X', 'Neck.Y', 'Neck.Z', 'Head.X', 'Head.Y', 'Head.Z', 'HeadEnd.X', 'HeadEnd.Y', 'HeadEnd.Z']
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
#
# Debug Information:
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
# T-pose positions: {'Hips': array([ 0.      , 89.062381,  0.      ]), 'LeftHip': array([7.78521200e+00, 8.90525861e+01, 3.31251140e-07]), 'LeftKnee': array([ 7.785212  , 48.30244939, -1.95830332]), 'LeftAnkle': array([ 7.785212  ,  8.66793811, -5.18636626]), 'LeftToe': array([ 7.785212  ,  1.63068611, 10.77240574]), 'LeftToeEnd': array([ 7.785212  ,  0.11709711, 17.35731374]), 'RightHip': array([-7.78521200e+00,  8.90547453e+01, -2.20896914e-07]), 'RightKnee': array([-7.785212  , 48.30449594, -1.95595682]), 'RightAnkle': array([-7.785212  ,  8.66793723, -5.1587819 ]), 'RightToe': array([-7.785212  ,  1.63068523, 10.7999901 ]), 'RightToeEnd': array([-7.785212  ,  0.11709623, 17.3848981 ]), 'Chest': array([ 0.00000000e+00,  9.86069642e+01, -6.81040802e-08]), 'Chest2': array([ 0.00000000e+00,  1.09133886e+02, -6.81040802e-08]), 'Chest3': array([  0.        , 118.69477667,  -0.97204375]), 'Chest4': array([  0.        , 128.24489067,  -1.9439801 ]), 'LeftCollar': array([  2.86465   , 135.75248167,  -1.9439801 ]), 'LeftShoulder': array([ 16.180918  , 135.75248167,  -1.9439801 ]), 'LeftElbow': array([ 44.484243  , 135.75248167,  -1.9439801 ]), 'LeftWrist': array([ 67.68105335, 135.75248167,  -1.00521599]), 'LeftWristEnd': array([ 85.05288935, 135.75248167,  -1.00521599]), 'RightCollar': array([ -2.86465   , 135.75248167,  -1.9439801 ]), 'RightShoulder': array([-16.180918  , 135.75248167,  -1.9439801 ]), 'RightElbow': array([-44.484243  , 135.75248167,  -1.9439801 ]), 'RightWrist': array([-67.68105335, 135.75248167,  -1.00521599]), 'RightWristEnd': array([-85.05288935, 135.75248167,  -1.00521599]), 'Neck': array([  0.        , 141.64188767,  -1.9439801 ]), 'Head': array([ 0.00000000e+00,  1.50363983e+02, -5.27447096e-04]), 'HeadEnd': array([  0.        , 166.97131676,   0.97534886])}
# Connections: [('Hips', 'Chest'), ('Chest', 'Chest2'), ('Chest2', 'Chest3'), ('Chest3', 'Chest4'), ('Chest4', 'Neck'), ('Neck', 'Head'), ('Chest4', 'RightCollar'), ('RightCollar', 'RightShoulder'), ('RightShoulder', 'RightElbow'), ('RightElbow', 'RightWrist'), ('Chest4', 'LeftCollar'), ('LeftCollar', 'LeftShoulder'), ('LeftShoulder', 'LeftElbow'), ('LeftElbow', 'LeftWrist'), ('Hips', 'RightHip'), ('RightHip', 'RightKnee'), ('RightKnee', 'RightAnkle'), ('RightAnkle', 'RightToe'), ('Hips', 'LeftHip'), ('LeftHip', 'LeftKnee'), ('LeftKnee', 'LeftAnkle'), ('LeftAnkle', 'LeftToe')]
#
# Video generation settings:
# Start time: 21.31s (frame 5113)
# End time: 26.17s (frame 6281)
# Output file: composite_videos\BKO_E1_D1_02_Maraka\beat_1\video_skeleton\front_view_21.3_26.2.mp4
# Output FPS: 24
# Video size: 1280x720
# Frame 5113 valid markers: 28/28
# Frame 5113 valid markers: 28/28
# Frame 5123 valid markers: 28/28
# Frame 5133 valid markers: 28/28
# Frame 5143 valid markers: 28/28
# Frame 5153 valid markers: 28/28
# Frame 5163 valid markers: 28/28
# Frame 5173 valid markers: 28/28
# Frame 5183 valid markers: 28/28
# Frame 5193 valid markers: 28/28
# Frame 5203 valid markers: 28/28
# Frame 5213 valid markers: 28/28
# Frame 5223 valid markers: 28/28
# Frame 5233 valid markers: 28/28
# Frame 5243 valid markers: 28/28
# Frame 5253 valid markers: 28/28
# Frame 5263 valid markers: 28/28
# Frame 5273 valid markers: 28/28
# Frame 5283 valid markers: 28/28
# Frame 5293 valid markers: 28/28
# Frame 5303 valid markers: 28/28
# Frame 5313 valid markers: 28/28
# Frame 5323 valid markers: 28/28
# Frame 5333 valid markers: 28/28
# Frame 5343 valid markers: 28/28
# Frame 5353 valid markers: 28/28
# Frame 5363 valid markers: 28/28
# Frame 5373 valid markers: 28/28
# Frame 5383 valid markers: 28/28
# Frame 5393 valid markers: 28/28
# Frame 5403 valid markers: 28/28
# Frame 5413 valid markers: 28/28
# Frame 5423 valid markers: 28/28
# Frame 5433 valid markers: 28/28
# Frame 5443 valid markers: 28/28
# Frame 5453 valid markers: 28/28
# Frame 5463 valid markers: 28/28
# Frame 5473 valid markers: 28/28
# Frame 5483 valid markers: 28/28
# Frame 5493 valid markers: 28/28
# Frame 5503 valid markers: 28/28
# Frame 5513 valid markers: 28/28
# Frame 5523 valid markers: 28/28
# Frame 5533 valid markers: 28/28
# Frame 5543 valid markers: 28/28
# Frame 5553 valid markers: 28/28
# Frame 5563 valid markers: 28/28
# Frame 5573 valid markers: 28/28
# Frame 5583 valid markers: 28/28
# Frame 5593 valid markers: 28/28
# Frame 5603 valid markers: 28/28
# Frame 5613 valid markers: 28/28
# Frame 5623 valid markers: 28/28
# Frame 5633 valid markers: 28/28
# Frame 5643 valid markers: 28/28
# Frame 5653 valid markers: 28/28
# Frame 5663 valid markers: 28/28
# Frame 5673 valid markers: 28/28
# Frame 5683 valid markers: 28/28
# Frame 5693 valid markers: 28/28
# Frame 5703 valid markers: 28/28
# Frame 5713 valid markers: 28/28
# Frame 5723 valid markers: 28/28
# Frame 5733 valid markers: 28/28
# Frame 5743 valid markers: 28/28
# Frame 5753 valid markers: 28/28
# Frame 5763 valid markers: 28/28
# Frame 5773 valid markers: 28/28
# Frame 5783 valid markers: 28/28
# Frame 5793 valid markers: 28/28
# Frame 5803 valid markers: 28/28
# Frame 5813 valid markers: 28/28
# Frame 5823 valid markers: 28/28
# Frame 5833 valid markers: 28/28
# Frame 5843 valid markers: 28/28
# Frame 5853 valid markers: 28/28
# Frame 5863 valid markers: 28/28
# Frame 5873 valid markers: 28/28
# Frame 5883 valid markers: 28/28
# Frame 5893 valid markers: 28/28
# Frame 5903 valid markers: 28/28
# Frame 5913 valid markers: 28/28
# Frame 5923 valid markers: 28/28
# Frame 5933 valid markers: 28/28
# Frame 5943 valid markers: 28/28
# Frame 5953 valid markers: 28/28
# Frame 5963 valid markers: 28/28
# Frame 5973 valid markers: 28/28
# Frame 5983 valid markers: 28/28
# Frame 5993 valid markers: 28/28
# Frame 6003 valid markers: 28/28
# Frame 6013 valid markers: 28/28
# Frame 6023 valid markers: 28/28
# Frame 6033 valid markers: 28/28
# Frame 6043 valid markers: 28/28
# Frame 6053 valid markers: 28/28
# Frame 6063 valid markers: 28/28
# Frame 6073 valid markers: 28/28
# Frame 6083 valid markers: 28/28
# Frame 6093 valid markers: 28/28
# Frame 6103 valid markers: 28/28
# Frame 6113 valid markers: 28/28
# Frame 6123 valid markers: 28/28
# Frame 6133 valid markers: 28/28
# Frame 6143 valid markers: 28/28
# Frame 6153 valid markers: 28/28
# Frame 6163 valid markers: 28/28
# Frame 6173 valid markers: 28/28
# Frame 6183 valid markers: 28/28
# Frame 6193 valid markers: 28/28
# Frame 6203 valid markers: 28/28
# Frame 6213 valid markers: 28/28
# Frame 6223 valid markers: 28/28
# Frame 6233 valid markers: 28/28
# Frame 6243 valid markers: 28/28
# Frame 6253 valid markers: 28/28
# Frame 6263 valid markers: 28/28
# Frame 6273 valid markers: 28/28
# Saved frame 117/116
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka\beat_1\video_skeleton\front_view_21.3_26.2.mp4
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 23.68611111066667s - 28.663888888666666s: 13
# Total onsets: 1830
# Onsets in window 23.68611111066667s - 28.663888888666666s: 27
# Total onsets: 1830
# Onsets in window 23.68611111066667s - 28.663888888666666s: 17
#
# Creating animation...
# Animation will have 120 frames
# Time range: 23.69s - 28.64s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\drum_dot_merged\drum_dot_merged_23.69_28.66.mp4
# Animation saved successfully!
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\dance_dot\dance_23.69_28.66.mp4
# Animation saved successfully!
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# Position columns: ['Time', 'Hips.X', 'Hips.Y', 'Hips.Z', 'LeftHip.X', 'LeftHip.Y', 'LeftHip.Z', 'LeftKnee.X', 'LeftKnee.Y', 'LeftKnee.Z', 'LeftAnkle.X', 'LeftAnkle.Y', 'LeftAnkle.Z', 'LeftToe.X', 'LeftToe.Y', 'LeftToe.Z', 'LeftToeEnd.X', 'LeftToeEnd.Y', 'LeftToeEnd.Z', 'RightHip.X', 'RightHip.Y', 'RightHip.Z', 'RightKnee.X', 'RightKnee.Y', 'RightKnee.Z', 'RightAnkle.X', 'RightAnkle.Y', 'RightAnkle.Z', 'RightToe.X', 'RightToe.Y', 'RightToe.Z', 'RightToeEnd.X', 'RightToeEnd.Y', 'RightToeEnd.Z', 'Chest.X', 'Chest.Y', 'Chest.Z', 'Chest2.X', 'Chest2.Y', 'Chest2.Z', 'Chest3.X', 'Chest3.Y', 'Chest3.Z', 'Chest4.X', 'Chest4.Y', 'Chest4.Z', 'LeftCollar.X', 'LeftCollar.Y', 'LeftCollar.Z', 'LeftShoulder.X', 'LeftShoulder.Y', 'LeftShoulder.Z', 'LeftElbow.X', 'LeftElbow.Y', 'LeftElbow.Z', 'LeftWrist.X', 'LeftWrist.Y', 'LeftWrist.Z', 'LeftWristEnd.X', 'LeftWristEnd.Y', 'LeftWristEnd.Z', 'RightCollar.X', 'RightCollar.Y', 'RightCollar.Z', 'RightShoulder.X', 'RightShoulder.Y', 'RightShoulder.Z', 'RightElbow.X', 'RightElbow.Y', 'RightElbow.Z', 'RightWrist.X', 'RightWrist.Y', 'RightWrist.Z', 'RightWristEnd.X', 'RightWristEnd.Y', 'RightWristEnd.Z', 'Neck.X', 'Neck.Y', 'Neck.Z', 'Head.X', 'Head.Y', 'Head.Z', 'HeadEnd.X', 'HeadEnd.Y', 'HeadEnd.Z']
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
#
# Debug Information:
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
# T-pose positions: {'Hips': array([ 0.      , 89.062381,  0.      ]), 'LeftHip': array([7.78521200e+00, 8.90525861e+01, 3.31251140e-07]), 'LeftKnee': array([ 7.785212  , 48.30244939, -1.95830332]), 'LeftAnkle': array([ 7.785212  ,  8.66793811, -5.18636626]), 'LeftToe': array([ 7.785212  ,  1.63068611, 10.77240574]), 'LeftToeEnd': array([ 7.785212  ,  0.11709711, 17.35731374]), 'RightHip': array([-7.78521200e+00,  8.90547453e+01, -2.20896914e-07]), 'RightKnee': array([-7.785212  , 48.30449594, -1.95595682]), 'RightAnkle': array([-7.785212  ,  8.66793723, -5.1587819 ]), 'RightToe': array([-7.785212  ,  1.63068523, 10.7999901 ]), 'RightToeEnd': array([-7.785212  ,  0.11709623, 17.3848981 ]), 'Chest': array([ 0.00000000e+00,  9.86069642e+01, -6.81040802e-08]), 'Chest2': array([ 0.00000000e+00,  1.09133886e+02, -6.81040802e-08]), 'Chest3': array([  0.        , 118.69477667,  -0.97204375]), 'Chest4': array([  0.        , 128.24489067,  -1.9439801 ]), 'LeftCollar': array([  2.86465   , 135.75248167,  -1.9439801 ]), 'LeftShoulder': array([ 16.180918  , 135.75248167,  -1.9439801 ]), 'LeftElbow': array([ 44.484243  , 135.75248167,  -1.9439801 ]), 'LeftWrist': array([ 67.68105335, 135.75248167,  -1.00521599]), 'LeftWristEnd': array([ 85.05288935, 135.75248167,  -1.00521599]), 'RightCollar': array([ -2.86465   , 135.75248167,  -1.9439801 ]), 'RightShoulder': array([-16.180918  , 135.75248167,  -1.9439801 ]), 'RightElbow': array([-44.484243  , 135.75248167,  -1.9439801 ]), 'RightWrist': array([-67.68105335, 135.75248167,  -1.00521599]), 'RightWristEnd': array([-85.05288935, 135.75248167,  -1.00521599]), 'Neck': array([  0.        , 141.64188767,  -1.9439801 ]), 'Head': array([ 0.00000000e+00,  1.50363983e+02, -5.27447096e-04]), 'HeadEnd': array([  0.        , 166.97131676,   0.97534886])}
# Connections: [('Hips', 'Chest'), ('Chest', 'Chest2'), ('Chest2', 'Chest3'), ('Chest3', 'Chest4'), ('Chest4', 'Neck'), ('Neck', 'Head'), ('Chest4', 'RightCollar'), ('RightCollar', 'RightShoulder'), ('RightShoulder', 'RightElbow'), ('RightElbow', 'RightWrist'), ('Chest4', 'LeftCollar'), ('LeftCollar', 'LeftShoulder'), ('LeftShoulder', 'LeftElbow'), ('LeftElbow', 'LeftWrist'), ('Hips', 'RightHip'), ('RightHip', 'RightKnee'), ('RightKnee', 'RightAnkle'), ('RightAnkle', 'RightToe'), ('Hips', 'LeftHip'), ('LeftHip', 'LeftKnee'), ('LeftKnee', 'LeftAnkle'), ('LeftAnkle', 'LeftToe')]
#
# Video generation settings:
# Start time: 23.69s (frame 5684)
# End time: 28.66s (frame 6879)
# Output file: composite_videos\BKO_E1_D1_02_Maraka\beat_1\video_skeleton\front_view_23.7_28.7.mp4
# Output FPS: 24
# Video size: 1280x720
# Frame 5684 valid markers: 28/28
# Frame 5684 valid markers: 28/28
# Frame 5694 valid markers: 28/28
# Frame 5704 valid markers: 28/28
# Frame 5714 valid markers: 28/28
# Frame 5724 valid markers: 28/28
# Frame 5734 valid markers: 28/28
# Frame 5744 valid markers: 28/28
# Frame 5754 valid markers: 28/28
# Frame 5764 valid markers: 28/28
# Frame 5774 valid markers: 28/28
# Frame 5784 valid markers: 28/28
# Frame 5794 valid markers: 28/28
# Frame 5804 valid markers: 28/28
# Frame 5814 valid markers: 28/28
# Frame 5824 valid markers: 28/28
# Frame 5834 valid markers: 28/28
# Frame 5844 valid markers: 28/28
# Frame 5854 valid markers: 28/28
# Frame 5864 valid markers: 28/28
# Frame 5874 valid markers: 28/28
# Frame 5884 valid markers: 28/28
# Frame 5894 valid markers: 28/28
# Frame 5904 valid markers: 28/28
# Frame 5914 valid markers: 28/28
# Frame 5924 valid markers: 28/28
# Frame 5934 valid markers: 28/28
# Frame 5944 valid markers: 28/28
# Frame 5954 valid markers: 28/28
# Frame 5964 valid markers: 28/28
# Frame 5974 valid markers: 28/28
# Frame 5984 valid markers: 28/28
# Frame 5994 valid markers: 28/28
# Frame 6004 valid markers: 28/28
# Frame 6014 valid markers: 28/28
# Frame 6024 valid markers: 28/28
# Frame 6034 valid markers: 28/28
# Frame 6044 valid markers: 28/28
# Frame 6054 valid markers: 28/28
# Frame 6064 valid markers: 28/28
# Frame 6074 valid markers: 28/28
# Frame 6084 valid markers: 28/28
# Frame 6094 valid markers: 28/28
# Frame 6104 valid markers: 28/28
# Frame 6114 valid markers: 28/28
# Frame 6124 valid markers: 28/28
# Frame 6134 valid markers: 28/28
# Frame 6144 valid markers: 28/28
# Frame 6154 valid markers: 28/28
# Frame 6164 valid markers: 28/28
# Frame 6174 valid markers: 28/28
# Frame 6184 valid markers: 28/28
# Frame 6194 valid markers: 28/28
# Frame 6204 valid markers: 28/28
# Frame 6214 valid markers: 28/28
# Frame 6224 valid markers: 28/28
# Frame 6234 valid markers: 28/28
# Frame 6244 valid markers: 28/28
# Frame 6254 valid markers: 28/28
# Frame 6264 valid markers: 28/28
# Frame 6274 valid markers: 28/28
# Frame 6284 valid markers: 28/28
# Frame 6294 valid markers: 28/28
# Frame 6304 valid markers: 28/28
# Frame 6314 valid markers: 28/28
# Frame 6324 valid markers: 28/28
# Frame 6334 valid markers: 28/28
# Frame 6344 valid markers: 28/28
# Frame 6354 valid markers: 28/28
# Frame 6364 valid markers: 28/28
# Frame 6374 valid markers: 28/28
# Frame 6384 valid markers: 28/28
# Frame 6394 valid markers: 28/28
# Frame 6404 valid markers: 28/28
# Frame 6414 valid markers: 28/28
# Frame 6424 valid markers: 28/28
# Frame 6434 valid markers: 28/28
# Frame 6444 valid markers: 28/28
# Frame 6454 valid markers: 28/28
# Frame 6464 valid markers: 28/28
# Frame 6474 valid markers: 28/28
# Frame 6484 valid markers: 28/28
# Frame 6494 valid markers: 28/28
# Frame 6504 valid markers: 28/28
# Frame 6514 valid markers: 28/28
# Frame 6524 valid markers: 28/28
# Frame 6534 valid markers: 28/28
# Frame 6544 valid markers: 28/28
# Frame 6554 valid markers: 28/28
# Frame 6564 valid markers: 28/28
# Frame 6574 valid markers: 28/28
# Frame 6584 valid markers: 28/28
# Frame 6594 valid markers: 28/28
# Frame 6604 valid markers: 28/28
# Frame 6614 valid markers: 28/28
# Frame 6624 valid markers: 28/28
# Frame 6634 valid markers: 28/28
# Frame 6644 valid markers: 28/28
# Frame 6654 valid markers: 28/28
# Frame 6664 valid markers: 28/28
# Frame 6674 valid markers: 28/28
# Frame 6684 valid markers: 28/28
# Frame 6694 valid markers: 28/28
# Frame 6704 valid markers: 28/28
# Frame 6714 valid markers: 28/28
# Frame 6724 valid markers: 28/28
# Frame 6734 valid markers: 28/28
# Frame 6744 valid markers: 28/28
# Frame 6754 valid markers: 28/28
# Frame 6764 valid markers: 28/28
# Frame 6774 valid markers: 28/28
# Frame 6784 valid markers: 28/28
# Frame 6794 valid markers: 28/28
# Frame 6804 valid markers: 28/28
# Frame 6814 valid markers: 28/28
# Frame 6824 valid markers: 28/28
# Frame 6834 valid markers: 28/28
# Frame 6844 valid markers: 28/28
# Frame 6854 valid markers: 28/28
# Frame 6864 valid markers: 28/28
# Frame 6874 valid markers: 28/28
# Saved frame 120/119
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka\beat_1\video_skeleton\front_view_23.7_28.7.mp4
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 26.251444444s - 31.07633333333333s: 13
# Total onsets: 1830
# Onsets in window 26.251444444s - 31.07633333333333s: 23
# Total onsets: 1830
# Onsets in window 26.251444444s - 31.07633333333333s: 15
#
# Creating animation...
# Animation will have 116 frames
# Time range: 26.25s - 31.04s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\drum_dot_merged\drum_dot_merged_26.25_31.08.mp4
# Animation saved successfully!
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\dance_dot\dance_26.25_31.08.mp4
# Animation saved successfully!
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# Position columns: ['Time', 'Hips.X', 'Hips.Y', 'Hips.Z', 'LeftHip.X', 'LeftHip.Y', 'LeftHip.Z', 'LeftKnee.X', 'LeftKnee.Y', 'LeftKnee.Z', 'LeftAnkle.X', 'LeftAnkle.Y', 'LeftAnkle.Z', 'LeftToe.X', 'LeftToe.Y', 'LeftToe.Z', 'LeftToeEnd.X', 'LeftToeEnd.Y', 'LeftToeEnd.Z', 'RightHip.X', 'RightHip.Y', 'RightHip.Z', 'RightKnee.X', 'RightKnee.Y', 'RightKnee.Z', 'RightAnkle.X', 'RightAnkle.Y', 'RightAnkle.Z', 'RightToe.X', 'RightToe.Y', 'RightToe.Z', 'RightToeEnd.X', 'RightToeEnd.Y', 'RightToeEnd.Z', 'Chest.X', 'Chest.Y', 'Chest.Z', 'Chest2.X', 'Chest2.Y', 'Chest2.Z', 'Chest3.X', 'Chest3.Y', 'Chest3.Z', 'Chest4.X', 'Chest4.Y', 'Chest4.Z', 'LeftCollar.X', 'LeftCollar.Y', 'LeftCollar.Z', 'LeftShoulder.X', 'LeftShoulder.Y', 'LeftShoulder.Z', 'LeftElbow.X', 'LeftElbow.Y', 'LeftElbow.Z', 'LeftWrist.X', 'LeftWrist.Y', 'LeftWrist.Z', 'LeftWristEnd.X', 'LeftWristEnd.Y', 'LeftWristEnd.Z', 'RightCollar.X', 'RightCollar.Y', 'RightCollar.Z', 'RightShoulder.X', 'RightShoulder.Y', 'RightShoulder.Z', 'RightElbow.X', 'RightElbow.Y', 'RightElbow.Z', 'RightWrist.X', 'RightWrist.Y', 'RightWrist.Z', 'RightWristEnd.X', 'RightWristEnd.Y', 'RightWristEnd.Z', 'Neck.X', 'Neck.Y', 'Neck.Z', 'Head.X', 'Head.Y', 'Head.Z', 'HeadEnd.X', 'HeadEnd.Y', 'HeadEnd.Z']
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
#
# Debug Information:
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
# T-pose positions: {'Hips': array([ 0.      , 89.062381,  0.      ]), 'LeftHip': array([7.78521200e+00, 8.90525861e+01, 3.31251140e-07]), 'LeftKnee': array([ 7.785212  , 48.30244939, -1.95830332]), 'LeftAnkle': array([ 7.785212  ,  8.66793811, -5.18636626]), 'LeftToe': array([ 7.785212  ,  1.63068611, 10.77240574]), 'LeftToeEnd': array([ 7.785212  ,  0.11709711, 17.35731374]), 'RightHip': array([-7.78521200e+00,  8.90547453e+01, -2.20896914e-07]), 'RightKnee': array([-7.785212  , 48.30449594, -1.95595682]), 'RightAnkle': array([-7.785212  ,  8.66793723, -5.1587819 ]), 'RightToe': array([-7.785212  ,  1.63068523, 10.7999901 ]), 'RightToeEnd': array([-7.785212  ,  0.11709623, 17.3848981 ]), 'Chest': array([ 0.00000000e+00,  9.86069642e+01, -6.81040802e-08]), 'Chest2': array([ 0.00000000e+00,  1.09133886e+02, -6.81040802e-08]), 'Chest3': array([  0.        , 118.69477667,  -0.97204375]), 'Chest4': array([  0.        , 128.24489067,  -1.9439801 ]), 'LeftCollar': array([  2.86465   , 135.75248167,  -1.9439801 ]), 'LeftShoulder': array([ 16.180918  , 135.75248167,  -1.9439801 ]), 'LeftElbow': array([ 44.484243  , 135.75248167,  -1.9439801 ]), 'LeftWrist': array([ 67.68105335, 135.75248167,  -1.00521599]), 'LeftWristEnd': array([ 85.05288935, 135.75248167,  -1.00521599]), 'RightCollar': array([ -2.86465   , 135.75248167,  -1.9439801 ]), 'RightShoulder': array([-16.180918  , 135.75248167,  -1.9439801 ]), 'RightElbow': array([-44.484243  , 135.75248167,  -1.9439801 ]), 'RightWrist': array([-67.68105335, 135.75248167,  -1.00521599]), 'RightWristEnd': array([-85.05288935, 135.75248167,  -1.00521599]), 'Neck': array([  0.        , 141.64188767,  -1.9439801 ]), 'Head': array([ 0.00000000e+00,  1.50363983e+02, -5.27447096e-04]), 'HeadEnd': array([  0.        , 166.97131676,   0.97534886])}
# Connections: [('Hips', 'Chest'), ('Chest', 'Chest2'), ('Chest2', 'Chest3'), ('Chest3', 'Chest4'), ('Chest4', 'Neck'), ('Neck', 'Head'), ('Chest4', 'RightCollar'), ('RightCollar', 'RightShoulder'), ('RightShoulder', 'RightElbow'), ('RightElbow', 'RightWrist'), ('Chest4', 'LeftCollar'), ('LeftCollar', 'LeftShoulder'), ('LeftShoulder', 'LeftElbow'), ('LeftElbow', 'LeftWrist'), ('Hips', 'RightHip'), ('RightHip', 'RightKnee'), ('RightKnee', 'RightAnkle'), ('RightAnkle', 'RightToe'), ('Hips', 'LeftHip'), ('LeftHip', 'LeftKnee'), ('LeftKnee', 'LeftAnkle'), ('LeftAnkle', 'LeftToe')]
#
# Video generation settings:
# Start time: 26.25s (frame 6300)
# End time: 31.08s (frame 7458)
# Output file: composite_videos\BKO_E1_D1_02_Maraka\beat_1\video_skeleton\front_view_26.3_31.1.mp4
# Output FPS: 24
# Video size: 1280x720
# Frame 6300 valid markers: 28/28
# Frame 6300 valid markers: 28/28
# Frame 6310 valid markers: 28/28
# Frame 6320 valid markers: 28/28
# Frame 6330 valid markers: 28/28
# Frame 6340 valid markers: 28/28
# Frame 6350 valid markers: 28/28
# Frame 6360 valid markers: 28/28
# Frame 6370 valid markers: 28/28
# Frame 6380 valid markers: 28/28
# Frame 6390 valid markers: 28/28
# Frame 6400 valid markers: 28/28
# Frame 6410 valid markers: 28/28
# Frame 6420 valid markers: 28/28
# Frame 6430 valid markers: 28/28
# Frame 6440 valid markers: 28/28
# Frame 6450 valid markers: 28/28
# Frame 6460 valid markers: 28/28
# Frame 6470 valid markers: 28/28
# Frame 6480 valid markers: 28/28
# Frame 6490 valid markers: 28/28
# Frame 6500 valid markers: 28/28
# Frame 6510 valid markers: 28/28
# Frame 6520 valid markers: 28/28
# Frame 6530 valid markers: 28/28
# Frame 6540 valid markers: 28/28
# Frame 6550 valid markers: 28/28
# Frame 6560 valid markers: 28/28
# Frame 6570 valid markers: 28/28
# Frame 6580 valid markers: 28/28
# Frame 6590 valid markers: 28/28
# Frame 6600 valid markers: 28/28
# Frame 6610 valid markers: 28/28
# Frame 6620 valid markers: 28/28
# Frame 6630 valid markers: 28/28
# Frame 6640 valid markers: 28/28
# Frame 6650 valid markers: 28/28
# Frame 6660 valid markers: 28/28
# Frame 6670 valid markers: 28/28
# Frame 6680 valid markers: 28/28
# Frame 6690 valid markers: 28/28
# Frame 6700 valid markers: 28/28
# Frame 6710 valid markers: 28/28
# Frame 6720 valid markers: 28/28
# Frame 6730 valid markers: 28/28
# Frame 6740 valid markers: 28/28
# Frame 6750 valid markers: 28/28
# Frame 6760 valid markers: 28/28
# Frame 6770 valid markers: 28/28
# Frame 6780 valid markers: 28/28
# Frame 6790 valid markers: 28/28
# Frame 6800 valid markers: 28/28
# Frame 6810 valid markers: 28/28
# Frame 6820 valid markers: 28/28
# Frame 6830 valid markers: 28/28
# Frame 6840 valid markers: 28/28
# Frame 6850 valid markers: 28/28
# Frame 6860 valid markers: 28/28
# Frame 6870 valid markers: 28/28
# Frame 6880 valid markers: 28/28
# Frame 6890 valid markers: 28/28
# Frame 6900 valid markers: 28/28
# Frame 6910 valid markers: 28/28
# Frame 6920 valid markers: 28/28
# Frame 6930 valid markers: 28/28
# Frame 6940 valid markers: 28/28
# Frame 6950 valid markers: 28/28
# Frame 6960 valid markers: 28/28
# Frame 6970 valid markers: 28/28
# Frame 6980 valid markers: 28/28
# Frame 6990 valid markers: 28/28
# Frame 7000 valid markers: 28/28
# Frame 7010 valid markers: 28/28
# Frame 7020 valid markers: 28/28
# Frame 7030 valid markers: 28/28
# Frame 7040 valid markers: 28/28
# Frame 7050 valid markers: 28/28
# Frame 7060 valid markers: 28/28
# Frame 7070 valid markers: 28/28
# Frame 7080 valid markers: 28/28
# Frame 7090 valid markers: 28/28
# Frame 7100 valid markers: 28/28
# Frame 7110 valid markers: 28/28
# Frame 7120 valid markers: 28/28
# Frame 7130 valid markers: 28/28
# Frame 7140 valid markers: 28/28
# Frame 7150 valid markers: 28/28
# Frame 7160 valid markers: 28/28
# Frame 7170 valid markers: 28/28
# Frame 7180 valid markers: 28/28
# Frame 7190 valid markers: 28/28
# Frame 7200 valid markers: 28/28
# Frame 7210 valid markers: 28/28
# Frame 7220 valid markers: 28/28
# Frame 7230 valid markers: 28/28
# Frame 7240 valid markers: 28/28
# Frame 7250 valid markers: 28/28
# Frame 7260 valid markers: 28/28
# Frame 7270 valid markers: 28/28
# Frame 7280 valid markers: 28/28
# Frame 7290 valid markers: 28/28
# Frame 7300 valid markers: 28/28
# Frame 7310 valid markers: 28/28
# Frame 7320 valid markers: 28/28
# Frame 7330 valid markers: 28/28
# Frame 7340 valid markers: 28/28
# Frame 7350 valid markers: 28/28
# Frame 7360 valid markers: 28/28
# Frame 7370 valid markers: 28/28
# Frame 7380 valid markers: 28/28
# Frame 7390 valid markers: 28/28
# Frame 7400 valid markers: 28/28
# Frame 7410 valid markers: 28/28
# Frame 7420 valid markers: 28/28
# Frame 7430 valid markers: 28/28
# Frame 7440 valid markers: 28/28
# Frame 7450 valid markers: 28/28
# Saved frame 116/115
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka\beat_1\video_skeleton\front_view_26.3_31.1.mp4
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 28.67100000033333s - 33.48166666633333s: 13
# Total onsets: 1830
# Onsets in window 28.67100000033333s - 33.48166666633333s: 20
# Total onsets: 1830
# Onsets in window 28.67100000033333s - 33.48166666633333s: 15
#
# Creating animation...
# Animation will have 116 frames
# Time range: 28.67s - 33.46s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\drum_dot_merged\drum_dot_merged_28.67_33.48.mp4
# Animation saved successfully!
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\dance_dot\dance_28.67_33.48.mp4
# Animation saved successfully!
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# Position columns: ['Time', 'Hips.X', 'Hips.Y', 'Hips.Z', 'LeftHip.X', 'LeftHip.Y', 'LeftHip.Z', 'LeftKnee.X', 'LeftKnee.Y', 'LeftKnee.Z', 'LeftAnkle.X', 'LeftAnkle.Y', 'LeftAnkle.Z', 'LeftToe.X', 'LeftToe.Y', 'LeftToe.Z', 'LeftToeEnd.X', 'LeftToeEnd.Y', 'LeftToeEnd.Z', 'RightHip.X', 'RightHip.Y', 'RightHip.Z', 'RightKnee.X', 'RightKnee.Y', 'RightKnee.Z', 'RightAnkle.X', 'RightAnkle.Y', 'RightAnkle.Z', 'RightToe.X', 'RightToe.Y', 'RightToe.Z', 'RightToeEnd.X', 'RightToeEnd.Y', 'RightToeEnd.Z', 'Chest.X', 'Chest.Y', 'Chest.Z', 'Chest2.X', 'Chest2.Y', 'Chest2.Z', 'Chest3.X', 'Chest3.Y', 'Chest3.Z', 'Chest4.X', 'Chest4.Y', 'Chest4.Z', 'LeftCollar.X', 'LeftCollar.Y', 'LeftCollar.Z', 'LeftShoulder.X', 'LeftShoulder.Y', 'LeftShoulder.Z', 'LeftElbow.X', 'LeftElbow.Y', 'LeftElbow.Z', 'LeftWrist.X', 'LeftWrist.Y', 'LeftWrist.Z', 'LeftWristEnd.X', 'LeftWristEnd.Y', 'LeftWristEnd.Z', 'RightCollar.X', 'RightCollar.Y', 'RightCollar.Z', 'RightShoulder.X', 'RightShoulder.Y', 'RightShoulder.Z', 'RightElbow.X', 'RightElbow.Y', 'RightElbow.Z', 'RightWrist.X', 'RightWrist.Y', 'RightWrist.Z', 'RightWristEnd.X', 'RightWristEnd.Y', 'RightWristEnd.Z', 'Neck.X', 'Neck.Y', 'Neck.Z', 'Head.X', 'Head.Y', 'Head.Z', 'HeadEnd.X', 'HeadEnd.Y', 'HeadEnd.Z']
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
#
# Debug Information:
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
# T-pose positions: {'Hips': array([ 0.      , 89.062381,  0.      ]), 'LeftHip': array([7.78521200e+00, 8.90525861e+01, 3.31251140e-07]), 'LeftKnee': array([ 7.785212  , 48.30244939, -1.95830332]), 'LeftAnkle': array([ 7.785212  ,  8.66793811, -5.18636626]), 'LeftToe': array([ 7.785212  ,  1.63068611, 10.77240574]), 'LeftToeEnd': array([ 7.785212  ,  0.11709711, 17.35731374]), 'RightHip': array([-7.78521200e+00,  8.90547453e+01, -2.20896914e-07]), 'RightKnee': array([-7.785212  , 48.30449594, -1.95595682]), 'RightAnkle': array([-7.785212  ,  8.66793723, -5.1587819 ]), 'RightToe': array([-7.785212  ,  1.63068523, 10.7999901 ]), 'RightToeEnd': array([-7.785212  ,  0.11709623, 17.3848981 ]), 'Chest': array([ 0.00000000e+00,  9.86069642e+01, -6.81040802e-08]), 'Chest2': array([ 0.00000000e+00,  1.09133886e+02, -6.81040802e-08]), 'Chest3': array([  0.        , 118.69477667,  -0.97204375]), 'Chest4': array([  0.        , 128.24489067,  -1.9439801 ]), 'LeftCollar': array([  2.86465   , 135.75248167,  -1.9439801 ]), 'LeftShoulder': array([ 16.180918  , 135.75248167,  -1.9439801 ]), 'LeftElbow': array([ 44.484243  , 135.75248167,  -1.9439801 ]), 'LeftWrist': array([ 67.68105335, 135.75248167,  -1.00521599]), 'LeftWristEnd': array([ 85.05288935, 135.75248167,  -1.00521599]), 'RightCollar': array([ -2.86465   , 135.75248167,  -1.9439801 ]), 'RightShoulder': array([-16.180918  , 135.75248167,  -1.9439801 ]), 'RightElbow': array([-44.484243  , 135.75248167,  -1.9439801 ]), 'RightWrist': array([-67.68105335, 135.75248167,  -1.00521599]), 'RightWristEnd': array([-85.05288935, 135.75248167,  -1.00521599]), 'Neck': array([  0.        , 141.64188767,  -1.9439801 ]), 'Head': array([ 0.00000000e+00,  1.50363983e+02, -5.27447096e-04]), 'HeadEnd': array([  0.        , 166.97131676,   0.97534886])}
# Connections: [('Hips', 'Chest'), ('Chest', 'Chest2'), ('Chest2', 'Chest3'), ('Chest3', 'Chest4'), ('Chest4', 'Neck'), ('Neck', 'Head'), ('Chest4', 'RightCollar'), ('RightCollar', 'RightShoulder'), ('RightShoulder', 'RightElbow'), ('RightElbow', 'RightWrist'), ('Chest4', 'LeftCollar'), ('LeftCollar', 'LeftShoulder'), ('LeftShoulder', 'LeftElbow'), ('LeftElbow', 'LeftWrist'), ('Hips', 'RightHip'), ('RightHip', 'RightKnee'), ('RightKnee', 'RightAnkle'), ('RightAnkle', 'RightToe'), ('Hips', 'LeftHip'), ('LeftHip', 'LeftKnee'), ('LeftKnee', 'LeftAnkle'), ('LeftAnkle', 'LeftToe')]
#
# Video generation settings:
# Start time: 28.67s (frame 6881)
# End time: 33.48s (frame 8035)
# Output file: composite_videos\BKO_E1_D1_02_Maraka\beat_1\video_skeleton\front_view_28.7_33.5.mp4
# Output FPS: 24
# Video size: 1280x720
# Frame 6881 valid markers: 28/28
# Frame 6881 valid markers: 28/28
# Frame 6891 valid markers: 28/28
# Frame 6901 valid markers: 28/28
# Frame 6911 valid markers: 28/28
# Frame 6921 valid markers: 28/28
# Frame 6931 valid markers: 28/28
# Frame 6941 valid markers: 28/28
# Frame 6951 valid markers: 28/28
# Frame 6961 valid markers: 28/28
# Frame 6971 valid markers: 28/28
# Frame 6981 valid markers: 28/28
# Frame 6991 valid markers: 28/28
# Frame 7001 valid markers: 28/28
# Frame 7011 valid markers: 28/28
# Frame 7021 valid markers: 28/28
# Frame 7031 valid markers: 28/28
# Frame 7041 valid markers: 28/28
# Frame 7051 valid markers: 28/28
# Frame 7061 valid markers: 28/28
# Frame 7071 valid markers: 28/28
# Frame 7081 valid markers: 28/28
# Frame 7091 valid markers: 28/28
# Frame 7101 valid markers: 28/28
# Frame 7111 valid markers: 28/28
# Frame 7121 valid markers: 28/28
# Frame 7131 valid markers: 28/28
# Frame 7141 valid markers: 28/28
# Frame 7151 valid markers: 28/28
# Frame 7161 valid markers: 28/28
# Frame 7171 valid markers: 28/28
# Frame 7181 valid markers: 28/28
# Frame 7191 valid markers: 28/28
# Frame 7201 valid markers: 28/28
# Frame 7211 valid markers: 28/28
# Frame 7221 valid markers: 28/28
# Frame 7231 valid markers: 28/28
# Frame 7241 valid markers: 28/28
# Frame 7251 valid markers: 28/28
# Frame 7261 valid markers: 28/28
# Frame 7271 valid markers: 28/28
# Frame 7281 valid markers: 28/28
# Frame 7291 valid markers: 28/28
# Frame 7301 valid markers: 28/28
# Frame 7311 valid markers: 28/28
# Frame 7321 valid markers: 28/28
# Frame 7331 valid markers: 28/28
# Frame 7341 valid markers: 28/28
# Frame 7351 valid markers: 28/28
# Frame 7361 valid markers: 28/28
# Frame 7371 valid markers: 28/28
# Frame 7381 valid markers: 28/28
# Frame 7391 valid markers: 28/28
# Frame 7401 valid markers: 28/28
# Frame 7411 valid markers: 28/28
# Frame 7421 valid markers: 28/28
# Frame 7431 valid markers: 28/28
# Frame 7441 valid markers: 28/28
# Frame 7451 valid markers: 28/28
# Frame 7461 valid markers: 28/28
# Frame 7471 valid markers: 28/28
# Frame 7481 valid markers: 28/28
# Frame 7491 valid markers: 28/28
# Frame 7501 valid markers: 28/28
# Frame 7511 valid markers: 28/28
# Frame 7521 valid markers: 28/28
# Frame 7531 valid markers: 28/28
# Frame 7541 valid markers: 28/28
# Frame 7551 valid markers: 28/28
# Frame 7561 valid markers: 28/28
# Frame 7571 valid markers: 28/28
# Frame 7581 valid markers: 28/28
# Frame 7591 valid markers: 28/28
# Frame 7601 valid markers: 28/28
# Frame 7611 valid markers: 28/28
# Frame 7621 valid markers: 28/28
# Frame 7631 valid markers: 28/28
# Frame 7641 valid markers: 28/28
# Frame 7651 valid markers: 28/28
# Frame 7661 valid markers: 28/28
# Frame 7671 valid markers: 28/28
# Frame 7681 valid markers: 28/28
# Frame 7691 valid markers: 28/28
# Frame 7701 valid markers: 28/28
# Frame 7711 valid markers: 28/28
# Frame 7721 valid markers: 28/28
# Frame 7731 valid markers: 28/28
# Frame 7741 valid markers: 28/28
# Frame 7751 valid markers: 28/28
# Frame 7761 valid markers: 28/28
# Frame 7771 valid markers: 28/28
# Frame 7781 valid markers: 28/28
# Frame 7791 valid markers: 28/28
# Frame 7801 valid markers: 28/28
# Frame 7811 valid markers: 28/28
# Frame 7821 valid markers: 28/28
# Frame 7831 valid markers: 28/28
# Frame 7841 valid markers: 28/28
# Frame 7851 valid markers: 28/28
# Frame 7861 valid markers: 28/28
# Frame 7871 valid markers: 28/28
# Frame 7881 valid markers: 28/28
# Frame 7891 valid markers: 28/28
# Frame 7901 valid markers: 28/28
# Frame 7911 valid markers: 28/28
# Frame 7921 valid markers: 28/28
# Frame 7931 valid markers: 28/28
# Frame 7941 valid markers: 28/28
# Frame 7951 valid markers: 28/28
# Frame 7961 valid markers: 28/28
# Frame 7971 valid markers: 28/28
# Frame 7981 valid markers: 28/28
# Frame 7991 valid markers: 28/28
# Frame 8001 valid markers: 28/28
# Frame 8011 valid markers: 28/28
# Frame 8021 valid markers: 28/28
# Frame 8031 valid markers: 28/28
# Saved frame 116/115
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka\beat_1\video_skeleton\front_view_28.7_33.5.mp4
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 31.111888888666662s - 35.851444444s: 11
# Total onsets: 1830
# Onsets in window 31.111888888666662s - 35.851444444s: 20
# Total onsets: 1830
# Onsets in window 31.111888888666662s - 35.851444444s: 15
#
# Creating animation...
# Animation will have 114 frames
# Time range: 31.11s - 35.82s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\drum_dot_merged\drum_dot_merged_31.11_35.85.mp4
# Animation saved successfully!
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\dance_dot\dance_31.11_35.85.mp4
# Animation saved successfully!
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# Position columns: ['Time', 'Hips.X', 'Hips.Y', 'Hips.Z', 'LeftHip.X', 'LeftHip.Y', 'LeftHip.Z', 'LeftKnee.X', 'LeftKnee.Y', 'LeftKnee.Z', 'LeftAnkle.X', 'LeftAnkle.Y', 'LeftAnkle.Z', 'LeftToe.X', 'LeftToe.Y', 'LeftToe.Z', 'LeftToeEnd.X', 'LeftToeEnd.Y', 'LeftToeEnd.Z', 'RightHip.X', 'RightHip.Y', 'RightHip.Z', 'RightKnee.X', 'RightKnee.Y', 'RightKnee.Z', 'RightAnkle.X', 'RightAnkle.Y', 'RightAnkle.Z', 'RightToe.X', 'RightToe.Y', 'RightToe.Z', 'RightToeEnd.X', 'RightToeEnd.Y', 'RightToeEnd.Z', 'Chest.X', 'Chest.Y', 'Chest.Z', 'Chest2.X', 'Chest2.Y', 'Chest2.Z', 'Chest3.X', 'Chest3.Y', 'Chest3.Z', 'Chest4.X', 'Chest4.Y', 'Chest4.Z', 'LeftCollar.X', 'LeftCollar.Y', 'LeftCollar.Z', 'LeftShoulder.X', 'LeftShoulder.Y', 'LeftShoulder.Z', 'LeftElbow.X', 'LeftElbow.Y', 'LeftElbow.Z', 'LeftWrist.X', 'LeftWrist.Y', 'LeftWrist.Z', 'LeftWristEnd.X', 'LeftWristEnd.Y', 'LeftWristEnd.Z', 'RightCollar.X', 'RightCollar.Y', 'RightCollar.Z', 'RightShoulder.X', 'RightShoulder.Y', 'RightShoulder.Z', 'RightElbow.X', 'RightElbow.Y', 'RightElbow.Z', 'RightWrist.X', 'RightWrist.Y', 'RightWrist.Z', 'RightWristEnd.X', 'RightWristEnd.Y', 'RightWristEnd.Z', 'Neck.X', 'Neck.Y', 'Neck.Z', 'Head.X', 'Head.Y', 'Head.Z', 'HeadEnd.X', 'HeadEnd.Y', 'HeadEnd.Z']
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
#
# Debug Information:
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
# T-pose positions: {'Hips': array([ 0.      , 89.062381,  0.      ]), 'LeftHip': array([7.78521200e+00, 8.90525861e+01, 3.31251140e-07]), 'LeftKnee': array([ 7.785212  , 48.30244939, -1.95830332]), 'LeftAnkle': array([ 7.785212  ,  8.66793811, -5.18636626]), 'LeftToe': array([ 7.785212  ,  1.63068611, 10.77240574]), 'LeftToeEnd': array([ 7.785212  ,  0.11709711, 17.35731374]), 'RightHip': array([-7.78521200e+00,  8.90547453e+01, -2.20896914e-07]), 'RightKnee': array([-7.785212  , 48.30449594, -1.95595682]), 'RightAnkle': array([-7.785212  ,  8.66793723, -5.1587819 ]), 'RightToe': array([-7.785212  ,  1.63068523, 10.7999901 ]), 'RightToeEnd': array([-7.785212  ,  0.11709623, 17.3848981 ]), 'Chest': array([ 0.00000000e+00,  9.86069642e+01, -6.81040802e-08]), 'Chest2': array([ 0.00000000e+00,  1.09133886e+02, -6.81040802e-08]), 'Chest3': array([  0.        , 118.69477667,  -0.97204375]), 'Chest4': array([  0.        , 128.24489067,  -1.9439801 ]), 'LeftCollar': array([  2.86465   , 135.75248167,  -1.9439801 ]), 'LeftShoulder': array([ 16.180918  , 135.75248167,  -1.9439801 ]), 'LeftElbow': array([ 44.484243  , 135.75248167,  -1.9439801 ]), 'LeftWrist': array([ 67.68105335, 135.75248167,  -1.00521599]), 'LeftWristEnd': array([ 85.05288935, 135.75248167,  -1.00521599]), 'RightCollar': array([ -2.86465   , 135.75248167,  -1.9439801 ]), 'RightShoulder': array([-16.180918  , 135.75248167,  -1.9439801 ]), 'RightElbow': array([-44.484243  , 135.75248167,  -1.9439801 ]), 'RightWrist': array([-67.68105335, 135.75248167,  -1.00521599]), 'RightWristEnd': array([-85.05288935, 135.75248167,  -1.00521599]), 'Neck': array([  0.        , 141.64188767,  -1.9439801 ]), 'Head': array([ 0.00000000e+00,  1.50363983e+02, -5.27447096e-04]), 'HeadEnd': array([  0.        , 166.97131676,   0.97534886])}
# Connections: [('Hips', 'Chest'), ('Chest', 'Chest2'), ('Chest2', 'Chest3'), ('Chest3', 'Chest4'), ('Chest4', 'Neck'), ('Neck', 'Head'), ('Chest4', 'RightCollar'), ('RightCollar', 'RightShoulder'), ('RightShoulder', 'RightElbow'), ('RightElbow', 'RightWrist'), ('Chest4', 'LeftCollar'), ('LeftCollar', 'LeftShoulder'), ('LeftShoulder', 'LeftElbow'), ('LeftElbow', 'LeftWrist'), ('Hips', 'RightHip'), ('RightHip', 'RightKnee'), ('RightKnee', 'RightAnkle'), ('RightAnkle', 'RightToe'), ('Hips', 'LeftHip'), ('LeftHip', 'LeftKnee'), ('LeftKnee', 'LeftAnkle'), ('LeftAnkle', 'LeftToe')]
#
# Video generation settings:
# Start time: 31.11s (frame 7466)
# End time: 35.85s (frame 8604)
# Output file: composite_videos\BKO_E1_D1_02_Maraka\beat_1\video_skeleton\front_view_31.1_35.9.mp4
# Output FPS: 24
# Video size: 1280x720
# Frame 7466 valid markers: 28/28
# Frame 7466 valid markers: 28/28
# Frame 7476 valid markers: 28/28
# Frame 7486 valid markers: 28/28
# Frame 7496 valid markers: 28/28
# Frame 7506 valid markers: 28/28
# Frame 7516 valid markers: 28/28
# Frame 7526 valid markers: 28/28
# Frame 7536 valid markers: 28/28
# Frame 7546 valid markers: 28/28
# Frame 7556 valid markers: 28/28
# Frame 7566 valid markers: 28/28
# Frame 7576 valid markers: 28/28
# Frame 7586 valid markers: 28/28
# Frame 7596 valid markers: 28/28
# Frame 7606 valid markers: 28/28
# Frame 7616 valid markers: 28/28
# Frame 7626 valid markers: 28/28
# Frame 7636 valid markers: 28/28
# Frame 7646 valid markers: 28/28
# Frame 7656 valid markers: 28/28
# Frame 7666 valid markers: 28/28
# Frame 7676 valid markers: 28/28
# Frame 7686 valid markers: 28/28
# Frame 7696 valid markers: 28/28
# Frame 7706 valid markers: 28/28
# Frame 7716 valid markers: 28/28
# Frame 7726 valid markers: 28/28
# Frame 7736 valid markers: 28/28
# Frame 7746 valid markers: 28/28
# Frame 7756 valid markers: 28/28
# Frame 7766 valid markers: 28/28
# Frame 7776 valid markers: 28/28
# Frame 7786 valid markers: 28/28
# Frame 7796 valid markers: 28/28
# Frame 7806 valid markers: 28/28
# Frame 7816 valid markers: 28/28
# Frame 7826 valid markers: 28/28
# Frame 7836 valid markers: 28/28
# Frame 7846 valid markers: 28/28
# Frame 7856 valid markers: 28/28
# Frame 7866 valid markers: 28/28
# Frame 7876 valid markers: 28/28
# Frame 7886 valid markers: 28/28
# Frame 7896 valid markers: 28/28
# Frame 7906 valid markers: 28/28
# Frame 7916 valid markers: 28/28
# Frame 7926 valid markers: 28/28
# Frame 7936 valid markers: 28/28
# Frame 7946 valid markers: 28/28
# Frame 7956 valid markers: 28/28
# Frame 7966 valid markers: 28/28
# Frame 7976 valid markers: 28/28
# Frame 7986 valid markers: 28/28
# Frame 7996 valid markers: 28/28
# Frame 8006 valid markers: 28/28
# Frame 8016 valid markers: 28/28
# Frame 8026 valid markers: 28/28
# Frame 8036 valid markers: 28/28
# Frame 8046 valid markers: 28/28
# Frame 8056 valid markers: 28/28
# Frame 8066 valid markers: 28/28
# Frame 8076 valid markers: 28/28
# Frame 8086 valid markers: 28/28
# Frame 8096 valid markers: 28/28
# Frame 8106 valid markers: 28/28
# Frame 8116 valid markers: 28/28
# Frame 8126 valid markers: 28/28
# Frame 8136 valid markers: 28/28
# Frame 8146 valid markers: 28/28
# Frame 8156 valid markers: 28/28
# Frame 8166 valid markers: 28/28
# Frame 8176 valid markers: 28/28
# Frame 8186 valid markers: 28/28
# Frame 8196 valid markers: 28/28
# Frame 8206 valid markers: 28/28
# Frame 8216 valid markers: 28/28
# Frame 8226 valid markers: 28/28
# Frame 8236 valid markers: 28/28
# Frame 8246 valid markers: 28/28
# Frame 8256 valid markers: 28/28
# Frame 8266 valid markers: 28/28
# Frame 8276 valid markers: 28/28
# Frame 8286 valid markers: 28/28
# Frame 8296 valid markers: 28/28
# Frame 8306 valid markers: 28/28
# Frame 8316 valid markers: 28/28
# Frame 8326 valid markers: 28/28
# Frame 8336 valid markers: 28/28
# Frame 8346 valid markers: 28/28
# Frame 8356 valid markers: 28/28
# Frame 8366 valid markers: 28/28
# Frame 8376 valid markers: 28/28
# Frame 8386 valid markers: 28/28
# Frame 8396 valid markers: 28/28
# Frame 8406 valid markers: 28/28
# Frame 8416 valid markers: 28/28
# Frame 8426 valid markers: 28/28
# Frame 8436 valid markers: 28/28
# Frame 8446 valid markers: 28/28
# Frame 8456 valid markers: 28/28
# Frame 8466 valid markers: 28/28
# Frame 8476 valid markers: 28/28
# Frame 8486 valid markers: 28/28
# Frame 8496 valid markers: 28/28
# Frame 8506 valid markers: 28/28
# Frame 8516 valid markers: 28/28
# Frame 8526 valid markers: 28/28
# Frame 8536 valid markers: 28/28
# Frame 8546 valid markers: 28/28
# Frame 8556 valid markers: 28/28
# Frame 8566 valid markers: 28/28
# Frame 8576 valid markers: 28/28
# Frame 8586 valid markers: 28/28
# Frame 8596 valid markers: 28/28
# Saved frame 114/113
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka\beat_1\video_skeleton\front_view_31.1_35.9.mp4
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 33.510111110333334s - 38.19277777766667s: 12
# Total onsets: 1830
# Onsets in window 33.510111110333334s - 38.19277777766667s: 20
# Total onsets: 1830
# Onsets in window 33.510111110333334s - 38.19277777766667s: 15
#
# Creating animation...
# Animation will have 113 frames
# Time range: 33.51s - 38.18s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\drum_dot_merged\drum_dot_merged_33.51_38.19.mp4
# Animation saved successfully!
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\dance_dot\dance_33.51_38.19.mp4
# Animation saved successfully!
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# Position columns: ['Time', 'Hips.X', 'Hips.Y', 'Hips.Z', 'LeftHip.X', 'LeftHip.Y', 'LeftHip.Z', 'LeftKnee.X', 'LeftKnee.Y', 'LeftKnee.Z', 'LeftAnkle.X', 'LeftAnkle.Y', 'LeftAnkle.Z', 'LeftToe.X', 'LeftToe.Y', 'LeftToe.Z', 'LeftToeEnd.X', 'LeftToeEnd.Y', 'LeftToeEnd.Z', 'RightHip.X', 'RightHip.Y', 'RightHip.Z', 'RightKnee.X', 'RightKnee.Y', 'RightKnee.Z', 'RightAnkle.X', 'RightAnkle.Y', 'RightAnkle.Z', 'RightToe.X', 'RightToe.Y', 'RightToe.Z', 'RightToeEnd.X', 'RightToeEnd.Y', 'RightToeEnd.Z', 'Chest.X', 'Chest.Y', 'Chest.Z', 'Chest2.X', 'Chest2.Y', 'Chest2.Z', 'Chest3.X', 'Chest3.Y', 'Chest3.Z', 'Chest4.X', 'Chest4.Y', 'Chest4.Z', 'LeftCollar.X', 'LeftCollar.Y', 'LeftCollar.Z', 'LeftShoulder.X', 'LeftShoulder.Y', 'LeftShoulder.Z', 'LeftElbow.X', 'LeftElbow.Y', 'LeftElbow.Z', 'LeftWrist.X', 'LeftWrist.Y', 'LeftWrist.Z', 'LeftWristEnd.X', 'LeftWristEnd.Y', 'LeftWristEnd.Z', 'RightCollar.X', 'RightCollar.Y', 'RightCollar.Z', 'RightShoulder.X', 'RightShoulder.Y', 'RightShoulder.Z', 'RightElbow.X', 'RightElbow.Y', 'RightElbow.Z', 'RightWrist.X', 'RightWrist.Y', 'RightWrist.Z', 'RightWristEnd.X', 'RightWristEnd.Y', 'RightWristEnd.Z', 'Neck.X', 'Neck.Y', 'Neck.Z', 'Head.X', 'Head.Y', 'Head.Z', 'HeadEnd.X', 'HeadEnd.Y', 'HeadEnd.Z']
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
#
# Debug Information:
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
# T-pose positions: {'Hips': array([ 0.      , 89.062381,  0.      ]), 'LeftHip': array([7.78521200e+00, 8.90525861e+01, 3.31251140e-07]), 'LeftKnee': array([ 7.785212  , 48.30244939, -1.95830332]), 'LeftAnkle': array([ 7.785212  ,  8.66793811, -5.18636626]), 'LeftToe': array([ 7.785212  ,  1.63068611, 10.77240574]), 'LeftToeEnd': array([ 7.785212  ,  0.11709711, 17.35731374]), 'RightHip': array([-7.78521200e+00,  8.90547453e+01, -2.20896914e-07]), 'RightKnee': array([-7.785212  , 48.30449594, -1.95595682]), 'RightAnkle': array([-7.785212  ,  8.66793723, -5.1587819 ]), 'RightToe': array([-7.785212  ,  1.63068523, 10.7999901 ]), 'RightToeEnd': array([-7.785212  ,  0.11709623, 17.3848981 ]), 'Chest': array([ 0.00000000e+00,  9.86069642e+01, -6.81040802e-08]), 'Chest2': array([ 0.00000000e+00,  1.09133886e+02, -6.81040802e-08]), 'Chest3': array([  0.        , 118.69477667,  -0.97204375]), 'Chest4': array([  0.        , 128.24489067,  -1.9439801 ]), 'LeftCollar': array([  2.86465   , 135.75248167,  -1.9439801 ]), 'LeftShoulder': array([ 16.180918  , 135.75248167,  -1.9439801 ]), 'LeftElbow': array([ 44.484243  , 135.75248167,  -1.9439801 ]), 'LeftWrist': array([ 67.68105335, 135.75248167,  -1.00521599]), 'LeftWristEnd': array([ 85.05288935, 135.75248167,  -1.00521599]), 'RightCollar': array([ -2.86465   , 135.75248167,  -1.9439801 ]), 'RightShoulder': array([-16.180918  , 135.75248167,  -1.9439801 ]), 'RightElbow': array([-44.484243  , 135.75248167,  -1.9439801 ]), 'RightWrist': array([-67.68105335, 135.75248167,  -1.00521599]), 'RightWristEnd': array([-85.05288935, 135.75248167,  -1.00521599]), 'Neck': array([  0.        , 141.64188767,  -1.9439801 ]), 'Head': array([ 0.00000000e+00,  1.50363983e+02, -5.27447096e-04]), 'HeadEnd': array([  0.        , 166.97131676,   0.97534886])}
# Connections: [('Hips', 'Chest'), ('Chest', 'Chest2'), ('Chest2', 'Chest3'), ('Chest3', 'Chest4'), ('Chest4', 'Neck'), ('Neck', 'Head'), ('Chest4', 'RightCollar'), ('RightCollar', 'RightShoulder'), ('RightShoulder', 'RightElbow'), ('RightElbow', 'RightWrist'), ('Chest4', 'LeftCollar'), ('LeftCollar', 'LeftShoulder'), ('LeftShoulder', 'LeftElbow'), ('LeftElbow', 'LeftWrist'), ('Hips', 'RightHip'), ('RightHip', 'RightKnee'), ('RightKnee', 'RightAnkle'), ('RightAnkle', 'RightToe'), ('Hips', 'LeftHip'), ('LeftHip', 'LeftKnee'), ('LeftKnee', 'LeftAnkle'), ('LeftAnkle', 'LeftToe')]
#
# Video generation settings:
# Start time: 33.51s (frame 8042)
# End time: 38.19s (frame 9166)
# Output file: composite_videos\BKO_E1_D1_02_Maraka\beat_1\video_skeleton\front_view_33.5_38.2.mp4
# Output FPS: 24
# Video size: 1280x720
# Frame 8042 valid markers: 28/28
# Frame 8042 valid markers: 28/28
# Frame 8052 valid markers: 28/28
# Frame 8062 valid markers: 28/28
# Frame 8072 valid markers: 28/28
# Frame 8082 valid markers: 28/28
# Frame 8092 valid markers: 28/28
# Frame 8102 valid markers: 28/28
# Frame 8112 valid markers: 28/28
# Frame 8122 valid markers: 28/28
# Frame 8132 valid markers: 28/28
# Frame 8142 valid markers: 28/28
# Frame 8152 valid markers: 28/28
# Frame 8162 valid markers: 28/28
# Frame 8172 valid markers: 28/28
# Frame 8182 valid markers: 28/28
# Frame 8192 valid markers: 28/28
# Frame 8202 valid markers: 28/28
# Frame 8212 valid markers: 28/28
# Frame 8222 valid markers: 28/28
# Frame 8232 valid markers: 28/28
# Frame 8242 valid markers: 28/28
# Frame 8252 valid markers: 28/28
# Frame 8262 valid markers: 28/28
# Frame 8272 valid markers: 28/28
# Frame 8282 valid markers: 28/28
# Frame 8292 valid markers: 28/28
# Frame 8302 valid markers: 28/28
# Frame 8312 valid markers: 28/28
# Frame 8322 valid markers: 28/28
# Frame 8332 valid markers: 28/28
# Frame 8342 valid markers: 28/28
# Frame 8352 valid markers: 28/28
# Frame 8362 valid markers: 28/28
# Frame 8372 valid markers: 28/28
# Frame 8382 valid markers: 28/28
# Frame 8392 valid markers: 28/28
# Frame 8402 valid markers: 28/28
# Frame 8412 valid markers: 28/28
# Frame 8422 valid markers: 28/28
# Frame 8432 valid markers: 28/28
# Frame 8442 valid markers: 28/28
# Frame 8452 valid markers: 28/28
# Frame 8462 valid markers: 28/28
# Frame 8472 valid markers: 28/28
# Frame 8482 valid markers: 28/28
# Frame 8492 valid markers: 28/28
# Frame 8502 valid markers: 28/28
# Frame 8512 valid markers: 28/28
# Frame 8522 valid markers: 28/28
# Frame 8532 valid markers: 28/28
# Frame 8542 valid markers: 28/28
# Frame 8552 valid markers: 28/28
# Frame 8562 valid markers: 28/28
# Frame 8572 valid markers: 28/28
# Frame 8582 valid markers: 28/28
# Frame 8592 valid markers: 28/28
# Frame 8602 valid markers: 28/28
# Frame 8612 valid markers: 28/28
# Frame 8622 valid markers: 28/28
# Frame 8632 valid markers: 28/28
# Frame 8642 valid markers: 28/28
# Frame 8652 valid markers: 28/28
# Frame 8662 valid markers: 28/28
# Frame 8672 valid markers: 28/28
# Frame 8682 valid markers: 28/28
# Frame 8692 valid markers: 28/28
# Frame 8702 valid markers: 28/28
# Frame 8712 valid markers: 28/28
# Frame 8722 valid markers: 28/28
# Frame 8732 valid markers: 28/28
# Frame 8742 valid markers: 28/28
# Frame 8752 valid markers: 28/28
# Frame 8762 valid markers: 28/28
# Frame 8772 valid markers: 28/28
# Frame 8782 valid markers: 28/28
# Frame 8792 valid markers: 28/28
# Frame 8802 valid markers: 28/28
# Frame 8812 valid markers: 28/28
# Frame 8822 valid markers: 28/28
# Frame 8832 valid markers: 28/28
# Frame 8842 valid markers: 28/28
# Frame 8852 valid markers: 28/28
# Frame 8862 valid markers: 28/28
# Frame 8872 valid markers: 28/28
# Frame 8882 valid markers: 28/28
# Frame 8892 valid markers: 28/28
# Frame 8902 valid markers: 28/28
# Frame 8912 valid markers: 28/28
# Frame 8922 valid markers: 28/28
# Frame 8932 valid markers: 28/28
# Frame 8942 valid markers: 28/28
# Frame 8952 valid markers: 28/28
# Frame 8962 valid markers: 28/28
# Frame 8972 valid markers: 28/28
# Frame 8982 valid markers: 28/28
# Frame 8992 valid markers: 28/28
# Frame 9002 valid markers: 28/28
# Frame 9012 valid markers: 28/28
# Frame 9022 valid markers: 28/28
# Frame 9032 valid markers: 28/28
# Frame 9042 valid markers: 28/28
# Frame 9052 valid markers: 28/28
# Frame 9062 valid markers: 28/28
# Frame 9072 valid markers: 28/28
# Frame 9082 valid markers: 28/28
# Frame 9092 valid markers: 28/28
# Frame 9102 valid markers: 28/28
# Frame 9112 valid markers: 28/28
# Frame 9122 valid markers: 28/28
# Frame 9132 valid markers: 28/28
# Frame 9142 valid markers: 28/28
# Frame 9152 valid markers: 28/28
# Frame 9162 valid markers: 28/28
# Saved frame 113/112
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka\beat_1\video_skeleton\front_view_33.5_38.2.mp4

# %% [markdown]
# ### Generate animated kinematic plots

# %%
# Generate animated kinematic plots: x axis in seconds
# joint_name = "Hips"  
# axis = 'y'      # y is vertical in bvh files

# output_dir2 = os.path.join("composite_videos", file_name, w_key, joint_name)
# os.makedirs(output_dir2, exist_ok=True)


# for start_time, end_time, _ in traj_tuples:
#     print(start_time, end_time)

#     visualize_joint_position(
#         bvh_file=bvh_file + ".bvh",
#         joint_name= joint_name,
#         axis= axis,
#         start_time= start_time,
#         end_time= end_time,
#         output_fps= 24,
#         output_dir= output_dir2,
#         fig_size= (12, 4),  # Half height for joint visualization
#         dpi= 200
#     )

# %%
def extract_cycle_plots(
    file_name: str,
    windows: list,  # List of (win_start, win_end, t_poi) tuples
    window_key: str,
    joint_name: str,
    axis: str = 'y',
    base_path_logs: str = "data/logs_v2_may",
    frame_rate: float = 240,  # Trajectory data frame rate
    n_beats_per_cycle: int = 4,
    n_subdiv_per_beat: int = 3,
    nn: int = 3,
    output_dir2: str = None,
    figsize: tuple = (10, 3),
    dpi: int = 200
):
    """
    Create trajectory animations for windows around points of interest (beats or subdivisions).
    Each plot shows [-cycle, 0-cycle, +cycle] around the POI.
    """
    # Create save directory if not provided
    if output_dir2 is None:
        
        output_dir2 = os.path.join("cycle_plots", file_name, window_key, joint_name)
    os.makedirs(output_dir2, exist_ok=True)
    
    # Load joint position data
    dir_csv = "extracted_mocap_csv"
    base_name = os.path.splitext(os.path.basename(file_name))[0]
    worldpos_file = os.path.join(dir_csv, f"{base_name}_T_worldpos.csv")
    
    try:
        world_positions = pd.read_csv(worldpos_file)
        print(f"Successfully loaded CSV with {len(world_positions)} rows")
    except Exception as e:
        print(f"Error loading CSV file: {e}")
        raise
    
    # Get time column and position data
    time_column = world_positions.columns[0]  # First column is time
    times = world_positions[time_column].values
    positions = world_positions[f"{joint_name}.{axis.upper()}"].values
    
    print(f"\nProcessing {len(windows)} windows")
    # print(f"Total frames in trajectory data: {len(times)}")
    # print(f"Time range in trajectory data: {times[0]:.3f} to {times[-1]:.3f}")
    
    # Process each window
    for i, (win_start, win_end, t_poi) in enumerate(windows):
        print(f"\nProcessing window {i+1}:")
        print(f"  Window time range: {win_start:.3f} to {win_end:.3f}")
        
        # Calculate segment times
        start_time = win_start
        end_time = win_end
        duration = end_time - start_time
        downbeat = t_poi  # This is the point of interest (beat or subdivision)
        
        # Calculate avg_cycle from the window duration
        avg_cycle = duration / 2  # Since window is ±1 cycle
        
        # Calculate window parameters
        beat_len = avg_cycle / n_beats_per_cycle
        subdiv_len = beat_len / n_subdiv_per_beat
        half_win = subdiv_len * nn
        
        # Calculate frame numbers for trajectory (240fps)
        traj_start_frame = int(start_time * frame_rate)
        traj_end_frame = int(end_time * frame_rate)
        traj_n_frames = traj_end_frame - traj_start_frame
        
        print(f"  Trajectory frames: {traj_start_frame} to {traj_end_frame} (240fps)")
        
        # Check if we have valid frame numbers
        if traj_start_frame >= traj_end_frame:
            print(f"  Skipping window {i+1}: Invalid frame range (start >= end)")
            continue
        if traj_start_frame < 0:
            print(f"  Skipping window {i+1}: Start frame < 0")
            continue
        if traj_end_frame > len(positions):
            print(f"  Skipping window {i+1}: End frame > total frames")
            continue
        
        # Trim trajectory data using frame numbers at 240fps
        pos_win = positions[traj_start_frame:traj_end_frame]
        t_win = times[traj_start_frame:traj_end_frame]
        
        # Check if we have valid trajectory data
        if len(pos_win) == 0:
            print(f"  Skipping window {i+1}: No trajectory data")
            continue
        
        print(f"  Trajectory data points: {len(pos_win)}")
        
        # Create figure and axis
        fig, ax = plt.subplots(figsize=figsize, dpi=dpi)
        fig.tight_layout(pad=2.0) 
        
        # Calculate all subdivision times for the window
        all_subdiv_times = []
        for beat_idx in range(-n_beats_per_cycle, n_beats_per_cycle + 1):
            beat_time = downbeat + beat_idx * beat_len
            for subdiv_idx in range(n_subdiv_per_beat):
                subdiv_time = beat_time + subdiv_idx * subdiv_len
                if start_time <= subdiv_time <= end_time:
                    all_subdiv_times.append((subdiv_time, beat_idx * n_subdiv_per_beat + subdiv_idx + 1))

        # Plot subdivision lines with appropriate colors
        for subdiv_time, subdiv_num in all_subdiv_times:
            color = get_subdiv_color(subdiv_num)
            # Add yellow glow effect for t=0
            if abs(subdiv_time - downbeat) < 0.001:  # If it's the POI
                ax.axvline(subdiv_time, color='yellow', linestyle='-', linewidth=3, alpha=0.3)
            # ax.axvline(subdiv_time, color=color, linestyle='-', linewidth=2, alpha=0.7)
            
            if subdiv_num in [-11, -8, -5, -2, 1, 4, 7, 10]:
                ax.axvline(subdiv_time, color=color, linestyle='-', linewidth=2, alpha=0.7) #beat color
            else:
                ax.axvline(subdiv_time, color=color, linestyle='--', linewidth=1, alpha=0.3) #subdivision color
        
        # Plot trajectory
        ax.plot(t_win, pos_win, '-', color='green', alpha=0.5, label=f'{joint_name} {axis.upper()}')
        
        ax.axvline(downbeat, color='yellow', linewidth=6, alpha=0.3, zorder=0)  # Glow effect
        
        # Set y-axis limits with safety checks
        try:
            y_min = pos_win.min()
            y_max = pos_win.max()
            y_range = y_max - y_min
            ax.set_ylim(y_min - 0.1*y_range, y_max + 0.1*y_range)
        except ValueError as e:
            print(f"  Warning: Could not set y-axis limits: {e}")
            # Set default y-axis limits
            ax.set_ylim(-1, 1)
        
        # Create vertical playhead
        v_playhead, = ax.plot([start_time, start_time], 
                            [y_min - 0.1*y_range, y_max + 0.1*y_range],
                            lw=1, alpha=0.9, color='orange')
        
        # Set up the plot with scaled x-axis
        ax.set_xlabel(f'Beats relative to {window_key}')
        ax.set_ylabel(f'{joint_name} Z Position')      # {axis.upper()} y is vertical in bvh files, Z is vertical in mocap
        ax.set_title(f'Window {i+1} | {window_key}: {downbeat:.2f}s')
        ax.grid(True, alpha=0.3)
        
        # Scale x-axis to show beats instead of cycles
        x_ticks = np.arange(-n_beats_per_cycle, n_beats_per_cycle + 1)
        x_tick_positions = downbeat + x_ticks * beat_len
        ax.set_xticks(x_tick_positions)
        ax.set_xticklabels(x_ticks)
        
        # Add legend
        custom = [
            Line2D([0],[0], color='blue', lw=1),
            Line2D([0],[0], color='black', lw=1),
            Line2D([0],[0], color='green', lw=1),
            Line2D([0],[0], color='red', lw=1),
        ]
        labels = [
            f"{joint_name} {axis.upper()}", 
            "Subdiv-1 (1,4,7,10)", 
            "Subdiv-2 (2,5,8,11)", 
            "Subdiv-3 (3,6,9,12)"
        ]
        ax.legend(custom, labels, loc='upper left', framealpha=0.3, fontsize=6)
        
        def update(frame):
            v_playhead.set_xdata([frame, frame])
            ax.set_title(f'Cycle {i+1} | {window_key}: {downbeat:.2f}s | Time: {frame:.2f}s')
            return v_playhead,
        
        # Create animation frames at 24fps
        n_frames = int(duration * 24)
        frames = np.linspace(start_time, end_time, n_frames)
        anim = animation.FuncAnimation(
            fig, update, frames=frames,
            interval=1000/24,  # 24fps
            blit=True
        )
        
        # Save animation
        plot_output_path = os.path.join(output_dir2, f"{file_name}_window_{i+1:03d}_{start_time:.2f}_{end_time:.2f}.mp4")
        writer = animation.FFMpegWriter(fps= 24, 
                                        bitrate=2000,
                                        codec='libx264',  # Specify codec
                                        # extra_args=['-preset', 'ultrafast']
                                        )  # 24fps
        anim.save(plot_output_path, writer=writer)
        plt.close(fig)
        
        print(f"  Plot saved: {plot_output_path}")
        print(f"  Plot duration: {len(frames)/24:.3f}s")
    
    print("\nProcessing complete!")

# %%
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 
# 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 
# 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 
# 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 
# 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']

joint_name = "Hips"  
axis = 'y'      # y is vertical in bvh files

output_dir2 = os.path.join("composite_videos", file_name, w_key, joint_name)
os.makedirs(output_dir2, exist_ok=True)

extract_cycle_plots(
file_name= file_name,
windows= traj_tuples,
window_key= w_key,
joint_name= joint_name,
axis="y",
output_dir2= output_dir2,
figsize = (10, 3),  # 2000 x 600 px
dpi= 200,
)
# Out:
# Successfully loaded CSV with 81793 rows
#
# Processing 6 windows
#
# Processing window 1:
#   Window time range: 21.306 to 26.175
#   Trajectory frames: 5113 to 6281 (240fps)
#   Trajectory data points: 1168
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\Hips\BKO_E1_D1_02_Maraka_window_001_21.31_26.17.mp4
#   Plot duration: 4.833s
#
# Processing window 2:
#   Window time range: 23.686 to 28.664
#   Trajectory frames: 5684 to 6879 (240fps)
#   Trajectory data points: 1195
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\Hips\BKO_E1_D1_02_Maraka_window_002_23.69_28.66.mp4
#   Plot duration: 4.958s
#
# Processing window 3:
#   Window time range: 26.251 to 31.076
#   Trajectory frames: 6300 to 7458 (240fps)
#   Trajectory data points: 1158
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\Hips\BKO_E1_D1_02_Maraka_window_003_26.25_31.08.mp4
#   Plot duration: 4.792s
#
# Processing window 4:
#   Window time range: 28.671 to 33.482
#   Trajectory frames: 6881 to 8035 (240fps)
#   Trajectory data points: 1154
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\Hips\BKO_E1_D1_02_Maraka_window_004_28.67_33.48.mp4
#   Plot duration: 4.792s
#
# Processing window 5:
#   Window time range: 31.112 to 35.851
#   Trajectory frames: 7466 to 8604 (240fps)
#   Trajectory data points: 1138
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\Hips\BKO_E1_D1_02_Maraka_window_005_31.11_35.85.mp4
#   Plot duration: 4.708s
#
# Processing window 6:
#   Window time range: 33.510 to 38.193
#   Trajectory frames: 8042 to 9166 (240fps)
#   Trajectory data points: 1124
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka\beat_1\Hips\BKO_E1_D1_02_Maraka_window_006_33.51_38.19.mp4
#   Plot duration: 4.667s
#
# Processing complete!

# %% [markdown]
# ### Generate merged distribution video plot (DunDun, J1, J2)

# %% [markdown]
# ### Prepare for concatenation

# %%
def extract_category(filename):
    """
    Given a filename like "front_view_56.7_61.2.mp4" or
    "BKO_E1_D1_02_Maraka_pre_R_Mix_trimmed_56.7_61.2.mp4",
    return the category portion before the last two underscore-separated tokens.
    """
    name, _ = os.path.splitext(filename)     # strip .mp4
    parts = name.split('_')
    # Last two parts are start and end times, so category is everything before them
    if len(parts) > 2:
        return "_".join(parts[:-2])
    return name   # fallback if unexpected format

def write_all_categories(files, output_dir, video_dir):
    """
    From a list of filenames, group by category (as defined by extract_category),
    and write each group into its own .txt file in output_dir.
    """
    # os.makedirs(output_dir, exist_ok=True)

    # Group filenames by category
    categories = {}
    for fname in files:
        cat = extract_category(fname)
        categories.setdefault(cat, []).append(fname)

    # Write each category's filenames to a separate text file
    for cat, fnames in categories.items():
        txt_path = os.path.join(output_dir, f"{cat}.txt")
        with open(txt_path, "w") as fw:
            for f in fnames:
                if video_dir:
                    rel_path = os.path.relpath(os.path.join(video_dir, f), os.path.dirname(txt_path))
                    fw.write(f"file '{rel_path}'\n")
                else:
                    fw.write(f + "\n")  
                

def create_concat_file(video_dir, output_file, prefix):
    """Create a text file listing all videos in order for concatenation"""
    with open(output_file, 'w') as f:
        # Get all video files and sort them
        video_files = sorted([f for f in os.listdir(video_dir) if f.endswith('.mp4')])
        # Write each file path - use relative path from the text file location
        for video in video_files:
            # Get relative path from output_file to video_dir
            rel_path = os.path.relpath(os.path.join(video_dir, video), os.path.dirname(output_file))
            f.write(f"file '{rel_path}'\n") 
            
def concatenate_and_overlay_videos(file_name, joint_name,  save_dir):
    """Concatenate cycle videos and plot videos, then overlay them"""
    video_dir = os.path.join(save_dir, "videos")
    plot_dir = os.path.join(save_dir, "plots")
    joint_dir = os.path.join(save_dir, joint_name)
    vid_skel_dir = os.path.join(save_dir, "video_skeleton")
    drum_dot_dir = os.path.join(save_dir, "drum_dot_merged")
    dance_dot_dir = os.path.join(save_dir, "dance_dot")

    # Create text files for concatenation
    video_list = os.path.join(save_dir, "video_list.txt")
    plot_list = os.path.join(save_dir, "plot_list.txt")
    joint_list = os.path.join(save_dir, "joint_list.txt")
    
    drum_dot_list = os.path.join(save_dir, "drum_dot_list.txt")
    dance_dot_list = os.path.join(save_dir, "dance_dot_list.txt")
    
    front_view_list = os.path.join(save_dir, "front_view.txt")
    # left_view_list = os.path.join(save_dir, "left_view.txt")
    # right_view_list = os.path.join(save_dir, "right_view.txt")
    # top_view_list = os.path.join(save_dir, "top_view.txt")
    
    
    mp4_file_list = [f for f in os.listdir(vid_skel_dir) if f.lower().endswith(".mp4")]
    write_all_categories(mp4_file_list, save_dir, video_dir = vid_skel_dir)
    
    
    # Check if directories exist
    if not os.path.exists(video_dir):
        print(f"Video directory not found: {video_dir}")
        return
    if not os.path.exists(plot_dir):
        print(f"Plot directory not found: {plot_dir}")
        return
        
    # Check if text files already exist
    if os.path.exists(video_list) and os.path.exists(plot_list):
        print("Concatenation files already exist, skipping creation")
    else:
        print("Creating concatenation files...")
        create_concat_file(video_dir, video_list, f"{file_name}_cycle_")
        create_concat_file(plot_dir, plot_list, f"{file_name}_cycle_")
        create_concat_file(joint_dir, joint_list, f"{file_name}_cycle_")
        create_concat_file(drum_dot_dir, drum_dot_list, f"{file_name}_cycle_")
        create_concat_file(dance_dot_dir, dance_dot_list, f"{file_name}_cycle_")
    
    def concatenate_videos(video_list, save_dir, save_name):
        
        concat_video = os.path.join(save_dir, f"{save_name}.mp4")
        try:
            result = subprocess.run([
                'ffmpeg', '-y',
                '-f', 'concat',
                '-safe', '0',
                '-i', video_list,
                '-c', 'copy',
                concat_video
            ], capture_output=True, text=True)
            if result.returncode != 0:
                print("Error concatenating videos:", result.stderr)
                return
        except Exception as e:
            print("Error running ffmpeg:", str(e))
            return
    
    concatenate_videos(video_list, save_dir, f"video_mix_concat")
    concatenate_videos(plot_list, save_dir, f"plot_concat")
    concatenate_videos(joint_list, save_dir, f"joint_{joint_name}_concat")
    
    concatenate_videos(drum_dot_list, save_dir, f"drum_dot_concat")
    concatenate_videos(dance_dot_list, save_dir, f"dance_dot_concat")
    
    concatenate_videos(front_view_list, save_dir, f"front_view_concat")
    # concatenate_videos(left_view_list, save_dir, f"left_view_concat")
    # concatenate_videos(right_view_list, save_dir, f"right_view_concat")
    # concatenate_videos(top_view_list, save_dir, f"top_view_concat") 

    
    # print(f"Concatenated plot saved: {concat_plot}")
    # print(f"Concatenated video saved: {concat_video}\n")

# %%
# joint_name = "Hips"

vid_plot_path = os.path.join("composite_videos", file_name, w_key)

concatenate_and_overlay_videos(file_name, joint_name, vid_plot_path)        # modify
# Out:
# Creating concatenation files...

# %% [markdown]
# ### Generate Composite Video

# %%
# file_name = "BKO_E1_D1_02_Maraka"
# w_key = "beat_1"
# vid_plot_path = os.path.join("composite_videos", file_name, w_key)

concat_file_list = [f for f in os.listdir(vid_plot_path) if f.lower().endswith(".mp4")]
concat_dict = {
    f.replace('_concat.mp4', ''): os.path.join(vid_plot_path, f) 
    for f in concat_file_list
}

concat_dict
# Out:
# {'dance_dot': 'composite_videos\\BKO_E1_D1_02_Maraka\\beat_1\\dance_dot_concat.mp4',
#  'drum_dot': 'composite_videos\\BKO_E1_D1_02_Maraka\\beat_1\\drum_dot_concat.mp4',
#  'final_output_1.mp4': 'composite_videos\\BKO_E1_D1_02_Maraka\\beat_1\\final_output_1.mp4',
#  'front_view': 'composite_videos\\BKO_E1_D1_02_Maraka\\beat_1\\front_view_concat.mp4',
#  'joint_Hips': 'composite_videos\\BKO_E1_D1_02_Maraka\\beat_1\\joint_Hips_concat.mp4',
#  'plot': 'composite_videos\\BKO_E1_D1_02_Maraka\\beat_1\\plot_concat.mp4',
#  'video_mix': 'composite_videos\\BKO_E1_D1_02_Maraka\\beat_1\\video_mix_concat.mp4'}

# %% [markdown]
# ### test

# %%
import os
import subprocess

def resize_video(video_path, width, height, save_dir):
    """
    Resize a video to the specified width and height using ffmpeg,
    with debug‐level output.

    Parameters:
    - video_path: str, path to the input video file
    - width: int, target width in pixels
    - height: int, target height in pixels
    - save_dir: str, directory where the resized video will be saved

    The output filename will be: <original_basename>_<width>x<height>.mp4
    """
    # Ensure the save directory exists
    os.makedirs(save_dir, exist_ok=True)

    # Derive output filename from input basename
    base_name = os.path.splitext(os.path.basename(video_path))[0]
    output_filename = f"{base_name}.mp4"   # f"{base_name}_{width}x{height}.mp4"
    output_path = os.path.join(save_dir, output_filename)

    # Build ffmpeg command with debug-level logging
    cmd = [
        "ffmpeg",
        "-y",                   # overwrite output if it exists
        "-loglevel", "debug",   # show full debug output
        "-i", video_path,
        "-vf", f"scale={width}:{height}",
        "-c:v", "libx264",
        "-crf", "18",
        "-preset", "slow",
        output_path
    ]

    # Run ffmpeg and capture stdout/stderr
    result = subprocess.run(cmd, capture_output=True, text=True)

    # Print debug output
    # print("=== ffmpeg stdout ===")
    # print(result.stdout)
    # print("=== ffmpeg stderr ===")
    # print(result.stderr)

    # Check return code and report
    if result.returncode == 0:
        print(f"Resizing succeeded, output saved to: {output_path}")
    else:
        print(f"ffmpeg failed with return code {result.returncode}")

    return output_path if result.returncode == 0 else None

# %%
view_videos = {
    'video_mix': concat_dict['video_mix'],  
    'plot': concat_dict['plot'],    
    'front_view': concat_dict['front_view'],
    'joint_Hips': concat_dict['joint_Hips'],
    'drum_dot': concat_dict['drum_dot'],
    'dance_dot': concat_dict['dance_dot'],
    
    # 'left_view': concat_dict['left_view'],
    # 'right_view': concat_dict['right_view'],
    # 'top_view': concat_dict['top_view'],
}

canvas_w, canvas_h = 1920, 1080 
composite_layout_1 = [
    # Top row - side by side
    {'view': 'video_mix', 'x': 0, 'y': 0, 'width': 960, 'height': 540},
    {'view': 'front_view', 'x': 960, 'y': 0, 'width': 960, 'height': 540},
    
    # Bottom row - stacked vertically
    {'view': 'joint_Hips', 'x': 0, 'y': 540, 'width': 1920, 'height': 270},
    {'view': 'plot', 'x': 0, 'y': 810, 'width': 1920, 'height': 270},
]

composite_layout_2 = [
    # Top row - side by side
    {'view': 'video_mix', 'x': 0, 'y': 0, 'width': 960, 'height': 540},
    {'view': 'front_view', 'x': 960, 'y': 0, 'width': 960, 'height': 540},
    
    # Bottom row - stacked vertically
    {'view': 'joint_Hips', 'x': 0, 'y': 540, 'width': 960, 'height': 270},
    {'view': 'plot', 'x': 0, 'y': 810, 'width': 960, 'height': 270},
    
    # {'view': 'drum_dot', 'x': 960, 'y': 540, 'width': 960, 'height': 540},
    {'view': 'drum_dot', 'x': 960, 'y': 540, 'width': 960, 'height': 270},
    {'view': 'dance_dot', 'x': 960, 'y': 810, 'width': 960, 'height': 270},
]


saved_resized_dir = os.path.join(vid_plot_path, "temp_resized")
os.makedirs(saved_resized_dir, exist_ok=True)

composite_video_elements = []

for video_element in composite_layout_2:
    video_path = view_videos[video_element['view']]
    v_width, v_height = video_element['width'], video_element['height']
    x_pos_pxl, y_pos_pxl = video_element['x'], video_element['y']
    
    resized_path = resize_video(video_path, v_width, v_height, saved_resized_dir)
    
    composite_video_elements.append({"view": video_element['view'], 
                           "vid_path": resized_path,
                           "x_pos_pxl": x_pos_pxl,
                           "y_pos_pxl": y_pos_pxl,
                           })
# Out:
# Resizing succeeded, output saved to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\temp_resized\video_mix_concat.mp4
# Resizing succeeded, output saved to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\temp_resized\front_view_concat.mp4
# Resizing succeeded, output saved to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\temp_resized\joint_Hips_concat.mp4
# Resizing succeeded, output saved to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\temp_resized\plot_concat.mp4
# Resizing succeeded, output saved to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\temp_resized\drum_dot_concat.mp4
# Resizing succeeded, output saved to: composite_videos\BKO_E1_D1_02_Maraka\beat_1\temp_resized\dance_dot_concat.mp4

# %%
# Create a list of dictionaries with just the paths and positions
video_positions = []
for element in composite_video_elements:
    video_positions.append({
        'path': element['vid_path'],
        'x': element['x_pos_pxl'],
        'y': element['y_pos_pxl']
    })

# Build the ffmpeg command
ffmpeg_inputs = []
for pos in video_positions:
    ffmpeg_inputs.extend(['-i', pos['path']])

# Create the xstack layout string
# Format: xstack=inputs=4:layout=0_0|w0_0|0_h0|w0_h0
layout = []
for pos in video_positions:
    layout.append(f"{pos['x']}_{pos['y']}")

xstack_layout = "|".join(layout)

final_out = os.path.join(vid_plot_path, "final_output.mp4")
ffmpeg_cmd = [
    'ffmpeg', '-y',
    *ffmpeg_inputs,
    '-filter_complex', f'xstack=inputs={len(video_positions)}:layout={xstack_layout}[v]',
    '-map', '[v]',
    '-map', '0:a?', '-c:a', 'aac', '-b:a', '192k',
    '-c:v', 'libx264',   #'libx264',
    '-crf', '23',
    '-preset', 'ultrafast',
    final_out
]

# Execute the command

try:
    subprocess.run(ffmpeg_cmd, check=True)
    print("Video successfully created as final_output.mp4")
except subprocess.CalledProcessError as e:
    print(f"Error creating video: {e}")
# Out:
# Video successfully created as final_output.mp4
