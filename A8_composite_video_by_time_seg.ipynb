# %%
import os
import pickle
import subprocess
# import pandas as pd
from utils_mocap_viz.generate_views import (    # organize this
    # get_output_dir,
    prepare_videos
)

from utils_mocap_viz.animated_merged_phase_analysis import animate_merged_phase_analysis
from utils_dance_anim.dance_dot import animate_dance_phase_analysis


from utils_pipeline.pipeline_B import *

# %% [markdown]
# ### Config

# %%
file_name = "BKO_E1_D1_02_Maraka"
traj_dir  = "traj_files_presentation"
status    = "included"   # or "excluded"
traj_threshold = "0.001"        # or any other threshold

bvh_dir = os.path.join("data", "bvh_files")
bvh_file = os.path.join(bvh_dir, file_name + "_T")

# path to onsets and cycles csv files
cycles_csv_path = f"data/virtual_cycles/{file_name}_C.csv"
onsets_csv_path = f"data/drum_onsets/{file_name}.csv"
dance_csv_path = f"data/dance_onsets/{file_name}_T_dance_onsets.csv"


m_idx = 0
mode = ["group", "individual", "audience"]
dance_mode = mode[m_idx]

motion_data_dir = "data/motion_data_pkl"
dance_mode_path = f"data/dance_modes_ts/{file_name}_{dance_mode}.pkl"

# load dance mode time segments
if os.path.exists(dance_mode_path):
    with open(dance_mode_path, "rb") as f:
        dmode_ts = pickle.load(f)
else:
    print(f"{file_name} {dance_mode} does not exist")

dmode_ts
# cycle_segs, windows = compute_windows(traj_dir, file_name, status, traj_threshold)
# Out:
# [(23.16, 65.2)]

# %%
input_start_time = 30
input_end_time = 60

cyc_df = pd.read_csv(cycles_csv_path)
cycle_onsets = cyc_df["Virtual Onset"].values
cycle_onsets_in_range = cycle_onsets[(cycle_onsets >= input_start_time) & (cycle_onsets <= input_end_time)] 


start_time = cycle_onsets_in_range[0]
end_time = cycle_onsets_in_range[-1]

traj_tuples = [ (cycle_onsets_in_range[i], cycle_onsets_in_range[i+1], 0) for i in range(len(cycle_onsets_in_range)-1)]
traj_tuples
# Out:
# [(31.07633333333333, 33.48166666633333, 0),
#  (33.48166666633333, 35.851444444, 0),
#  (35.851444444, 38.19277777766667, 0),
#  (38.19277777766667, 40.538555555, 0),
#  (40.538555555, 42.90566666666667, 0),
#  (42.90566666666667, 45.23455555533334, 0),
#  (45.23455555533334, 47.571, 0),
#  (47.571, 49.90033333333333, 0),
#  (49.90033333333333, 52.17588888866667, 0),
#  (52.17588888866667, 54.4496666665, 0),
#  (54.4496666665, 56.688777777666665, 0),
#  (56.688777777666665, 58.955, 0)]

# %% [markdown]
# ### Generate trajectory video + trimmed dance video plots

# %%
# vid_plot_path = f"cycle_videos/{file_name}/"
# start_time = 30
# end_time = 60
# traj_tuples = [(start_time, end_time, 0)]

base_output_dir = os.path.join("composite_videos", f"{file_name}_{start_time:.2f}_{end_time:.2f}")
os.makedirs(base_output_dir, exist_ok=True)

# %%
extract_forward_cycle_videos_and_plots(
    file_name = file_name,
    windows = traj_tuples,  # List of (win_start, win_end, t_poi) tuples
    # window_key = w_key,
    base_path_logs = "data/logs_v4_0.007_foot_jun3",            # logs_v4_0.007_foot_jun3       logs_v2_may
    figsize = (10, 3),
    dpi = 200,
    save_dir = base_output_dir,
    legend_flag = True,
    )
# Out:
# Windows data:
# Window 1:
#   Start: 31.076
#   End: 33.482
#   Duration: 2.405
# Window 2:
#   Start: 33.482
#   End: 35.851
#   Duration: 2.370
# Window 3:
#   Start: 35.851
#   End: 38.193
#   Duration: 2.341
# Window 4:
#   Start: 38.193
#   End: 40.539
#   Duration: 2.346
# Window 5:
#   Start: 40.539
#   End: 42.906
#   Duration: 2.367
# Window 6:
#   Start: 42.906
#   End: 45.235
#   Duration: 2.329
# Window 7:
#   Start: 45.235
#   End: 47.571
#   Duration: 2.336
# Window 8:
#   Start: 47.571
#   End: 49.900
#   Duration: 2.329
# Window 9:
#   Start: 49.900
#   End: 52.176
#   Duration: 2.276
# Window 10:
#   Start: 52.176
#   End: 54.450
#   Duration: 2.274
# Window 11:
#   Start: 54.450
#   End: 56.689
#   Duration: 2.239
# Window 12:
#   Start: 56.689
#   End: 58.955
#   Duration: 2.266
#
# Foot data ranges:
# Left foot time range: 0.733 to 340.450
# Right foot time range: 0.267 to 339.721
# Number of left foot onsets: 240
# Number of right foot onsets: 234
#
# Processing 12 windows
# Total frames in trajectory data: 81793
# Time range in trajectory data: 0.000 to 340.800
#
# Processing window 1:
#   Window time range: 31.076 to 33.482
#   Found 1 left foot onsets and 1 right foot onsets
#   Left foot onset times: [32.29583333]
#   Right foot onset times: [31.125]
#   Video frames: 1553 to 1674 (50fps)
#   Trajectory frames: 7458 to 8035 (240fps)
#   Trajectory data points: 577
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_001_31.08_33.48.mp4
# Start time: 31.07633333333333
# Duration: 2.4053333330000015
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 31.07633333333333 -t 2.4053333330000015 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_001_31.08_33.48.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_001_31.08_33.48.mp4
# File size: 1552287 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_001_31.08_33.48.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\plots\BKO_E1_D1_02_Maraka_window_001_31.08_33.48.mp4
#   Video duration: 2.405s
#   Plot duration: 2.375s
#
# Processing window 2:
#   Window time range: 33.482 to 35.851
#   Found 1 left foot onsets and 1 right foot onsets
#   Left foot onset times: [34.6625]
#   Right foot onset times: [33.52083333]
#   Video frames: 1674 to 1792 (50fps)
#   Trajectory frames: 8035 to 8604 (240fps)
#   Trajectory data points: 569
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_002_33.48_35.85.mp4
# Start time: 33.48166666633333
# Duration: 2.3697777776666697
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 33.48166666633333 -t 2.3697777776666697 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_002_33.48_35.85.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_002_33.48_35.85.mp4
# File size: 1489197 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_002_33.48_35.85.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\plots\BKO_E1_D1_02_Maraka_window_002_33.48_35.85.mp4
#   Video duration: 2.370s
#   Plot duration: 2.333s
#
# Processing window 3:
#   Window time range: 35.851 to 38.193
#   Found 1 left foot onsets and 1 right foot onsets
#   Left foot onset times: [36.9875]
#   Right foot onset times: [35.9]
#   Video frames: 1792 to 1909 (50fps)
#   Trajectory frames: 8604 to 9166 (240fps)
#   Trajectory data points: 562
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_003_35.85_38.19.mp4
# Start time: 35.851444444
# Duration: 2.341333333666668
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 35.851444444 -t 2.341333333666668 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_003_35.85_38.19.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_003_35.85_38.19.mp4
# File size: 1547486 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_003_35.85_38.19.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\plots\BKO_E1_D1_02_Maraka_window_003_35.85_38.19.mp4
#   Video duration: 2.341s
#   Plot duration: 2.333s
#
# Processing window 4:
#   Window time range: 38.193 to 40.539
#   Found 1 left foot onsets and 1 right foot onsets
#   Left foot onset times: [39.3375]
#   Right foot onset times: [38.24166667]
#   Video frames: 1909 to 2026 (50fps)
#   Trajectory frames: 9166 to 9729 (240fps)
#   Trajectory data points: 563
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_004_38.19_40.54.mp4
# Start time: 38.19277777766667
# Duration: 2.345777777333332
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 38.19277777766667 -t 2.345777777333332 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_004_38.19_40.54.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_004_38.19_40.54.mp4
# File size: 1583675 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_004_38.19_40.54.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\plots\BKO_E1_D1_02_Maraka_window_004_38.19_40.54.mp4
#   Video duration: 2.346s
#   Plot duration: 2.333s
#
# Processing window 5:
#   Window time range: 40.539 to 42.906
#   Found 1 left foot onsets and 1 right foot onsets
#   Left foot onset times: [41.69583333]
#   Right foot onset times: [40.55]
#   Video frames: 2026 to 2145 (50fps)
#   Trajectory frames: 9729 to 10297 (240fps)
#   Trajectory data points: 568
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_005_40.54_42.91.mp4
# Start time: 40.538555555
# Duration: 2.3671111116666665
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 40.538555555 -t 2.3671111116666665 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_005_40.54_42.91.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_005_40.54_42.91.mp4
# File size: 1574418 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_005_40.54_42.91.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\plots\BKO_E1_D1_02_Maraka_window_005_40.54_42.91.mp4
#   Video duration: 2.367s
#   Plot duration: 2.333s
#
# Processing window 6:
#   Window time range: 42.906 to 45.235
#   Found 1 left foot onsets and 1 right foot onsets
#   Left foot onset times: [44.0625]
#   Right foot onset times: [42.93333333]
#   Video frames: 2145 to 2261 (50fps)
#   Trajectory frames: 10297 to 10856 (240fps)
#   Trajectory data points: 559
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_006_42.91_45.23.mp4
# Start time: 42.90566666666667
# Duration: 2.3288888886666683
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 42.90566666666667 -t 2.3288888886666683 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_006_42.91_45.23.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_006_42.91_45.23.mp4
# File size: 1495427 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_006_42.91_45.23.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\plots\BKO_E1_D1_02_Maraka_window_006_42.91_45.23.mp4
#   Video duration: 2.329s
#   Plot duration: 2.292s
#
# Processing window 7:
#   Window time range: 45.235 to 47.571
#   Found 1 left foot onsets and 2 right foot onsets
#   Left foot onset times: [46.3875]
#   Right foot onset times: [45.27083333 47.5625    ]
#   Video frames: 2261 to 2378 (50fps)
#   Trajectory frames: 10856 to 11417 (240fps)
#   Trajectory data points: 561
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_007_45.23_47.57.mp4
# Start time: 45.23455555533334
# Duration: 2.336444444666661
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 45.23455555533334 -t 2.336444444666661 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_007_45.23_47.57.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_007_45.23_47.57.mp4
# File size: 1572852 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_007_45.23_47.57.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\plots\BKO_E1_D1_02_Maraka_window_007_45.23_47.57.mp4
#   Video duration: 2.336s
#   Plot duration: 2.333s
#
# Processing window 8:
#   Window time range: 47.571 to 49.900
#   Found 1 left foot onsets and 0 right foot onsets
#   Left foot onset times: [48.72916667]
#   Video frames: 2378 to 2495 (50fps)
#   Trajectory frames: 11417 to 11976 (240fps)
#   Trajectory data points: 559
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_008_47.57_49.90.mp4
# Start time: 47.571
# Duration: 2.329333333333331
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 47.571 -t 2.329333333333331 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_008_47.57_49.90.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_008_47.57_49.90.mp4
# File size: 1473160 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_008_47.57_49.90.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\plots\BKO_E1_D1_02_Maraka_window_008_47.57_49.90.mp4
#   Video duration: 2.329s
#   Plot duration: 2.292s
#
# Processing window 9:
#   Window time range: 49.900 to 52.176
#   Found 1 left foot onsets and 2 right foot onsets
#   Left foot onset times: [51.025]
#   Right foot onset times: [49.975      52.15416667]
#   Video frames: 2495 to 2608 (50fps)
#   Trajectory frames: 11976 to 12522 (240fps)
#   Trajectory data points: 546
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_009_49.90_52.18.mp4
# Start time: 49.90033333333333
# Duration: 2.275555555333341
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 49.90033333333333 -t 2.275555555333341 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_009_49.90_52.18.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_009_49.90_52.18.mp4
# File size: 1469365 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_009_49.90_52.18.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\plots\BKO_E1_D1_02_Maraka_window_009_49.90_52.18.mp4
#   Video duration: 2.276s
#   Plot duration: 2.250s
#
# Processing window 10:
#   Window time range: 52.176 to 54.450
#   Found 1 left foot onsets and 0 right foot onsets
#   Left foot onset times: [53.33333333]
#   Video frames: 2608 to 2722 (50fps)
#   Trajectory frames: 12522 to 13067 (240fps)
#   Trajectory data points: 545
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_010_52.18_54.45.mp4
# Start time: 52.17588888866667
# Duration: 2.273777777833331
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 52.17588888866667 -t 2.273777777833331 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_010_52.18_54.45.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_010_52.18_54.45.mp4
# File size: 1405740 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_010_52.18_54.45.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\plots\BKO_E1_D1_02_Maraka_window_010_52.18_54.45.mp4
#   Video duration: 2.274s
#   Plot duration: 2.250s
#
# Processing window 11:
#   Window time range: 54.450 to 56.689
#   Found 1 left foot onsets and 1 right foot onsets
#   Left foot onset times: [55.53333333]
#   Right foot onset times: [54.45]
#   Video frames: 2722 to 2834 (50fps)
#   Trajectory frames: 13067 to 13605 (240fps)
#   Trajectory data points: 538
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_011_54.45_56.69.mp4
# Start time: 54.4496666665
# Duration: 2.2391111111666646
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 54.4496666665 -t 2.2391111111666646 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_011_54.45_56.69.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_011_54.45_56.69.mp4
# File size: 1357590 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_011_54.45_56.69.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\plots\BKO_E1_D1_02_Maraka_window_011_54.45_56.69.mp4
#   Video duration: 2.239s
#   Plot duration: 2.208s
#
# Processing window 12:
#   Window time range: 56.689 to 58.955
#   Found 1 left foot onsets and 1 right foot onsets
#   Left foot onset times: [57.82083333]
#   Right foot onset times: [56.75833333]
#   Video frames: 2834 to 2947 (50fps)
#   Trajectory frames: 13605 to 14149 (240fps)
#   Trajectory data points: 544
#
# Video extraction:
# Input video: data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4
# Output video: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_012_56.69_58.95.mp4
# Start time: 56.688777777666665
# Duration: 2.266222222333333
# FFmpeg command: ffmpeg -y -i data/videos/BKO_E1_D1_02_Maraka_pre_R_Mix.mp4 -ss 56.688777777666665 -t 2.266222222333333 -c:v libx264 -c:a aac -r 24 composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_012_56.69_58.95.mp4
# Video extraction successful
# Output file exists: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_012_56.69_58.95.mp4
# File size: 1354409 bytes
#   Video saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\videos\BKO_E1_D1_02_Maraka_window_012_56.69_58.95.mp4
#   Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\plots\BKO_E1_D1_02_Maraka_window_012_56.69_58.95.mp4
#   Video duration: 2.266s
#   Plot duration: 2.250s
#
# Processing complete!

# %% [markdown]
# ### Generate Skeletal video + trimmed_video_mix + drum dot

# %%
# video_path = os.path.join("data", "videos", f"{file_name}_pre_R_Mix.mp4")

output_dir1 = os.path.join(base_output_dir, "video_skeleton")
os.makedirs(output_dir1, exist_ok=True)

output_dir3 = os.path.join(base_output_dir, "drum_dot_merged")
os.makedirs(output_dir3, exist_ok=True)

output_dir4 = os.path.join(base_output_dir, "dance_dot")
os.makedirs(output_dir4, exist_ok=True)

views_to_generate = ['front']       # skeleton views ['front', 'right' 'left', 'top'] 

for start_time, end_time, _ in traj_tuples:

    
    save_fname = f"drum_dot_merged_{start_time:.2f}_{end_time:.2f}.mp4"
    
    # Merged Drum dot plot video
    animate_merged_phase_analysis(
        file_name, start_time, end_time,
        cycles_csv_path, onsets_csv_path,
        figsize=(10, 3), dpi=200,
        save_fname = save_fname,
        save_dir=output_dir3,
        legend_flag = True,
        )
    
    # Dance dot plot video
    animate_dance_phase_analysis(       
        file_name, start_time, end_time,
        cycles_csv_path, dance_csv_path,
        figsize= (10, 3), 
        dpi= 200, 
        save_dir= output_dir4,
        )

    # Generate Skeleton views
    view_videos = prepare_videos(
        filename= bvh_file,
        start_time= start_time,
        end_time= end_time,
        views_to_generate = views_to_generate,
        video_path= None,             # video_path, wont generate video
        video_size= (1280, 720),
        fps= 24,
        output_dir = output_dir1
    )
# Out:
# Generating animation for drum merged dot plot for BKO_E1_D1_02_Maraka | Window: 31.1s - 33.5s
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 31.07633333333333s - 33.48166666633333s: 6
# Total onsets: 1830
# Onsets in window 31.07633333333333s - 33.48166666633333s: 10
# Total onsets: 1830
# Onsets in window 31.07633333333333s - 33.48166666633333s: 8
#
# Creating animation...
# Animation will have 58 frames
# Time range: 31.08s - 33.45s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\drum_dot_merged\drum_dot_merged_31.08_33.48.mp4
# Animation saved successfully!
# Generating animation for dance dot plot for BKO_E1_D1_02_Maraka | Window: 31.1s - 33.5s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\dance_dot\dance_31.08_33.48.mp4
# Animation saved successfully!
# Generating Skeletonviews for data\bvh_files\BKO_E1_D1_02_Maraka_T | Window: 31.1s - 33.5s
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# Position columns: ['Time', 'Hips.X', 'Hips.Y', 'Hips.Z', 'LeftHip.X', 'LeftHip.Y', 'LeftHip.Z', 'LeftKnee.X', 'LeftKnee.Y', 'LeftKnee.Z', 'LeftAnkle.X', 'LeftAnkle.Y', 'LeftAnkle.Z', 'LeftToe.X', 'LeftToe.Y', 'LeftToe.Z', 'LeftToeEnd.X', 'LeftToeEnd.Y', 'LeftToeEnd.Z', 'RightHip.X', 'RightHip.Y', 'RightHip.Z', 'RightKnee.X', 'RightKnee.Y', 'RightKnee.Z', 'RightAnkle.X', 'RightAnkle.Y', 'RightAnkle.Z', 'RightToe.X', 'RightToe.Y', 'RightToe.Z', 'RightToeEnd.X', 'RightToeEnd.Y', 'RightToeEnd.Z', 'Chest.X', 'Chest.Y', 'Chest.Z', 'Chest2.X', 'Chest2.Y', 'Chest2.Z', 'Chest3.X', 'Chest3.Y', 'Chest3.Z', 'Chest4.X', 'Chest4.Y', 'Chest4.Z', 'LeftCollar.X', 'LeftCollar.Y', 'LeftCollar.Z', 'LeftShoulder.X', 'LeftShoulder.Y', 'LeftShoulder.Z', 'LeftElbow.X', 'LeftElbow.Y', 'LeftElbow.Z', 'LeftWrist.X', 'LeftWrist.Y', 'LeftWrist.Z', 'LeftWristEnd.X', 'LeftWristEnd.Y', 'LeftWristEnd.Z', 'RightCollar.X', 'RightCollar.Y', 'RightCollar.Z', 'RightShoulder.X', 'RightShoulder.Y', 'RightShoulder.Z', 'RightElbow.X', 'RightElbow.Y', 'RightElbow.Z', 'RightWrist.X', 'RightWrist.Y', 'RightWrist.Z', 'RightWristEnd.X', 'RightWristEnd.Y', 'RightWristEnd.Z', 'Neck.X', 'Neck.Y', 'Neck.Z', 'Head.X', 'Head.Y', 'Head.Z', 'HeadEnd.X', 'HeadEnd.Y', 'HeadEnd.Z']
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
#
# Debug Information:
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
# T-pose positions: {'Hips': array([ 0.      , 89.062381,  0.      ]), 'LeftHip': array([7.78521200e+00, 8.90525861e+01, 3.31251140e-07]), 'LeftKnee': array([ 7.785212  , 48.30244939, -1.95830332]), 'LeftAnkle': array([ 7.785212  ,  8.66793811, -5.18636626]), 'LeftToe': array([ 7.785212  ,  1.63068611, 10.77240574]), 'LeftToeEnd': array([ 7.785212  ,  0.11709711, 17.35731374]), 'RightHip': array([-7.78521200e+00,  8.90547453e+01, -2.20896914e-07]), 'RightKnee': array([-7.785212  , 48.30449594, -1.95595682]), 'RightAnkle': array([-7.785212  ,  8.66793723, -5.1587819 ]), 'RightToe': array([-7.785212  ,  1.63068523, 10.7999901 ]), 'RightToeEnd': array([-7.785212  ,  0.11709623, 17.3848981 ]), 'Chest': array([ 0.00000000e+00,  9.86069642e+01, -6.81040802e-08]), 'Chest2': array([ 0.00000000e+00,  1.09133886e+02, -6.81040802e-08]), 'Chest3': array([  0.        , 118.69477667,  -0.97204375]), 'Chest4': array([  0.        , 128.24489067,  -1.9439801 ]), 'LeftCollar': array([  2.86465   , 135.75248167,  -1.9439801 ]), 'LeftShoulder': array([ 16.180918  , 135.75248167,  -1.9439801 ]), 'LeftElbow': array([ 44.484243  , 135.75248167,  -1.9439801 ]), 'LeftWrist': array([ 67.68105335, 135.75248167,  -1.00521599]), 'LeftWristEnd': array([ 85.05288935, 135.75248167,  -1.00521599]), 'RightCollar': array([ -2.86465   , 135.75248167,  -1.9439801 ]), 'RightShoulder': array([-16.180918  , 135.75248167,  -1.9439801 ]), 'RightElbow': array([-44.484243  , 135.75248167,  -1.9439801 ]), 'RightWrist': array([-67.68105335, 135.75248167,  -1.00521599]), 'RightWristEnd': array([-85.05288935, 135.75248167,  -1.00521599]), 'Neck': array([  0.        , 141.64188767,  -1.9439801 ]), 'Head': array([ 0.00000000e+00,  1.50363983e+02, -5.27447096e-04]), 'HeadEnd': array([  0.        , 166.97131676,   0.97534886])}
# Connections: [('Hips', 'Chest'), ('Chest', 'Chest2'), ('Chest2', 'Chest3'), ('Chest3', 'Chest4'), ('Chest4', 'Neck'), ('Neck', 'Head'), ('Chest4', 'RightCollar'), ('RightCollar', 'RightShoulder'), ('RightShoulder', 'RightElbow'), ('RightElbow', 'RightWrist'), ('Chest4', 'LeftCollar'), ('LeftCollar', 'LeftShoulder'), ('LeftShoulder', 'LeftElbow'), ('LeftElbow', 'LeftWrist'), ('Hips', 'RightHip'), ('RightHip', 'RightKnee'), ('RightKnee', 'RightAnkle'), ('RightAnkle', 'RightToe'), ('Hips', 'LeftHip'), ('LeftHip', 'LeftKnee'), ('LeftKnee', 'LeftAnkle'), ('LeftAnkle', 'LeftToe')]
#
# Video generation settings:
# Start time: 31.08s (frame 7458)
# End time: 33.48s (frame 8035)
# Output file: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_31.1_33.5.mp4
# Output FPS: 24
# Video size: 1280x720
# Frame 7458 valid markers: 28/28
# Frame 7458 valid markers: 28/28
# Frame 7468 valid markers: 28/28
# Frame 7478 valid markers: 28/28
# Frame 7488 valid markers: 28/28
# Frame 7498 valid markers: 28/28
# Frame 7508 valid markers: 28/28
# Frame 7518 valid markers: 28/28
# Frame 7528 valid markers: 28/28
# Frame 7538 valid markers: 28/28
# Frame 7548 valid markers: 28/28
# Frame 7558 valid markers: 28/28
# Frame 7568 valid markers: 28/28
# Frame 7578 valid markers: 28/28
# Frame 7588 valid markers: 28/28
# Frame 7598 valid markers: 28/28
# Frame 7608 valid markers: 28/28
# Frame 7618 valid markers: 28/28
# Frame 7628 valid markers: 28/28
# Frame 7638 valid markers: 28/28
# Frame 7648 valid markers: 28/28
# Frame 7658 valid markers: 28/28
# Frame 7668 valid markers: 28/28
# Frame 7678 valid markers: 28/28
# Frame 7688 valid markers: 28/28
# Frame 7698 valid markers: 28/28
# Frame 7708 valid markers: 28/28
# Frame 7718 valid markers: 28/28
# Frame 7728 valid markers: 28/28
# Frame 7738 valid markers: 28/28
# Frame 7748 valid markers: 28/28
# Frame 7758 valid markers: 28/28
# Frame 7768 valid markers: 28/28
# Frame 7778 valid markers: 28/28
# Frame 7788 valid markers: 28/28
# Frame 7798 valid markers: 28/28
# Frame 7808 valid markers: 28/28
# Frame 7818 valid markers: 28/28
# Frame 7828 valid markers: 28/28
# Frame 7838 valid markers: 28/28
# Frame 7848 valid markers: 28/28
# Frame 7858 valid markers: 28/28
# Frame 7868 valid markers: 28/28
# Frame 7878 valid markers: 28/28
# Frame 7888 valid markers: 28/28
# Frame 7898 valid markers: 28/28
# Frame 7908 valid markers: 28/28
# Frame 7918 valid markers: 28/28
# Frame 7928 valid markers: 28/28
# Frame 7938 valid markers: 28/28
# Frame 7948 valid markers: 28/28
# Frame 7958 valid markers: 28/28
# Frame 7968 valid markers: 28/28
# Frame 7978 valid markers: 28/28
# Frame 7988 valid markers: 28/28
# Frame 7998 valid markers: 28/28
# Frame 8008 valid markers: 28/28
# Frame 8018 valid markers: 28/28
# Frame 8028 valid markers: 28/28
# Saved frame 58/57
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_31.1_33.5.mp4
# Generating animation for drum merged dot plot for BKO_E1_D1_02_Maraka | Window: 33.5s - 35.9s
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 33.48166666633333s - 35.851444444s: 5
# Total onsets: 1830
# Onsets in window 33.48166666633333s - 35.851444444s: 10
# Total onsets: 1830
# Onsets in window 33.48166666633333s - 35.851444444s: 8
#
# Creating animation...
# Animation will have 57 frames
# Time range: 33.48s - 35.81s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\drum_dot_merged\drum_dot_merged_33.48_35.85.mp4
# Animation saved successfully!
# Generating animation for dance dot plot for BKO_E1_D1_02_Maraka | Window: 33.5s - 35.9s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\dance_dot\dance_33.48_35.85.mp4
# Animation saved successfully!
# Generating Skeletonviews for data\bvh_files\BKO_E1_D1_02_Maraka_T | Window: 33.5s - 35.9s
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# Position columns: ['Time', 'Hips.X', 'Hips.Y', 'Hips.Z', 'LeftHip.X', 'LeftHip.Y', 'LeftHip.Z', 'LeftKnee.X', 'LeftKnee.Y', 'LeftKnee.Z', 'LeftAnkle.X', 'LeftAnkle.Y', 'LeftAnkle.Z', 'LeftToe.X', 'LeftToe.Y', 'LeftToe.Z', 'LeftToeEnd.X', 'LeftToeEnd.Y', 'LeftToeEnd.Z', 'RightHip.X', 'RightHip.Y', 'RightHip.Z', 'RightKnee.X', 'RightKnee.Y', 'RightKnee.Z', 'RightAnkle.X', 'RightAnkle.Y', 'RightAnkle.Z', 'RightToe.X', 'RightToe.Y', 'RightToe.Z', 'RightToeEnd.X', 'RightToeEnd.Y', 'RightToeEnd.Z', 'Chest.X', 'Chest.Y', 'Chest.Z', 'Chest2.X', 'Chest2.Y', 'Chest2.Z', 'Chest3.X', 'Chest3.Y', 'Chest3.Z', 'Chest4.X', 'Chest4.Y', 'Chest4.Z', 'LeftCollar.X', 'LeftCollar.Y', 'LeftCollar.Z', 'LeftShoulder.X', 'LeftShoulder.Y', 'LeftShoulder.Z', 'LeftElbow.X', 'LeftElbow.Y', 'LeftElbow.Z', 'LeftWrist.X', 'LeftWrist.Y', 'LeftWrist.Z', 'LeftWristEnd.X', 'LeftWristEnd.Y', 'LeftWristEnd.Z', 'RightCollar.X', 'RightCollar.Y', 'RightCollar.Z', 'RightShoulder.X', 'RightShoulder.Y', 'RightShoulder.Z', 'RightElbow.X', 'RightElbow.Y', 'RightElbow.Z', 'RightWrist.X', 'RightWrist.Y', 'RightWrist.Z', 'RightWristEnd.X', 'RightWristEnd.Y', 'RightWristEnd.Z', 'Neck.X', 'Neck.Y', 'Neck.Z', 'Head.X', 'Head.Y', 'Head.Z', 'HeadEnd.X', 'HeadEnd.Y', 'HeadEnd.Z']
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
#
# Debug Information:
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
# T-pose positions: {'Hips': array([ 0.      , 89.062381,  0.      ]), 'LeftHip': array([7.78521200e+00, 8.90525861e+01, 3.31251140e-07]), 'LeftKnee': array([ 7.785212  , 48.30244939, -1.95830332]), 'LeftAnkle': array([ 7.785212  ,  8.66793811, -5.18636626]), 'LeftToe': array([ 7.785212  ,  1.63068611, 10.77240574]), 'LeftToeEnd': array([ 7.785212  ,  0.11709711, 17.35731374]), 'RightHip': array([-7.78521200e+00,  8.90547453e+01, -2.20896914e-07]), 'RightKnee': array([-7.785212  , 48.30449594, -1.95595682]), 'RightAnkle': array([-7.785212  ,  8.66793723, -5.1587819 ]), 'RightToe': array([-7.785212  ,  1.63068523, 10.7999901 ]), 'RightToeEnd': array([-7.785212  ,  0.11709623, 17.3848981 ]), 'Chest': array([ 0.00000000e+00,  9.86069642e+01, -6.81040802e-08]), 'Chest2': array([ 0.00000000e+00,  1.09133886e+02, -6.81040802e-08]), 'Chest3': array([  0.        , 118.69477667,  -0.97204375]), 'Chest4': array([  0.        , 128.24489067,  -1.9439801 ]), 'LeftCollar': array([  2.86465   , 135.75248167,  -1.9439801 ]), 'LeftShoulder': array([ 16.180918  , 135.75248167,  -1.9439801 ]), 'LeftElbow': array([ 44.484243  , 135.75248167,  -1.9439801 ]), 'LeftWrist': array([ 67.68105335, 135.75248167,  -1.00521599]), 'LeftWristEnd': array([ 85.05288935, 135.75248167,  -1.00521599]), 'RightCollar': array([ -2.86465   , 135.75248167,  -1.9439801 ]), 'RightShoulder': array([-16.180918  , 135.75248167,  -1.9439801 ]), 'RightElbow': array([-44.484243  , 135.75248167,  -1.9439801 ]), 'RightWrist': array([-67.68105335, 135.75248167,  -1.00521599]), 'RightWristEnd': array([-85.05288935, 135.75248167,  -1.00521599]), 'Neck': array([  0.        , 141.64188767,  -1.9439801 ]), 'Head': array([ 0.00000000e+00,  1.50363983e+02, -5.27447096e-04]), 'HeadEnd': array([  0.        , 166.97131676,   0.97534886])}
# Connections: [('Hips', 'Chest'), ('Chest', 'Chest2'), ('Chest2', 'Chest3'), ('Chest3', 'Chest4'), ('Chest4', 'Neck'), ('Neck', 'Head'), ('Chest4', 'RightCollar'), ('RightCollar', 'RightShoulder'), ('RightShoulder', 'RightElbow'), ('RightElbow', 'RightWrist'), ('Chest4', 'LeftCollar'), ('LeftCollar', 'LeftShoulder'), ('LeftShoulder', 'LeftElbow'), ('LeftElbow', 'LeftWrist'), ('Hips', 'RightHip'), ('RightHip', 'RightKnee'), ('RightKnee', 'RightAnkle'), ('RightAnkle', 'RightToe'), ('Hips', 'LeftHip'), ('LeftHip', 'LeftKnee'), ('LeftKnee', 'LeftAnkle'), ('LeftAnkle', 'LeftToe')]
#
# Video generation settings:
# Start time: 33.48s (frame 8035)
# End time: 35.85s (frame 8604)
# Output file: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_33.5_35.9.mp4
# Output FPS: 24
# Video size: 1280x720
# Frame 8035 valid markers: 28/28
# Frame 8035 valid markers: 28/28
# Frame 8045 valid markers: 28/28
# Frame 8055 valid markers: 28/28
# Frame 8065 valid markers: 28/28
# Frame 8075 valid markers: 28/28
# Frame 8085 valid markers: 28/28
# Frame 8095 valid markers: 28/28
# Frame 8105 valid markers: 28/28
# Frame 8115 valid markers: 28/28
# Frame 8125 valid markers: 28/28
# Frame 8135 valid markers: 28/28
# Frame 8145 valid markers: 28/28
# Frame 8155 valid markers: 28/28
# Frame 8165 valid markers: 28/28
# Frame 8175 valid markers: 28/28
# Frame 8185 valid markers: 28/28
# Frame 8195 valid markers: 28/28
# Frame 8205 valid markers: 28/28
# Frame 8215 valid markers: 28/28
# Frame 8225 valid markers: 28/28
# Frame 8235 valid markers: 28/28
# Frame 8245 valid markers: 28/28
# Frame 8255 valid markers: 28/28
# Frame 8265 valid markers: 28/28
# Frame 8275 valid markers: 28/28
# Frame 8285 valid markers: 28/28
# Frame 8295 valid markers: 28/28
# Frame 8305 valid markers: 28/28
# Frame 8315 valid markers: 28/28
# Frame 8325 valid markers: 28/28
# Frame 8335 valid markers: 28/28
# Frame 8345 valid markers: 28/28
# Frame 8355 valid markers: 28/28
# Frame 8365 valid markers: 28/28
# Frame 8375 valid markers: 28/28
# Frame 8385 valid markers: 28/28
# Frame 8395 valid markers: 28/28
# Frame 8405 valid markers: 28/28
# Frame 8415 valid markers: 28/28
# Frame 8425 valid markers: 28/28
# Frame 8435 valid markers: 28/28
# Frame 8445 valid markers: 28/28
# Frame 8455 valid markers: 28/28
# Frame 8465 valid markers: 28/28
# Frame 8475 valid markers: 28/28
# Frame 8485 valid markers: 28/28
# Frame 8495 valid markers: 28/28
# Frame 8505 valid markers: 28/28
# Frame 8515 valid markers: 28/28
# Frame 8525 valid markers: 28/28
# Frame 8535 valid markers: 28/28
# Frame 8545 valid markers: 28/28
# Frame 8555 valid markers: 28/28
# Frame 8565 valid markers: 28/28
# Frame 8575 valid markers: 28/28
# Frame 8585 valid markers: 28/28
# Frame 8595 valid markers: 28/28
# Saved frame 57/56
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_33.5_35.9.mp4
# Generating animation for drum merged dot plot for BKO_E1_D1_02_Maraka | Window: 35.9s - 38.2s
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 35.851444444s - 38.19277777766667s: 7
# Total onsets: 1830
# Onsets in window 35.851444444s - 38.19277777766667s: 10
# Total onsets: 1830
# Onsets in window 35.851444444s - 38.19277777766667s: 8
#
# Creating animation...
# Animation will have 57 frames
# Time range: 35.85s - 38.18s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\drum_dot_merged\drum_dot_merged_35.85_38.19.mp4
# Animation saved successfully!
# Generating animation for dance dot plot for BKO_E1_D1_02_Maraka | Window: 35.9s - 38.2s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\dance_dot\dance_35.85_38.19.mp4
# Animation saved successfully!
# Generating Skeletonviews for data\bvh_files\BKO_E1_D1_02_Maraka_T | Window: 35.9s - 38.2s
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# Position columns: ['Time', 'Hips.X', 'Hips.Y', 'Hips.Z', 'LeftHip.X', 'LeftHip.Y', 'LeftHip.Z', 'LeftKnee.X', 'LeftKnee.Y', 'LeftKnee.Z', 'LeftAnkle.X', 'LeftAnkle.Y', 'LeftAnkle.Z', 'LeftToe.X', 'LeftToe.Y', 'LeftToe.Z', 'LeftToeEnd.X', 'LeftToeEnd.Y', 'LeftToeEnd.Z', 'RightHip.X', 'RightHip.Y', 'RightHip.Z', 'RightKnee.X', 'RightKnee.Y', 'RightKnee.Z', 'RightAnkle.X', 'RightAnkle.Y', 'RightAnkle.Z', 'RightToe.X', 'RightToe.Y', 'RightToe.Z', 'RightToeEnd.X', 'RightToeEnd.Y', 'RightToeEnd.Z', 'Chest.X', 'Chest.Y', 'Chest.Z', 'Chest2.X', 'Chest2.Y', 'Chest2.Z', 'Chest3.X', 'Chest3.Y', 'Chest3.Z', 'Chest4.X', 'Chest4.Y', 'Chest4.Z', 'LeftCollar.X', 'LeftCollar.Y', 'LeftCollar.Z', 'LeftShoulder.X', 'LeftShoulder.Y', 'LeftShoulder.Z', 'LeftElbow.X', 'LeftElbow.Y', 'LeftElbow.Z', 'LeftWrist.X', 'LeftWrist.Y', 'LeftWrist.Z', 'LeftWristEnd.X', 'LeftWristEnd.Y', 'LeftWristEnd.Z', 'RightCollar.X', 'RightCollar.Y', 'RightCollar.Z', 'RightShoulder.X', 'RightShoulder.Y', 'RightShoulder.Z', 'RightElbow.X', 'RightElbow.Y', 'RightElbow.Z', 'RightWrist.X', 'RightWrist.Y', 'RightWrist.Z', 'RightWristEnd.X', 'RightWristEnd.Y', 'RightWristEnd.Z', 'Neck.X', 'Neck.Y', 'Neck.Z', 'Head.X', 'Head.Y', 'Head.Z', 'HeadEnd.X', 'HeadEnd.Y', 'HeadEnd.Z']
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
#
# Debug Information:
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
# T-pose positions: {'Hips': array([ 0.      , 89.062381,  0.      ]), 'LeftHip': array([7.78521200e+00, 8.90525861e+01, 3.31251140e-07]), 'LeftKnee': array([ 7.785212  , 48.30244939, -1.95830332]), 'LeftAnkle': array([ 7.785212  ,  8.66793811, -5.18636626]), 'LeftToe': array([ 7.785212  ,  1.63068611, 10.77240574]), 'LeftToeEnd': array([ 7.785212  ,  0.11709711, 17.35731374]), 'RightHip': array([-7.78521200e+00,  8.90547453e+01, -2.20896914e-07]), 'RightKnee': array([-7.785212  , 48.30449594, -1.95595682]), 'RightAnkle': array([-7.785212  ,  8.66793723, -5.1587819 ]), 'RightToe': array([-7.785212  ,  1.63068523, 10.7999901 ]), 'RightToeEnd': array([-7.785212  ,  0.11709623, 17.3848981 ]), 'Chest': array([ 0.00000000e+00,  9.86069642e+01, -6.81040802e-08]), 'Chest2': array([ 0.00000000e+00,  1.09133886e+02, -6.81040802e-08]), 'Chest3': array([  0.        , 118.69477667,  -0.97204375]), 'Chest4': array([  0.        , 128.24489067,  -1.9439801 ]), 'LeftCollar': array([  2.86465   , 135.75248167,  -1.9439801 ]), 'LeftShoulder': array([ 16.180918  , 135.75248167,  -1.9439801 ]), 'LeftElbow': array([ 44.484243  , 135.75248167,  -1.9439801 ]), 'LeftWrist': array([ 67.68105335, 135.75248167,  -1.00521599]), 'LeftWristEnd': array([ 85.05288935, 135.75248167,  -1.00521599]), 'RightCollar': array([ -2.86465   , 135.75248167,  -1.9439801 ]), 'RightShoulder': array([-16.180918  , 135.75248167,  -1.9439801 ]), 'RightElbow': array([-44.484243  , 135.75248167,  -1.9439801 ]), 'RightWrist': array([-67.68105335, 135.75248167,  -1.00521599]), 'RightWristEnd': array([-85.05288935, 135.75248167,  -1.00521599]), 'Neck': array([  0.        , 141.64188767,  -1.9439801 ]), 'Head': array([ 0.00000000e+00,  1.50363983e+02, -5.27447096e-04]), 'HeadEnd': array([  0.        , 166.97131676,   0.97534886])}
# Connections: [('Hips', 'Chest'), ('Chest', 'Chest2'), ('Chest2', 'Chest3'), ('Chest3', 'Chest4'), ('Chest4', 'Neck'), ('Neck', 'Head'), ('Chest4', 'RightCollar'), ('RightCollar', 'RightShoulder'), ('RightShoulder', 'RightElbow'), ('RightElbow', 'RightWrist'), ('Chest4', 'LeftCollar'), ('LeftCollar', 'LeftShoulder'), ('LeftShoulder', 'LeftElbow'), ('LeftElbow', 'LeftWrist'), ('Hips', 'RightHip'), ('RightHip', 'RightKnee'), ('RightKnee', 'RightAnkle'), ('RightAnkle', 'RightToe'), ('Hips', 'LeftHip'), ('LeftHip', 'LeftKnee'), ('LeftKnee', 'LeftAnkle'), ('LeftAnkle', 'LeftToe')]
#
# Video generation settings:
# Start time: 35.85s (frame 8604)
# End time: 38.19s (frame 9166)
# Output file: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_35.9_38.2.mp4
# Output FPS: 24
# Video size: 1280x720
# Frame 8604 valid markers: 28/28
# Frame 8604 valid markers: 28/28
# Frame 8614 valid markers: 28/28
# Frame 8624 valid markers: 28/28
# Frame 8634 valid markers: 28/28
# Frame 8644 valid markers: 28/28
# Frame 8654 valid markers: 28/28
# Frame 8664 valid markers: 28/28
# Frame 8674 valid markers: 28/28
# Frame 8684 valid markers: 28/28
# Frame 8694 valid markers: 28/28
# Frame 8704 valid markers: 28/28
# Frame 8714 valid markers: 28/28
# Frame 8724 valid markers: 28/28
# Frame 8734 valid markers: 28/28
# Frame 8744 valid markers: 28/28
# Frame 8754 valid markers: 28/28
# Frame 8764 valid markers: 28/28
# Frame 8774 valid markers: 28/28
# Frame 8784 valid markers: 28/28
# Frame 8794 valid markers: 28/28
# Frame 8804 valid markers: 28/28
# Frame 8814 valid markers: 28/28
# Frame 8824 valid markers: 28/28
# Frame 8834 valid markers: 28/28
# Frame 8844 valid markers: 28/28
# Frame 8854 valid markers: 28/28
# Frame 8864 valid markers: 28/28
# Frame 8874 valid markers: 28/28
# Frame 8884 valid markers: 28/28
# Frame 8894 valid markers: 28/28
# Frame 8904 valid markers: 28/28
# Frame 8914 valid markers: 28/28
# Frame 8924 valid markers: 28/28
# Frame 8934 valid markers: 28/28
# Frame 8944 valid markers: 28/28
# Frame 8954 valid markers: 28/28
# Frame 8964 valid markers: 28/28
# Frame 8974 valid markers: 28/28
# Frame 8984 valid markers: 28/28
# Frame 8994 valid markers: 28/28
# Frame 9004 valid markers: 28/28
# Frame 9014 valid markers: 28/28
# Frame 9024 valid markers: 28/28
# Frame 9034 valid markers: 28/28
# Frame 9044 valid markers: 28/28
# Frame 9054 valid markers: 28/28
# Frame 9064 valid markers: 28/28
# Frame 9074 valid markers: 28/28
# Frame 9084 valid markers: 28/28
# Frame 9094 valid markers: 28/28
# Frame 9104 valid markers: 28/28
# Frame 9114 valid markers: 28/28
# Frame 9124 valid markers: 28/28
# Frame 9134 valid markers: 28/28
# Frame 9144 valid markers: 28/28
# Frame 9154 valid markers: 28/28
# Frame 9164 valid markers: 28/28
# Saved frame 57/56
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_35.9_38.2.mp4
# Generating animation for drum merged dot plot for BKO_E1_D1_02_Maraka | Window: 38.2s - 40.5s
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 38.19277777766667s - 40.538555555s: 6
# Total onsets: 1830
# Onsets in window 38.19277777766667s - 40.538555555s: 15
# Total onsets: 1830
# Onsets in window 38.19277777766667s - 40.538555555s: 9
#
# Creating animation...
# Animation will have 57 frames
# Time range: 38.19s - 40.53s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\drum_dot_merged\drum_dot_merged_38.19_40.54.mp4
# Animation saved successfully!
# Generating animation for dance dot plot for BKO_E1_D1_02_Maraka | Window: 38.2s - 40.5s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\dance_dot\dance_38.19_40.54.mp4
# Animation saved successfully!
# Generating Skeletonviews for data\bvh_files\BKO_E1_D1_02_Maraka_T | Window: 38.2s - 40.5s
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# Position columns: ['Time', 'Hips.X', 'Hips.Y', 'Hips.Z', 'LeftHip.X', 'LeftHip.Y', 'LeftHip.Z', 'LeftKnee.X', 'LeftKnee.Y', 'LeftKnee.Z', 'LeftAnkle.X', 'LeftAnkle.Y', 'LeftAnkle.Z', 'LeftToe.X', 'LeftToe.Y', 'LeftToe.Z', 'LeftToeEnd.X', 'LeftToeEnd.Y', 'LeftToeEnd.Z', 'RightHip.X', 'RightHip.Y', 'RightHip.Z', 'RightKnee.X', 'RightKnee.Y', 'RightKnee.Z', 'RightAnkle.X', 'RightAnkle.Y', 'RightAnkle.Z', 'RightToe.X', 'RightToe.Y', 'RightToe.Z', 'RightToeEnd.X', 'RightToeEnd.Y', 'RightToeEnd.Z', 'Chest.X', 'Chest.Y', 'Chest.Z', 'Chest2.X', 'Chest2.Y', 'Chest2.Z', 'Chest3.X', 'Chest3.Y', 'Chest3.Z', 'Chest4.X', 'Chest4.Y', 'Chest4.Z', 'LeftCollar.X', 'LeftCollar.Y', 'LeftCollar.Z', 'LeftShoulder.X', 'LeftShoulder.Y', 'LeftShoulder.Z', 'LeftElbow.X', 'LeftElbow.Y', 'LeftElbow.Z', 'LeftWrist.X', 'LeftWrist.Y', 'LeftWrist.Z', 'LeftWristEnd.X', 'LeftWristEnd.Y', 'LeftWristEnd.Z', 'RightCollar.X', 'RightCollar.Y', 'RightCollar.Z', 'RightShoulder.X', 'RightShoulder.Y', 'RightShoulder.Z', 'RightElbow.X', 'RightElbow.Y', 'RightElbow.Z', 'RightWrist.X', 'RightWrist.Y', 'RightWrist.Z', 'RightWristEnd.X', 'RightWristEnd.Y', 'RightWristEnd.Z', 'Neck.X', 'Neck.Y', 'Neck.Z', 'Head.X', 'Head.Y', 'Head.Z', 'HeadEnd.X', 'HeadEnd.Y', 'HeadEnd.Z']
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
#
# Debug Information:
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
# T-pose positions: {'Hips': array([ 0.      , 89.062381,  0.      ]), 'LeftHip': array([7.78521200e+00, 8.90525861e+01, 3.31251140e-07]), 'LeftKnee': array([ 7.785212  , 48.30244939, -1.95830332]), 'LeftAnkle': array([ 7.785212  ,  8.66793811, -5.18636626]), 'LeftToe': array([ 7.785212  ,  1.63068611, 10.77240574]), 'LeftToeEnd': array([ 7.785212  ,  0.11709711, 17.35731374]), 'RightHip': array([-7.78521200e+00,  8.90547453e+01, -2.20896914e-07]), 'RightKnee': array([-7.785212  , 48.30449594, -1.95595682]), 'RightAnkle': array([-7.785212  ,  8.66793723, -5.1587819 ]), 'RightToe': array([-7.785212  ,  1.63068523, 10.7999901 ]), 'RightToeEnd': array([-7.785212  ,  0.11709623, 17.3848981 ]), 'Chest': array([ 0.00000000e+00,  9.86069642e+01, -6.81040802e-08]), 'Chest2': array([ 0.00000000e+00,  1.09133886e+02, -6.81040802e-08]), 'Chest3': array([  0.        , 118.69477667,  -0.97204375]), 'Chest4': array([  0.        , 128.24489067,  -1.9439801 ]), 'LeftCollar': array([  2.86465   , 135.75248167,  -1.9439801 ]), 'LeftShoulder': array([ 16.180918  , 135.75248167,  -1.9439801 ]), 'LeftElbow': array([ 44.484243  , 135.75248167,  -1.9439801 ]), 'LeftWrist': array([ 67.68105335, 135.75248167,  -1.00521599]), 'LeftWristEnd': array([ 85.05288935, 135.75248167,  -1.00521599]), 'RightCollar': array([ -2.86465   , 135.75248167,  -1.9439801 ]), 'RightShoulder': array([-16.180918  , 135.75248167,  -1.9439801 ]), 'RightElbow': array([-44.484243  , 135.75248167,  -1.9439801 ]), 'RightWrist': array([-67.68105335, 135.75248167,  -1.00521599]), 'RightWristEnd': array([-85.05288935, 135.75248167,  -1.00521599]), 'Neck': array([  0.        , 141.64188767,  -1.9439801 ]), 'Head': array([ 0.00000000e+00,  1.50363983e+02, -5.27447096e-04]), 'HeadEnd': array([  0.        , 166.97131676,   0.97534886])}
# Connections: [('Hips', 'Chest'), ('Chest', 'Chest2'), ('Chest2', 'Chest3'), ('Chest3', 'Chest4'), ('Chest4', 'Neck'), ('Neck', 'Head'), ('Chest4', 'RightCollar'), ('RightCollar', 'RightShoulder'), ('RightShoulder', 'RightElbow'), ('RightElbow', 'RightWrist'), ('Chest4', 'LeftCollar'), ('LeftCollar', 'LeftShoulder'), ('LeftShoulder', 'LeftElbow'), ('LeftElbow', 'LeftWrist'), ('Hips', 'RightHip'), ('RightHip', 'RightKnee'), ('RightKnee', 'RightAnkle'), ('RightAnkle', 'RightToe'), ('Hips', 'LeftHip'), ('LeftHip', 'LeftKnee'), ('LeftKnee', 'LeftAnkle'), ('LeftAnkle', 'LeftToe')]
#
# Video generation settings:
# Start time: 38.19s (frame 9166)
# End time: 40.54s (frame 9729)
# Output file: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_38.2_40.5.mp4
# Output FPS: 24
# Video size: 1280x720
# Frame 9166 valid markers: 28/28
# Frame 9166 valid markers: 28/28
# Frame 9176 valid markers: 28/28
# Frame 9186 valid markers: 28/28
# Frame 9196 valid markers: 28/28
# Frame 9206 valid markers: 28/28
# Frame 9216 valid markers: 28/28
# Frame 9226 valid markers: 28/28
# Frame 9236 valid markers: 28/28
# Frame 9246 valid markers: 28/28
# Frame 9256 valid markers: 28/28
# Frame 9266 valid markers: 28/28
# Frame 9276 valid markers: 28/28
# Frame 9286 valid markers: 28/28
# Frame 9296 valid markers: 28/28
# Frame 9306 valid markers: 28/28
# Frame 9316 valid markers: 28/28
# Frame 9326 valid markers: 28/28
# Frame 9336 valid markers: 28/28
# Frame 9346 valid markers: 28/28
# Frame 9356 valid markers: 28/28
# Frame 9366 valid markers: 28/28
# Frame 9376 valid markers: 28/28
# Frame 9386 valid markers: 28/28
# Frame 9396 valid markers: 28/28
# Frame 9406 valid markers: 28/28
# Frame 9416 valid markers: 28/28
# Frame 9426 valid markers: 28/28
# Frame 9436 valid markers: 28/28
# Frame 9446 valid markers: 28/28
# Frame 9456 valid markers: 28/28
# Frame 9466 valid markers: 28/28
# Frame 9476 valid markers: 28/28
# Frame 9486 valid markers: 28/28
# Frame 9496 valid markers: 28/28
# Frame 9506 valid markers: 28/28
# Frame 9516 valid markers: 28/28
# Frame 9526 valid markers: 28/28
# Frame 9536 valid markers: 28/28
# Frame 9546 valid markers: 28/28
# Frame 9556 valid markers: 28/28
# Frame 9566 valid markers: 28/28
# Frame 9576 valid markers: 28/28
# Frame 9586 valid markers: 28/28
# Frame 9596 valid markers: 28/28
# Frame 9606 valid markers: 28/28
# Frame 9616 valid markers: 28/28
# Frame 9626 valid markers: 28/28
# Frame 9636 valid markers: 28/28
# Frame 9646 valid markers: 28/28
# Frame 9656 valid markers: 28/28
# Frame 9666 valid markers: 28/28
# Frame 9676 valid markers: 28/28
# Frame 9686 valid markers: 28/28
# Frame 9696 valid markers: 28/28
# Frame 9706 valid markers: 28/28
# Frame 9716 valid markers: 28/28
# Frame 9726 valid markers: 28/28
# Saved frame 57/56
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_38.2_40.5.mp4
# Generating animation for drum merged dot plot for BKO_E1_D1_02_Maraka | Window: 40.5s - 42.9s
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 40.538555555s - 42.90566666666667s: 6
# Total onsets: 1830
# Onsets in window 40.538555555s - 42.90566666666667s: 17
# Total onsets: 1830
# Onsets in window 40.538555555s - 42.90566666666667s: 7
#
# Creating animation...
# Animation will have 57 frames
# Time range: 40.54s - 42.87s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\drum_dot_merged\drum_dot_merged_40.54_42.91.mp4
# Animation saved successfully!
# Generating animation for dance dot plot for BKO_E1_D1_02_Maraka | Window: 40.5s - 42.9s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\dance_dot\dance_40.54_42.91.mp4
# Animation saved successfully!
# Generating Skeletonviews for data\bvh_files\BKO_E1_D1_02_Maraka_T | Window: 40.5s - 42.9s
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# Position columns: ['Time', 'Hips.X', 'Hips.Y', 'Hips.Z', 'LeftHip.X', 'LeftHip.Y', 'LeftHip.Z', 'LeftKnee.X', 'LeftKnee.Y', 'LeftKnee.Z', 'LeftAnkle.X', 'LeftAnkle.Y', 'LeftAnkle.Z', 'LeftToe.X', 'LeftToe.Y', 'LeftToe.Z', 'LeftToeEnd.X', 'LeftToeEnd.Y', 'LeftToeEnd.Z', 'RightHip.X', 'RightHip.Y', 'RightHip.Z', 'RightKnee.X', 'RightKnee.Y', 'RightKnee.Z', 'RightAnkle.X', 'RightAnkle.Y', 'RightAnkle.Z', 'RightToe.X', 'RightToe.Y', 'RightToe.Z', 'RightToeEnd.X', 'RightToeEnd.Y', 'RightToeEnd.Z', 'Chest.X', 'Chest.Y', 'Chest.Z', 'Chest2.X', 'Chest2.Y', 'Chest2.Z', 'Chest3.X', 'Chest3.Y', 'Chest3.Z', 'Chest4.X', 'Chest4.Y', 'Chest4.Z', 'LeftCollar.X', 'LeftCollar.Y', 'LeftCollar.Z', 'LeftShoulder.X', 'LeftShoulder.Y', 'LeftShoulder.Z', 'LeftElbow.X', 'LeftElbow.Y', 'LeftElbow.Z', 'LeftWrist.X', 'LeftWrist.Y', 'LeftWrist.Z', 'LeftWristEnd.X', 'LeftWristEnd.Y', 'LeftWristEnd.Z', 'RightCollar.X', 'RightCollar.Y', 'RightCollar.Z', 'RightShoulder.X', 'RightShoulder.Y', 'RightShoulder.Z', 'RightElbow.X', 'RightElbow.Y', 'RightElbow.Z', 'RightWrist.X', 'RightWrist.Y', 'RightWrist.Z', 'RightWristEnd.X', 'RightWristEnd.Y', 'RightWristEnd.Z', 'Neck.X', 'Neck.Y', 'Neck.Z', 'Head.X', 'Head.Y', 'Head.Z', 'HeadEnd.X', 'HeadEnd.Y', 'HeadEnd.Z']
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
#
# Debug Information:
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
# T-pose positions: {'Hips': array([ 0.      , 89.062381,  0.      ]), 'LeftHip': array([7.78521200e+00, 8.90525861e+01, 3.31251140e-07]), 'LeftKnee': array([ 7.785212  , 48.30244939, -1.95830332]), 'LeftAnkle': array([ 7.785212  ,  8.66793811, -5.18636626]), 'LeftToe': array([ 7.785212  ,  1.63068611, 10.77240574]), 'LeftToeEnd': array([ 7.785212  ,  0.11709711, 17.35731374]), 'RightHip': array([-7.78521200e+00,  8.90547453e+01, -2.20896914e-07]), 'RightKnee': array([-7.785212  , 48.30449594, -1.95595682]), 'RightAnkle': array([-7.785212  ,  8.66793723, -5.1587819 ]), 'RightToe': array([-7.785212  ,  1.63068523, 10.7999901 ]), 'RightToeEnd': array([-7.785212  ,  0.11709623, 17.3848981 ]), 'Chest': array([ 0.00000000e+00,  9.86069642e+01, -6.81040802e-08]), 'Chest2': array([ 0.00000000e+00,  1.09133886e+02, -6.81040802e-08]), 'Chest3': array([  0.        , 118.69477667,  -0.97204375]), 'Chest4': array([  0.        , 128.24489067,  -1.9439801 ]), 'LeftCollar': array([  2.86465   , 135.75248167,  -1.9439801 ]), 'LeftShoulder': array([ 16.180918  , 135.75248167,  -1.9439801 ]), 'LeftElbow': array([ 44.484243  , 135.75248167,  -1.9439801 ]), 'LeftWrist': array([ 67.68105335, 135.75248167,  -1.00521599]), 'LeftWristEnd': array([ 85.05288935, 135.75248167,  -1.00521599]), 'RightCollar': array([ -2.86465   , 135.75248167,  -1.9439801 ]), 'RightShoulder': array([-16.180918  , 135.75248167,  -1.9439801 ]), 'RightElbow': array([-44.484243  , 135.75248167,  -1.9439801 ]), 'RightWrist': array([-67.68105335, 135.75248167,  -1.00521599]), 'RightWristEnd': array([-85.05288935, 135.75248167,  -1.00521599]), 'Neck': array([  0.        , 141.64188767,  -1.9439801 ]), 'Head': array([ 0.00000000e+00,  1.50363983e+02, -5.27447096e-04]), 'HeadEnd': array([  0.        , 166.97131676,   0.97534886])}
# Connections: [('Hips', 'Chest'), ('Chest', 'Chest2'), ('Chest2', 'Chest3'), ('Chest3', 'Chest4'), ('Chest4', 'Neck'), ('Neck', 'Head'), ('Chest4', 'RightCollar'), ('RightCollar', 'RightShoulder'), ('RightShoulder', 'RightElbow'), ('RightElbow', 'RightWrist'), ('Chest4', 'LeftCollar'), ('LeftCollar', 'LeftShoulder'), ('LeftShoulder', 'LeftElbow'), ('LeftElbow', 'LeftWrist'), ('Hips', 'RightHip'), ('RightHip', 'RightKnee'), ('RightKnee', 'RightAnkle'), ('RightAnkle', 'RightToe'), ('Hips', 'LeftHip'), ('LeftHip', 'LeftKnee'), ('LeftKnee', 'LeftAnkle'), ('LeftAnkle', 'LeftToe')]
#
# Video generation settings:
# Start time: 40.54s (frame 9729)
# End time: 42.91s (frame 10297)
# Output file: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_40.5_42.9.mp4
# Output FPS: 24
# Video size: 1280x720
# Frame 9729 valid markers: 28/28
# Frame 9729 valid markers: 28/28
# Frame 9739 valid markers: 28/28
# Frame 9749 valid markers: 28/28
# Frame 9759 valid markers: 28/28
# Frame 9769 valid markers: 28/28
# Frame 9779 valid markers: 28/28
# Frame 9789 valid markers: 28/28
# Frame 9799 valid markers: 28/28
# Frame 9809 valid markers: 28/28
# Frame 9819 valid markers: 28/28
# Frame 9829 valid markers: 28/28
# Frame 9839 valid markers: 28/28
# Frame 9849 valid markers: 28/28
# Frame 9859 valid markers: 28/28
# Frame 9869 valid markers: 28/28
# Frame 9879 valid markers: 28/28
# Frame 9889 valid markers: 28/28
# Frame 9899 valid markers: 28/28
# Frame 9909 valid markers: 28/28
# Frame 9919 valid markers: 28/28
# Frame 9929 valid markers: 28/28
# Frame 9939 valid markers: 28/28
# Frame 9949 valid markers: 28/28
# Frame 9959 valid markers: 28/28
# Frame 9969 valid markers: 28/28
# Frame 9979 valid markers: 28/28
# Frame 9989 valid markers: 28/28
# Frame 9999 valid markers: 28/28
# Frame 10009 valid markers: 28/28
# Frame 10019 valid markers: 28/28
# Frame 10029 valid markers: 28/28
# Frame 10039 valid markers: 28/28
# Frame 10049 valid markers: 28/28
# Frame 10059 valid markers: 28/28
# Frame 10069 valid markers: 28/28
# Frame 10079 valid markers: 28/28
# Frame 10089 valid markers: 28/28
# Frame 10099 valid markers: 28/28
# Frame 10109 valid markers: 28/28
# Frame 10119 valid markers: 28/28
# Frame 10129 valid markers: 28/28
# Frame 10139 valid markers: 28/28
# Frame 10149 valid markers: 28/28
# Frame 10159 valid markers: 28/28
# Frame 10169 valid markers: 28/28
# Frame 10179 valid markers: 28/28
# Frame 10189 valid markers: 28/28
# Frame 10199 valid markers: 28/28
# Frame 10209 valid markers: 28/28
# Frame 10219 valid markers: 28/28
# Frame 10229 valid markers: 28/28
# Frame 10239 valid markers: 28/28
# Frame 10249 valid markers: 28/28
# Frame 10259 valid markers: 28/28
# Frame 10269 valid markers: 28/28
# Frame 10279 valid markers: 28/28
# Frame 10289 valid markers: 28/28
# Saved frame 57/56
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_40.5_42.9.mp4
# Generating animation for drum merged dot plot for BKO_E1_D1_02_Maraka | Window: 42.9s - 45.2s
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 42.90566666666667s - 45.23455555533334s: 5
# Total onsets: 1830
# Onsets in window 42.90566666666667s - 45.23455555533334s: 14
# Total onsets: 1830
# Onsets in window 42.90566666666667s - 45.23455555533334s: 9
#
# Creating animation...
# Animation will have 56 frames
# Time range: 42.91s - 45.20s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\drum_dot_merged\drum_dot_merged_42.91_45.23.mp4
# Animation saved successfully!
# Generating animation for dance dot plot for BKO_E1_D1_02_Maraka | Window: 42.9s - 45.2s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\dance_dot\dance_42.91_45.23.mp4
# Animation saved successfully!
# Generating Skeletonviews for data\bvh_files\BKO_E1_D1_02_Maraka_T | Window: 42.9s - 45.2s
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# Position columns: ['Time', 'Hips.X', 'Hips.Y', 'Hips.Z', 'LeftHip.X', 'LeftHip.Y', 'LeftHip.Z', 'LeftKnee.X', 'LeftKnee.Y', 'LeftKnee.Z', 'LeftAnkle.X', 'LeftAnkle.Y', 'LeftAnkle.Z', 'LeftToe.X', 'LeftToe.Y', 'LeftToe.Z', 'LeftToeEnd.X', 'LeftToeEnd.Y', 'LeftToeEnd.Z', 'RightHip.X', 'RightHip.Y', 'RightHip.Z', 'RightKnee.X', 'RightKnee.Y', 'RightKnee.Z', 'RightAnkle.X', 'RightAnkle.Y', 'RightAnkle.Z', 'RightToe.X', 'RightToe.Y', 'RightToe.Z', 'RightToeEnd.X', 'RightToeEnd.Y', 'RightToeEnd.Z', 'Chest.X', 'Chest.Y', 'Chest.Z', 'Chest2.X', 'Chest2.Y', 'Chest2.Z', 'Chest3.X', 'Chest3.Y', 'Chest3.Z', 'Chest4.X', 'Chest4.Y', 'Chest4.Z', 'LeftCollar.X', 'LeftCollar.Y', 'LeftCollar.Z', 'LeftShoulder.X', 'LeftShoulder.Y', 'LeftShoulder.Z', 'LeftElbow.X', 'LeftElbow.Y', 'LeftElbow.Z', 'LeftWrist.X', 'LeftWrist.Y', 'LeftWrist.Z', 'LeftWristEnd.X', 'LeftWristEnd.Y', 'LeftWristEnd.Z', 'RightCollar.X', 'RightCollar.Y', 'RightCollar.Z', 'RightShoulder.X', 'RightShoulder.Y', 'RightShoulder.Z', 'RightElbow.X', 'RightElbow.Y', 'RightElbow.Z', 'RightWrist.X', 'RightWrist.Y', 'RightWrist.Z', 'RightWristEnd.X', 'RightWristEnd.Y', 'RightWristEnd.Z', 'Neck.X', 'Neck.Y', 'Neck.Z', 'Head.X', 'Head.Y', 'Head.Z', 'HeadEnd.X', 'HeadEnd.Y', 'HeadEnd.Z']
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
#
# Debug Information:
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
# T-pose positions: {'Hips': array([ 0.      , 89.062381,  0.      ]), 'LeftHip': array([7.78521200e+00, 8.90525861e+01, 3.31251140e-07]), 'LeftKnee': array([ 7.785212  , 48.30244939, -1.95830332]), 'LeftAnkle': array([ 7.785212  ,  8.66793811, -5.18636626]), 'LeftToe': array([ 7.785212  ,  1.63068611, 10.77240574]), 'LeftToeEnd': array([ 7.785212  ,  0.11709711, 17.35731374]), 'RightHip': array([-7.78521200e+00,  8.90547453e+01, -2.20896914e-07]), 'RightKnee': array([-7.785212  , 48.30449594, -1.95595682]), 'RightAnkle': array([-7.785212  ,  8.66793723, -5.1587819 ]), 'RightToe': array([-7.785212  ,  1.63068523, 10.7999901 ]), 'RightToeEnd': array([-7.785212  ,  0.11709623, 17.3848981 ]), 'Chest': array([ 0.00000000e+00,  9.86069642e+01, -6.81040802e-08]), 'Chest2': array([ 0.00000000e+00,  1.09133886e+02, -6.81040802e-08]), 'Chest3': array([  0.        , 118.69477667,  -0.97204375]), 'Chest4': array([  0.        , 128.24489067,  -1.9439801 ]), 'LeftCollar': array([  2.86465   , 135.75248167,  -1.9439801 ]), 'LeftShoulder': array([ 16.180918  , 135.75248167,  -1.9439801 ]), 'LeftElbow': array([ 44.484243  , 135.75248167,  -1.9439801 ]), 'LeftWrist': array([ 67.68105335, 135.75248167,  -1.00521599]), 'LeftWristEnd': array([ 85.05288935, 135.75248167,  -1.00521599]), 'RightCollar': array([ -2.86465   , 135.75248167,  -1.9439801 ]), 'RightShoulder': array([-16.180918  , 135.75248167,  -1.9439801 ]), 'RightElbow': array([-44.484243  , 135.75248167,  -1.9439801 ]), 'RightWrist': array([-67.68105335, 135.75248167,  -1.00521599]), 'RightWristEnd': array([-85.05288935, 135.75248167,  -1.00521599]), 'Neck': array([  0.        , 141.64188767,  -1.9439801 ]), 'Head': array([ 0.00000000e+00,  1.50363983e+02, -5.27447096e-04]), 'HeadEnd': array([  0.        , 166.97131676,   0.97534886])}
# Connections: [('Hips', 'Chest'), ('Chest', 'Chest2'), ('Chest2', 'Chest3'), ('Chest3', 'Chest4'), ('Chest4', 'Neck'), ('Neck', 'Head'), ('Chest4', 'RightCollar'), ('RightCollar', 'RightShoulder'), ('RightShoulder', 'RightElbow'), ('RightElbow', 'RightWrist'), ('Chest4', 'LeftCollar'), ('LeftCollar', 'LeftShoulder'), ('LeftShoulder', 'LeftElbow'), ('LeftElbow', 'LeftWrist'), ('Hips', 'RightHip'), ('RightHip', 'RightKnee'), ('RightKnee', 'RightAnkle'), ('RightAnkle', 'RightToe'), ('Hips', 'LeftHip'), ('LeftHip', 'LeftKnee'), ('LeftKnee', 'LeftAnkle'), ('LeftAnkle', 'LeftToe')]
#
# Video generation settings:
# Start time: 42.91s (frame 10297)
# End time: 45.23s (frame 10856)
# Output file: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_42.9_45.2.mp4
# Output FPS: 24
# Video size: 1280x720
# Frame 10297 valid markers: 28/28
# Frame 10297 valid markers: 28/28
# Frame 10307 valid markers: 28/28
# Frame 10317 valid markers: 28/28
# Frame 10327 valid markers: 28/28
# Frame 10337 valid markers: 28/28
# Frame 10347 valid markers: 28/28
# Frame 10357 valid markers: 28/28
# Frame 10367 valid markers: 28/28
# Frame 10377 valid markers: 28/28
# Frame 10387 valid markers: 28/28
# Frame 10397 valid markers: 28/28
# Frame 10407 valid markers: 28/28
# Frame 10417 valid markers: 28/28
# Frame 10427 valid markers: 28/28
# Frame 10437 valid markers: 28/28
# Frame 10447 valid markers: 28/28
# Frame 10457 valid markers: 28/28
# Frame 10467 valid markers: 28/28
# Frame 10477 valid markers: 28/28
# Frame 10487 valid markers: 28/28
# Frame 10497 valid markers: 28/28
# Frame 10507 valid markers: 28/28
# Frame 10517 valid markers: 28/28
# Frame 10527 valid markers: 28/28
# Frame 10537 valid markers: 28/28
# Frame 10547 valid markers: 28/28
# Frame 10557 valid markers: 28/28
# Frame 10567 valid markers: 28/28
# Frame 10577 valid markers: 28/28
# Frame 10587 valid markers: 28/28
# Frame 10597 valid markers: 28/28
# Frame 10607 valid markers: 28/28
# Frame 10617 valid markers: 28/28
# Frame 10627 valid markers: 28/28
# Frame 10637 valid markers: 28/28
# Frame 10647 valid markers: 28/28
# Frame 10657 valid markers: 28/28
# Frame 10667 valid markers: 28/28
# Frame 10677 valid markers: 28/28
# Frame 10687 valid markers: 28/28
# Frame 10697 valid markers: 28/28
# Frame 10707 valid markers: 28/28
# Frame 10717 valid markers: 28/28
# Frame 10727 valid markers: 28/28
# Frame 10737 valid markers: 28/28
# Frame 10747 valid markers: 28/28
# Frame 10757 valid markers: 28/28
# Frame 10767 valid markers: 28/28
# Frame 10777 valid markers: 28/28
# Frame 10787 valid markers: 28/28
# Frame 10797 valid markers: 28/28
# Frame 10807 valid markers: 28/28
# Frame 10817 valid markers: 28/28
# Frame 10827 valid markers: 28/28
# Frame 10837 valid markers: 28/28
# Frame 10847 valid markers: 28/28
# Saved frame 56/55
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_42.9_45.2.mp4
# Generating animation for drum merged dot plot for BKO_E1_D1_02_Maraka | Window: 45.2s - 47.6s
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 45.23455555533334s - 47.571s: 7
# Total onsets: 1830
# Onsets in window 45.23455555533334s - 47.571s: 10
# Total onsets: 1830
# Onsets in window 45.23455555533334s - 47.571s: 7
#
# Creating animation...
# Animation will have 57 frames
# Time range: 45.23s - 47.57s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\drum_dot_merged\drum_dot_merged_45.23_47.57.mp4
# Animation saved successfully!
# Generating animation for dance dot plot for BKO_E1_D1_02_Maraka | Window: 45.2s - 47.6s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\dance_dot\dance_45.23_47.57.mp4
# Animation saved successfully!
# Generating Skeletonviews for data\bvh_files\BKO_E1_D1_02_Maraka_T | Window: 45.2s - 47.6s
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# ...
# Frame 12952 valid markers: 28/28
# Frame 12962 valid markers: 28/28
# Frame 12972 valid markers: 28/28
# Frame 12982 valid markers: 28/28
# Frame 12992 valid markers: 28/28
# Frame 13002 valid markers: 28/28
# Frame 13012 valid markers: 28/28
# Frame 13022 valid markers: 28/28
# Frame 13032 valid markers: 28/28
# Frame 13042 valid markers: 28/28
# Frame 13052 valid markers: 28/28
# Frame 13062 valid markers: 28/28
# Saved frame 55/54
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_52.2_54.4.mp4
# Generating animation for drum merged dot plot for BKO_E1_D1_02_Maraka | Window: 54.4s - 56.7s
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 54.4496666665s - 56.688777777666665s: 6
# Total onsets: 1830
# Onsets in window 54.4496666665s - 56.688777777666665s: 9
# Total onsets: 1830
# Onsets in window 54.4496666665s - 56.688777777666665s: 7
#
# Creating animation...
# Animation will have 54 frames
# Time range: 54.45s - 56.66s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\drum_dot_merged\drum_dot_merged_54.45_56.69.mp4
# Animation saved successfully!
# Generating animation for dance dot plot for BKO_E1_D1_02_Maraka | Window: 54.4s - 56.7s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\dance_dot\dance_54.45_56.69.mp4
# Animation saved successfully!
# Generating Skeletonviews for data\bvh_files\BKO_E1_D1_02_Maraka_T | Window: 54.4s - 56.7s
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# Position columns: ['Time', 'Hips.X', 'Hips.Y', 'Hips.Z', 'LeftHip.X', 'LeftHip.Y', 'LeftHip.Z', 'LeftKnee.X', 'LeftKnee.Y', 'LeftKnee.Z', 'LeftAnkle.X', 'LeftAnkle.Y', 'LeftAnkle.Z', 'LeftToe.X', 'LeftToe.Y', 'LeftToe.Z', 'LeftToeEnd.X', 'LeftToeEnd.Y', 'LeftToeEnd.Z', 'RightHip.X', 'RightHip.Y', 'RightHip.Z', 'RightKnee.X', 'RightKnee.Y', 'RightKnee.Z', 'RightAnkle.X', 'RightAnkle.Y', 'RightAnkle.Z', 'RightToe.X', 'RightToe.Y', 'RightToe.Z', 'RightToeEnd.X', 'RightToeEnd.Y', 'RightToeEnd.Z', 'Chest.X', 'Chest.Y', 'Chest.Z', 'Chest2.X', 'Chest2.Y', 'Chest2.Z', 'Chest3.X', 'Chest3.Y', 'Chest3.Z', 'Chest4.X', 'Chest4.Y', 'Chest4.Z', 'LeftCollar.X', 'LeftCollar.Y', 'LeftCollar.Z', 'LeftShoulder.X', 'LeftShoulder.Y', 'LeftShoulder.Z', 'LeftElbow.X', 'LeftElbow.Y', 'LeftElbow.Z', 'LeftWrist.X', 'LeftWrist.Y', 'LeftWrist.Z', 'LeftWristEnd.X', 'LeftWristEnd.Y', 'LeftWristEnd.Z', 'RightCollar.X', 'RightCollar.Y', 'RightCollar.Z', 'RightShoulder.X', 'RightShoulder.Y', 'RightShoulder.Z', 'RightElbow.X', 'RightElbow.Y', 'RightElbow.Z', 'RightWrist.X', 'RightWrist.Y', 'RightWrist.Z', 'RightWristEnd.X', 'RightWristEnd.Y', 'RightWristEnd.Z', 'Neck.X', 'Neck.Y', 'Neck.Z', 'Head.X', 'Head.Y', 'Head.Z', 'HeadEnd.X', 'HeadEnd.Y', 'HeadEnd.Z']
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
#
# Debug Information:
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
# T-pose positions: {'Hips': array([ 0.      , 89.062381,  0.      ]), 'LeftHip': array([7.78521200e+00, 8.90525861e+01, 3.31251140e-07]), 'LeftKnee': array([ 7.785212  , 48.30244939, -1.95830332]), 'LeftAnkle': array([ 7.785212  ,  8.66793811, -5.18636626]), 'LeftToe': array([ 7.785212  ,  1.63068611, 10.77240574]), 'LeftToeEnd': array([ 7.785212  ,  0.11709711, 17.35731374]), 'RightHip': array([-7.78521200e+00,  8.90547453e+01, -2.20896914e-07]), 'RightKnee': array([-7.785212  , 48.30449594, -1.95595682]), 'RightAnkle': array([-7.785212  ,  8.66793723, -5.1587819 ]), 'RightToe': array([-7.785212  ,  1.63068523, 10.7999901 ]), 'RightToeEnd': array([-7.785212  ,  0.11709623, 17.3848981 ]), 'Chest': array([ 0.00000000e+00,  9.86069642e+01, -6.81040802e-08]), 'Chest2': array([ 0.00000000e+00,  1.09133886e+02, -6.81040802e-08]), 'Chest3': array([  0.        , 118.69477667,  -0.97204375]), 'Chest4': array([  0.        , 128.24489067,  -1.9439801 ]), 'LeftCollar': array([  2.86465   , 135.75248167,  -1.9439801 ]), 'LeftShoulder': array([ 16.180918  , 135.75248167,  -1.9439801 ]), 'LeftElbow': array([ 44.484243  , 135.75248167,  -1.9439801 ]), 'LeftWrist': array([ 67.68105335, 135.75248167,  -1.00521599]), 'LeftWristEnd': array([ 85.05288935, 135.75248167,  -1.00521599]), 'RightCollar': array([ -2.86465   , 135.75248167,  -1.9439801 ]), 'RightShoulder': array([-16.180918  , 135.75248167,  -1.9439801 ]), 'RightElbow': array([-44.484243  , 135.75248167,  -1.9439801 ]), 'RightWrist': array([-67.68105335, 135.75248167,  -1.00521599]), 'RightWristEnd': array([-85.05288935, 135.75248167,  -1.00521599]), 'Neck': array([  0.        , 141.64188767,  -1.9439801 ]), 'Head': array([ 0.00000000e+00,  1.50363983e+02, -5.27447096e-04]), 'HeadEnd': array([  0.        , 166.97131676,   0.97534886])}
# Connections: [('Hips', 'Chest'), ('Chest', 'Chest2'), ('Chest2', 'Chest3'), ('Chest3', 'Chest4'), ('Chest4', 'Neck'), ('Neck', 'Head'), ('Chest4', 'RightCollar'), ('RightCollar', 'RightShoulder'), ('RightShoulder', 'RightElbow'), ('RightElbow', 'RightWrist'), ('Chest4', 'LeftCollar'), ('LeftCollar', 'LeftShoulder'), ('LeftShoulder', 'LeftElbow'), ('LeftElbow', 'LeftWrist'), ('Hips', 'RightHip'), ('RightHip', 'RightKnee'), ('RightKnee', 'RightAnkle'), ('RightAnkle', 'RightToe'), ('Hips', 'LeftHip'), ('LeftHip', 'LeftKnee'), ('LeftKnee', 'LeftAnkle'), ('LeftAnkle', 'LeftToe')]
#
# Video generation settings:
# Start time: 54.45s (frame 13067)
# End time: 56.69s (frame 13605)
# Output file: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_54.4_56.7.mp4
# Output FPS: 24
# Video size: 1280x720
# Frame 13067 valid markers: 28/28
# Frame 13067 valid markers: 28/28
# Frame 13077 valid markers: 28/28
# Frame 13087 valid markers: 28/28
# Frame 13097 valid markers: 28/28
# Frame 13107 valid markers: 28/28
# Frame 13117 valid markers: 28/28
# Frame 13127 valid markers: 28/28
# Frame 13137 valid markers: 28/28
# Frame 13147 valid markers: 28/28
# Frame 13157 valid markers: 28/28
# Frame 13167 valid markers: 28/28
# Frame 13177 valid markers: 28/28
# Frame 13187 valid markers: 28/28
# Frame 13197 valid markers: 28/28
# Frame 13207 valid markers: 28/28
# Frame 13217 valid markers: 28/28
# Frame 13227 valid markers: 28/28
# Frame 13237 valid markers: 28/28
# Frame 13247 valid markers: 28/28
# Frame 13257 valid markers: 28/28
# Frame 13267 valid markers: 28/28
# Frame 13277 valid markers: 28/28
# Frame 13287 valid markers: 28/28
# Frame 13297 valid markers: 28/28
# Frame 13307 valid markers: 28/28
# Frame 13317 valid markers: 28/28
# Frame 13327 valid markers: 28/28
# Frame 13337 valid markers: 28/28
# Frame 13347 valid markers: 28/28
# Frame 13357 valid markers: 28/28
# Frame 13367 valid markers: 28/28
# Frame 13377 valid markers: 28/28
# Frame 13387 valid markers: 28/28
# Frame 13397 valid markers: 28/28
# Frame 13407 valid markers: 28/28
# Frame 13417 valid markers: 28/28
# Frame 13427 valid markers: 28/28
# Frame 13437 valid markers: 28/28
# Frame 13447 valid markers: 28/28
# Frame 13457 valid markers: 28/28
# Frame 13467 valid markers: 28/28
# Frame 13477 valid markers: 28/28
# Frame 13487 valid markers: 28/28
# Frame 13497 valid markers: 28/28
# Frame 13507 valid markers: 28/28
# Frame 13517 valid markers: 28/28
# Frame 13527 valid markers: 28/28
# Frame 13537 valid markers: 28/28
# Frame 13547 valid markers: 28/28
# Frame 13557 valid markers: 28/28
# Frame 13567 valid markers: 28/28
# Frame 13577 valid markers: 28/28
# Frame 13587 valid markers: 28/28
# Frame 13597 valid markers: 28/28
# Saved frame 54/53
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_54.4_56.7.mp4
# Generating animation for drum merged dot plot for BKO_E1_D1_02_Maraka | Window: 56.7s - 59.0s
# Loading data from:
#   data/virtual_cycles/BKO_E1_D1_02_Maraka_C.csv
#   data/drum_onsets/BKO_E1_D1_02_Maraka.csv
# Total onsets: 1830
# Onsets in window 56.688777777666665s - 58.955s: 8
# Total onsets: 1830
# Onsets in window 56.688777777666665s - 58.955s: 9
# Total onsets: 1830
# Onsets in window 56.688777777666665s - 58.955s: 8
#
# Creating animation...
# Animation will have 55 frames
# Time range: 56.69s - 58.94s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\drum_dot_merged\drum_dot_merged_56.69_58.95.mp4
# Animation saved successfully!
# Generating animation for dance dot plot for BKO_E1_D1_02_Maraka | Window: 56.7s - 59.0s
#
# Saving animation to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\dance_dot\dance_56.69_58.95.mp4
# Animation saved successfully!
# Generating Skeletonviews for data\bvh_files\BKO_E1_D1_02_Maraka_T | Window: 56.7s - 59.0s
#
# Generating front view...
#
# BVH file information:
# Frame rate: 240 Hz
# Total frames: 81793
# Total time: 340.80 seconds
# Position columns: ['Time', 'Hips.X', 'Hips.Y', 'Hips.Z', 'LeftHip.X', 'LeftHip.Y', 'LeftHip.Z', 'LeftKnee.X', 'LeftKnee.Y', 'LeftKnee.Z', 'LeftAnkle.X', 'LeftAnkle.Y', 'LeftAnkle.Z', 'LeftToe.X', 'LeftToe.Y', 'LeftToe.Z', 'LeftToeEnd.X', 'LeftToeEnd.Y', 'LeftToeEnd.Z', 'RightHip.X', 'RightHip.Y', 'RightHip.Z', 'RightKnee.X', 'RightKnee.Y', 'RightKnee.Z', 'RightAnkle.X', 'RightAnkle.Y', 'RightAnkle.Z', 'RightToe.X', 'RightToe.Y', 'RightToe.Z', 'RightToeEnd.X', 'RightToeEnd.Y', 'RightToeEnd.Z', 'Chest.X', 'Chest.Y', 'Chest.Z', 'Chest2.X', 'Chest2.Y', 'Chest2.Z', 'Chest3.X', 'Chest3.Y', 'Chest3.Z', 'Chest4.X', 'Chest4.Y', 'Chest4.Z', 'LeftCollar.X', 'LeftCollar.Y', 'LeftCollar.Z', 'LeftShoulder.X', 'LeftShoulder.Y', 'LeftShoulder.Z', 'LeftElbow.X', 'LeftElbow.Y', 'LeftElbow.Z', 'LeftWrist.X', 'LeftWrist.Y', 'LeftWrist.Z', 'LeftWristEnd.X', 'LeftWristEnd.Y', 'LeftWristEnd.Z', 'RightCollar.X', 'RightCollar.Y', 'RightCollar.Z', 'RightShoulder.X', 'RightShoulder.Y', 'RightShoulder.Z', 'RightElbow.X', 'RightElbow.Y', 'RightElbow.Z', 'RightWrist.X', 'RightWrist.Y', 'RightWrist.Z', 'RightWristEnd.X', 'RightWristEnd.Y', 'RightWristEnd.Z', 'Neck.X', 'Neck.Y', 'Neck.Z', 'Head.X', 'Head.Y', 'Head.Z', 'HeadEnd.X', 'HeadEnd.Y', 'HeadEnd.Z']
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
#
# Debug Information:
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']
# T-pose positions: {'Hips': array([ 0.      , 89.062381,  0.      ]), 'LeftHip': array([7.78521200e+00, 8.90525861e+01, 3.31251140e-07]), 'LeftKnee': array([ 7.785212  , 48.30244939, -1.95830332]), 'LeftAnkle': array([ 7.785212  ,  8.66793811, -5.18636626]), 'LeftToe': array([ 7.785212  ,  1.63068611, 10.77240574]), 'LeftToeEnd': array([ 7.785212  ,  0.11709711, 17.35731374]), 'RightHip': array([-7.78521200e+00,  8.90547453e+01, -2.20896914e-07]), 'RightKnee': array([-7.785212  , 48.30449594, -1.95595682]), 'RightAnkle': array([-7.785212  ,  8.66793723, -5.1587819 ]), 'RightToe': array([-7.785212  ,  1.63068523, 10.7999901 ]), 'RightToeEnd': array([-7.785212  ,  0.11709623, 17.3848981 ]), 'Chest': array([ 0.00000000e+00,  9.86069642e+01, -6.81040802e-08]), 'Chest2': array([ 0.00000000e+00,  1.09133886e+02, -6.81040802e-08]), 'Chest3': array([  0.        , 118.69477667,  -0.97204375]), 'Chest4': array([  0.        , 128.24489067,  -1.9439801 ]), 'LeftCollar': array([  2.86465   , 135.75248167,  -1.9439801 ]), 'LeftShoulder': array([ 16.180918  , 135.75248167,  -1.9439801 ]), 'LeftElbow': array([ 44.484243  , 135.75248167,  -1.9439801 ]), 'LeftWrist': array([ 67.68105335, 135.75248167,  -1.00521599]), 'LeftWristEnd': array([ 85.05288935, 135.75248167,  -1.00521599]), 'RightCollar': array([ -2.86465   , 135.75248167,  -1.9439801 ]), 'RightShoulder': array([-16.180918  , 135.75248167,  -1.9439801 ]), 'RightElbow': array([-44.484243  , 135.75248167,  -1.9439801 ]), 'RightWrist': array([-67.68105335, 135.75248167,  -1.00521599]), 'RightWristEnd': array([-85.05288935, 135.75248167,  -1.00521599]), 'Neck': array([  0.        , 141.64188767,  -1.9439801 ]), 'Head': array([ 0.00000000e+00,  1.50363983e+02, -5.27447096e-04]), 'HeadEnd': array([  0.        , 166.97131676,   0.97534886])}
# Connections: [('Hips', 'Chest'), ('Chest', 'Chest2'), ('Chest2', 'Chest3'), ('Chest3', 'Chest4'), ('Chest4', 'Neck'), ('Neck', 'Head'), ('Chest4', 'RightCollar'), ('RightCollar', 'RightShoulder'), ('RightShoulder', 'RightElbow'), ('RightElbow', 'RightWrist'), ('Chest4', 'LeftCollar'), ('LeftCollar', 'LeftShoulder'), ('LeftShoulder', 'LeftElbow'), ('LeftElbow', 'LeftWrist'), ('Hips', 'RightHip'), ('RightHip', 'RightKnee'), ('RightKnee', 'RightAnkle'), ('RightAnkle', 'RightToe'), ('Hips', 'LeftHip'), ('LeftHip', 'LeftKnee'), ('LeftKnee', 'LeftAnkle'), ('LeftAnkle', 'LeftToe')]
#
# Video generation settings:
# Start time: 56.69s (frame 13605)
# End time: 58.95s (frame 14149)
# Output file: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_56.7_59.0.mp4
# Output FPS: 24
# Video size: 1280x720
# Frame 13605 valid markers: 28/28
# Frame 13605 valid markers: 28/28
# Frame 13615 valid markers: 28/28
# Frame 13625 valid markers: 28/28
# Frame 13635 valid markers: 28/28
# Frame 13645 valid markers: 28/28
# Frame 13655 valid markers: 28/28
# Frame 13665 valid markers: 28/28
# Frame 13675 valid markers: 28/28
# Frame 13685 valid markers: 28/28
# Frame 13695 valid markers: 28/28
# Frame 13705 valid markers: 28/28
# Frame 13715 valid markers: 28/28
# Frame 13725 valid markers: 28/28
# Frame 13735 valid markers: 28/28
# Frame 13745 valid markers: 28/28
# Frame 13755 valid markers: 28/28
# Frame 13765 valid markers: 28/28
# Frame 13775 valid markers: 28/28
# Frame 13785 valid markers: 28/28
# Frame 13795 valid markers: 28/28
# Frame 13805 valid markers: 28/28
# Frame 13815 valid markers: 28/28
# Frame 13825 valid markers: 28/28
# Frame 13835 valid markers: 28/28
# Frame 13845 valid markers: 28/28
# Frame 13855 valid markers: 28/28
# Frame 13865 valid markers: 28/28
# Frame 13875 valid markers: 28/28
# Frame 13885 valid markers: 28/28
# Frame 13895 valid markers: 28/28
# Frame 13905 valid markers: 28/28
# Frame 13915 valid markers: 28/28
# Frame 13925 valid markers: 28/28
# Frame 13935 valid markers: 28/28
# Frame 13945 valid markers: 28/28
# Frame 13955 valid markers: 28/28
# Frame 13965 valid markers: 28/28
# Frame 13975 valid markers: 28/28
# Frame 13985 valid markers: 28/28
# Frame 13995 valid markers: 28/28
# Frame 14005 valid markers: 28/28
# Frame 14015 valid markers: 28/28
# Frame 14025 valid markers: 28/28
# Frame 14035 valid markers: 28/28
# Frame 14045 valid markers: 28/28
# Frame 14055 valid markers: 28/28
# Frame 14065 valid markers: 28/28
# Frame 14075 valid markers: 28/28
# Frame 14085 valid markers: 28/28
# Frame 14095 valid markers: 28/28
# Frame 14105 valid markers: 28/28
# Frame 14115 valid markers: 28/28
# Frame 14125 valid markers: 28/28
# Frame 14135 valid markers: 28/28
# Frame 14145 valid markers: 28/28
# Saved frame 55/54
# Converting frames to video...
# Video generation complete! Saved to composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\video_skeleton\front_view_56.7_59.0.mp4

# %% [markdown]
# ### Generate animated kinematic plots

# %%
def extract_kinematic_cycle_plots(
    file_name: str,
    windows: list,  # List of (win_start, win_end, t_poi) tuples
    joint_name: str,
    axis: str = 'y',
    base_path_logs: str = "data/logs_v2_may",
    frame_rate: float = 240,  # Trajectory data frame rate
    n_beats_per_cycle: int = 4,
    n_subdiv_per_beat: int = 3,
    nn: int = 3,
    output_dir2: str = None,
    figsize: tuple = (10, 3),
    dpi: int = 200,
    legend_flag: bool = True,
):
    """
    Create trajectory animations for windows around points of interest (beats or subdivisions).
    Each plot shows [-cycle, 0-cycle, +cycle] around the POI.
    """
    # Create save directory if not provided
    # if output_dir2 is None:
    #     output_dir2 = os.path.join("cycle_plots", file_name, window_key, joint_name)
    #     os.makedirs(output_dir2, exist_ok=True)
    
    bvh_to_mvnx = {
    'x': 'y',  # BVH side → MVNX side
    'y': 'z',  # BVH vertical → MVNX vertical
    'z': 'x',  # BVH forward → MVNX forward
    }
    
    
    # Load joint position data
    dir_csv = "extracted_mocap_csv"
    base_name = os.path.splitext(os.path.basename(file_name))[0]
    worldpos_file = os.path.join(dir_csv, f"{base_name}_T_worldpos.csv")
    
    try:
        world_positions = pd.read_csv(worldpos_file)
        print(f"Successfully loaded CSV with {len(world_positions)} rows")
    except Exception as e:
        print(f"Error loading CSV file: {e}")
        raise
    
    # Get time column and position data
    time_column = world_positions.columns[0]  # First column is time
    times = world_positions[time_column].values
    positions = world_positions[f"{joint_name}.{axis.upper()}"].values
    
    print(f"\nProcessing {len(windows)} windows")
    # print(f"Total frames in trajectory data: {len(times)}")
    # print(f"Time range in trajectory data: {times[0]:.3f} to {times[-1]:.3f}")
    
    # Process each window
    for i, (win_start, win_end, _) in enumerate(windows):  # Removed t_poi
        print(f"\nProcessing window {i+1}:")
        print(f"  Window time range: {win_start:.3f} to {win_end:.3f}")
        
        # Calculate segment times
        start_time = win_start
        end_time = win_end
        duration = end_time - start_time
        
        # Calculate window parameters
        beat_len = duration / n_beats_per_cycle
        subdiv_len = beat_len / n_subdiv_per_beat
        half_win = subdiv_len * nn
        
        # Calculate frame numbers for trajectory (240fps)
        traj_start_frame = int(start_time * frame_rate)
        traj_end_frame = int(end_time * frame_rate)
        traj_n_frames = traj_end_frame - traj_start_frame
        
        print(f"  Trajectory frames: {traj_start_frame} to {traj_end_frame} (240fps)")
        
        # Check if we have valid frame numbers
        if traj_start_frame >= traj_end_frame:
            print(f"  Skipping window {i+1}: Invalid frame range (start >= end)")
            continue
        if traj_start_frame < 0:
            print(f"  Skipping window {i+1}: Start frame < 0")
            continue
        if traj_end_frame > len(positions):
            print(f"  Skipping window {i+1}: End frame > total frames")
            continue
        
        # Trim trajectory data using frame numbers at 240fps
        pos_win = positions[traj_start_frame:traj_end_frame]
        t_win = times[traj_start_frame:traj_end_frame]
        
        # Check if we have valid trajectory data
        if len(pos_win) == 0:
            print(f"  Skipping window {i+1}: No trajectory data")
            continue
        
        print(f"  Trajectory data points: {len(pos_win)}")
        
        # Create figure and axis ------------------------------------------------------------------------
        fig, ax = plt.subplots(figsize=figsize, dpi=dpi)
        fig.tight_layout(pad=2.0) 
        
        # Calculate all subdivision times for the window
        all_subdiv_times = []
        for beat_idx in range(0, n_beats_per_cycle + 1):  # Changed: now starts from 0
            beat_time = start_time + beat_idx * beat_len  # Changed: use start_time instead of downbeat
            for subdiv_idx in range(n_subdiv_per_beat):
                subdiv_time = beat_time + subdiv_idx * subdiv_len
                if start_time <= subdiv_time <= end_time:
                    all_subdiv_times.append((subdiv_time, beat_idx * n_subdiv_per_beat + subdiv_idx + 1))

        # Plot subdivision lines with appropriate colors
        for subdiv_time, subdiv_num in all_subdiv_times:
            color = get_subdiv_color(subdiv_num)
            if subdiv_num in [1, 4, 7, 10, 13]:
                ax.axvline(subdiv_time, color=color, linestyle='-', linewidth=2, alpha=0.7) #beat color
            else:
                ax.axvline(subdiv_time, color=color, linestyle='--', linewidth=1, alpha=0.3) #subdivision color
        
        # Plot trajectory
        ax.plot(t_win, pos_win, '-', color='green', alpha=0.5, label=f'{joint_name} {axis.upper()}')
        
        # Set y-axis limits with safety checks
        try:
            y_min = pos_win.min()
            y_max = pos_win.max()
            y_range = y_max - y_min
            ax.set_ylim(y_min - 0.1*y_range, y_max + 0.1*y_range)
        except ValueError as e:
            print(f"  Warning: Could not set y-axis limits: {e}")
            ax.set_ylim(-1, 1)
        
        # Create vertical playhead
        v_playhead, = ax.plot([start_time, start_time], 
                            [y_min - 0.1*y_range, y_max + 0.1*y_range],
                            lw=1.5, alpha=0.9, color='orange')
        
        # Set up the plot with scaled x-axis
        ax.set_xlabel(f'Beat span')
        ax.set_ylabel(f'{joint_name} {bvh_to_mvnx[axis.lower()]} Position')      # {axis.upper()} y is vertical in bvh files, Z is vertical in mocap
        ax.set_title(f'{file_name} | Window:{start_time:.2f}s - {end_time:.2f}| Time: {start_time:.2f}s')
        ax.grid(True, alpha=0.3)
        
        # Scale x-axis to show beats instead of cycles
        x_ticks = np.arange(1, n_beats_per_cycle + 2)  # Changed: now 1 to 5
        x_tick_positions = start_time + (x_ticks - 1) * beat_len  # Changed: use start_time and adjust for 1-based indexing
        ax.set_xticks(x_tick_positions)
        ax.set_xticklabels(x_ticks)
        ax.set_xlim(start_time, end_time)
        
        # Add legend
        custom = [
            Line2D([0],[0], color='green', lw=1.5),
            Line2D([0],[0], color='black', lw=1),
            Line2D([0],[0], color='green', lw=1, linestyle='--'),
            Line2D([0],[0], color='red', lw=1, linestyle='--'),
        ]
        labels = [
            f"{joint_name} {axis.upper()}", 
            "Subdiv-1 (1,4,7,10)", 
            "Subdiv-2 (2,5,8,11)", 
            "Subdiv-3 (3,6,9,12)"
        ]
        
        if legend_flag:
            ax.legend(custom, labels, loc='upper left', framealpha=0.3, fontsize=6)
        
        def update(frame):
            v_playhead.set_xdata([frame, frame])
            ax.set_title(f'{file_name} | Window:{start_time:.2f}s - {end_time:.2f}s| Time: {frame:.2f}s')
            return v_playhead,
        
        # Create animation frames at 24fps
        n_frames = int(duration * 24)
        frames = np.linspace(start_time, end_time, n_frames)
        anim = animation.FuncAnimation(
            fig, update, frames=frames,
            interval=1000/24,  # 24fps
            blit=True
        )
        
        # Save animation
        plot_output_path = os.path.join(output_dir2, f"{file_name}_window_{i+1:03d}_{start_time:.2f}_{end_time:.2f}.mp4")
        writer = animation.FFMpegWriter(fps= 24, 
                                        bitrate=2000,
                                        codec='libx264',  # Specify codec
                                        # extra_args=['-preset', 'ultrafast']
                                        )  # 24fps
        anim.save(plot_output_path, writer=writer)
        plt.close(fig)
        
        print(f"Plot saved: {plot_output_path}")
        print(f"Plot duration: {len(frames)/24:.3f}s")
    
    print("\nProcessing complete!")

# %%
# Available markers: ['Hips', 'LeftHip', 'LeftKnee', 'LeftAnkle', 'LeftToe', 
# 'LeftToeEnd', 'RightHip', 'RightKnee', 'RightAnkle', 'RightToe', 'RightToeEnd', 
# 'Chest', 'Chest2', 'Chest3', 'Chest4', 'LeftCollar', 'LeftShoulder', 'LeftElbow', 
# 'LeftWrist', 'LeftWristEnd', 'RightCollar', 'RightShoulder', 'RightElbow', 
# 'RightWrist', 'RightWristEnd', 'Neck', 'Head', 'HeadEnd']

mvnx_to_bvh = {
    'x': 'z',  # forward mvnx → backward bvh
    'y': 'x',  # side mvnx → side bvh
    'z': 'y',  # vertical mvnx → vertical bvh
}

joint_name = "Hips"  
axis = 'z'      # z is vertical in mvnx files

output_dir2 = os.path.join(base_output_dir, joint_name)
os.makedirs(output_dir2, exist_ok=True)

extract_kinematic_cycle_plots(
file_name= file_name,
windows= traj_tuples,
joint_name= joint_name,
axis= mvnx_to_bvh['z'],
output_dir2= output_dir2,
figsize = (10, 3),  # 2000 x 600 px
dpi= 200,
legend_flag = False,
)
# Out:
# Successfully loaded CSV with 81793 rows
#
# Processing 12 windows
#
# Processing window 1:
#   Window time range: 31.076 to 33.482
#   Trajectory frames: 7458 to 8035 (240fps)
#   Trajectory data points: 577
# Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\Hips\BKO_E1_D1_02_Maraka_window_001_31.08_33.48.mp4
# Plot duration: 2.375s
#
# Processing window 2:
#   Window time range: 33.482 to 35.851
#   Trajectory frames: 8035 to 8604 (240fps)
#   Trajectory data points: 569
# Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\Hips\BKO_E1_D1_02_Maraka_window_002_33.48_35.85.mp4
# Plot duration: 2.333s
#
# Processing window 3:
#   Window time range: 35.851 to 38.193
#   Trajectory frames: 8604 to 9166 (240fps)
#   Trajectory data points: 562
# Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\Hips\BKO_E1_D1_02_Maraka_window_003_35.85_38.19.mp4
# Plot duration: 2.333s
#
# Processing window 4:
#   Window time range: 38.193 to 40.539
#   Trajectory frames: 9166 to 9729 (240fps)
#   Trajectory data points: 563
# Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\Hips\BKO_E1_D1_02_Maraka_window_004_38.19_40.54.mp4
# Plot duration: 2.333s
#
# Processing window 5:
#   Window time range: 40.539 to 42.906
#   Trajectory frames: 9729 to 10297 (240fps)
#   Trajectory data points: 568
# Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\Hips\BKO_E1_D1_02_Maraka_window_005_40.54_42.91.mp4
# Plot duration: 2.333s
#
# Processing window 6:
#   Window time range: 42.906 to 45.235
#   Trajectory frames: 10297 to 10856 (240fps)
#   Trajectory data points: 559
# Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\Hips\BKO_E1_D1_02_Maraka_window_006_42.91_45.23.mp4
# Plot duration: 2.292s
#
# Processing window 7:
#   Window time range: 45.235 to 47.571
#   Trajectory frames: 10856 to 11417 (240fps)
#   Trajectory data points: 561
# Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\Hips\BKO_E1_D1_02_Maraka_window_007_45.23_47.57.mp4
# Plot duration: 2.333s
#
# Processing window 8:
#   Window time range: 47.571 to 49.900
#   Trajectory frames: 11417 to 11976 (240fps)
#   Trajectory data points: 559
# Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\Hips\BKO_E1_D1_02_Maraka_window_008_47.57_49.90.mp4
# Plot duration: 2.292s
#
# Processing window 9:
#   Window time range: 49.900 to 52.176
#   Trajectory frames: 11976 to 12522 (240fps)
#   Trajectory data points: 546
# Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\Hips\BKO_E1_D1_02_Maraka_window_009_49.90_52.18.mp4
# Plot duration: 2.250s
#
# Processing window 10:
#   Window time range: 52.176 to 54.450
#   Trajectory frames: 12522 to 13067 (240fps)
#   Trajectory data points: 545
# Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\Hips\BKO_E1_D1_02_Maraka_window_010_52.18_54.45.mp4
# Plot duration: 2.250s
#
# Processing window 11:
#   Window time range: 54.450 to 56.689
#   Trajectory frames: 13067 to 13605 (240fps)
#   Trajectory data points: 538
# Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\Hips\BKO_E1_D1_02_Maraka_window_011_54.45_56.69.mp4
# Plot duration: 2.208s
#
# Processing window 12:
#   Window time range: 56.689 to 58.955
#   Trajectory frames: 13605 to 14149 (240fps)
#   Trajectory data points: 544
# Plot saved: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\Hips\BKO_E1_D1_02_Maraka_window_012_56.69_58.95.mp4
# Plot duration: 2.250s
#
# Processing complete!

# %% [markdown]
# ### Prepare for concatenation

# %%
def extract_category(filename):
    """
    Given a filename like "front_view_56.7_61.2.mp4" or
    "BKO_E1_D1_02_Maraka_pre_R_Mix_trimmed_56.7_61.2.mp4",
    return the category portion before the last two underscore-separated tokens.
    """
    name, _ = os.path.splitext(filename)     # strip .mp4
    parts = name.split('_')
    # Last two parts are start and end times, so category is everything before them
    if len(parts) > 2:
        return "_".join(parts[:-2])
    return name   # fallback if unexpected format

def write_all_categories(files, output_dir, video_dir):
    """
    From a list of filenames, group by category (as defined by extract_category),
    and write each group into its own .txt file in output_dir.
    """
    # os.makedirs(output_dir, exist_ok=True)

    # Group filenames by category
    categories = {}
    for fname in files:
        cat = extract_category(fname)
        categories.setdefault(cat, []).append(fname)

    # Write each category's filenames to a separate text file
    for cat, fnames in categories.items():
        txt_path = os.path.join(output_dir, f"{cat}.txt")
        with open(txt_path, "w") as fw:
            for f in fnames:
                if video_dir:
                    rel_path = os.path.relpath(os.path.join(video_dir, f), os.path.dirname(txt_path))
                    fw.write(f"file '{rel_path}'\n")
                else:
                    fw.write(f + "\n")  
                

def create_concat_file(video_dir, output_file, prefix):
    """Create a text file listing all videos in order for concatenation"""
    with open(output_file, 'w') as f:
        # Get all video files and sort them
        video_files = sorted([f for f in os.listdir(video_dir) if f.endswith('.mp4')])
        # Write each file path - use relative path from the text file location
        for video in video_files:
            # Get relative path from output_file to video_dir
            rel_path = os.path.relpath(os.path.join(video_dir, video), os.path.dirname(output_file))
            f.write(f"file '{rel_path}'\n") 
            
def concatenate_and_overlay_videos(file_name, joint_name,  save_dir,  views_to_generate):
    """Concatenate cycle videos and plot videos, then overlay them"""
    video_dir = os.path.join(save_dir, "videos")
    plot_dir = os.path.join(save_dir, "plots")
    joint_dir = os.path.join(save_dir, joint_name)
    vid_skel_dir = os.path.join(save_dir, "video_skeleton")
    drum_dot_dir = os.path.join(save_dir, "drum_dot_merged")
    dance_dot_dir = os.path.join(save_dir, "dance_dot")

    # Create text files for concatenation
    video_list = os.path.join(save_dir, "video_list.txt")
    plot_list = os.path.join(save_dir, "plot_list.txt")
    joint_list = os.path.join(save_dir, "joint_list.txt")
    
    drum_dot_list = os.path.join(save_dir, "drum_dot_list.txt")
    dance_dot_list = os.path.join(save_dir, "dance_dot_list.txt")
    
    # 'front', 'right' 'left', 'top'
    if 'front' in views_to_generate:
        front_view_list = os.path.join(save_dir, "front_view.txt")
    if 'left' in views_to_generate:
        left_view_list = os.path.join(save_dir, "left_view.txt")
    if 'right' in views_to_generate:
        right_view_list = os.path.join(save_dir, "right_view.txt")
    if 'top' in views_to_generate:
        top_view_list = os.path.join(save_dir, "top_view.txt")
    
    
    mp4_file_list = [f for f in os.listdir(vid_skel_dir) if f.lower().endswith(".mp4")]
    write_all_categories(mp4_file_list, save_dir, video_dir = vid_skel_dir)
    
    
    # Check if directories exist
    if not os.path.exists(video_dir):
        print(f"Video directory not found: {video_dir}")
        return
    if not os.path.exists(plot_dir):
        print(f"Plot directory not found: {plot_dir}")
        return
        
    # Check if text files already exist
    if os.path.exists(video_list) and os.path.exists(plot_list):
        print("Concatenation files already exist, skipping creation")
    else:
        print("Creating concatenation files...")
        create_concat_file(video_dir, video_list, f"{file_name}_cycle_")
        create_concat_file(plot_dir, plot_list, f"{file_name}_cycle_")
        create_concat_file(joint_dir, joint_list, f"{file_name}_cycle_")
        create_concat_file(drum_dot_dir, drum_dot_list, f"{file_name}_cycle_")
        create_concat_file(dance_dot_dir, dance_dot_list, f"{file_name}_cycle_")
    
    def concatenate_videos(video_list, save_dir, save_name):
        
        concat_video = os.path.join(save_dir, f"{save_name}.mp4")
        try:
            result = subprocess.run([
                'ffmpeg', '-y',
                '-f', 'concat',
                '-safe', '0',
                '-i', video_list,
                '-c', 'copy',
                concat_video
            ], capture_output=True, text=True)
            if result.returncode != 0:
                print("Error concatenating videos:", result.stderr)
                return
        except Exception as e:
            print("Error running ffmpeg:", str(e))
            return
    
    concatenate_videos(video_list, save_dir, f"video_mix_concat")
    concatenate_videos(plot_list, save_dir, f"plot_concat")
    concatenate_videos(joint_list, save_dir, f"joint_{joint_name}_concat")
    
    concatenate_videos(drum_dot_list, save_dir, f"drum_dot_concat")
    concatenate_videos(dance_dot_list, save_dir, f"dance_dot_concat")
    
    if 'front' in views_to_generate:    
        concatenate_videos(front_view_list, save_dir, f"front_view_concat")
    if 'left' in views_to_generate:
        concatenate_videos(left_view_list, save_dir, f"left_view_concat")
    if 'right' in views_to_generate:
        concatenate_videos(right_view_list, save_dir, f"right_view_concat")
    if 'top' in views_to_generate:
        concatenate_videos(top_view_list, save_dir, f"top_view_concat") 

    
    print(f"Concatenation complete: {save_dir}")

# %%
concatenate_and_overlay_videos(file_name, joint_name, base_output_dir, views_to_generate)        # modify

concat_file_list = [f for f in os.listdir(base_output_dir) if f.lower().endswith(".mp4")]
concat_dict = {
    f.replace('_concat.mp4', ''): os.path.join(base_output_dir, f) 
    for f in concat_file_list
}
concat_dict
# Out:
# Creating concatenation files...
# Concatenation complete: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95
# {'dance_dot': 'composite_videos\\BKO_E1_D1_02_Maraka_31.08_58.95\\dance_dot_concat.mp4',
#  'drum_dot': 'composite_videos\\BKO_E1_D1_02_Maraka_31.08_58.95\\drum_dot_concat.mp4',
#  'front_view': 'composite_videos\\BKO_E1_D1_02_Maraka_31.08_58.95\\front_view_concat.mp4',
#  'joint_Hips': 'composite_videos\\BKO_E1_D1_02_Maraka_31.08_58.95\\joint_Hips_concat.mp4',
#  'plot': 'composite_videos\\BKO_E1_D1_02_Maraka_31.08_58.95\\plot_concat.mp4',
#  'video_mix': 'composite_videos\\BKO_E1_D1_02_Maraka_31.08_58.95\\video_mix_concat.mp4'}

# %% [markdown]
# ### Generate Composite Video

# %%
concat_file_list = [f for f in os.listdir(base_output_dir) if f.lower().endswith(".mp4")]
concat_dict = {
    f.replace('_concat.mp4', ''): os.path.join(base_output_dir, f) 
    for f in concat_file_list
}
concat_dict
# Out:
# {'dance_dot': 'composite_videos\\BKO_E1_D1_02_Maraka_31.08_58.95\\dance_dot_concat.mp4',
#  'drum_dot': 'composite_videos\\BKO_E1_D1_02_Maraka_31.08_58.95\\drum_dot_concat.mp4',
#  'front_view': 'composite_videos\\BKO_E1_D1_02_Maraka_31.08_58.95\\front_view_concat.mp4',
#  'joint_Hips': 'composite_videos\\BKO_E1_D1_02_Maraka_31.08_58.95\\joint_Hips_concat.mp4',
#  'plot': 'composite_videos\\BKO_E1_D1_02_Maraka_31.08_58.95\\plot_concat.mp4',
#  'video_mix': 'composite_videos\\BKO_E1_D1_02_Maraka_31.08_58.95\\video_mix_concat.mp4'}

# %% [markdown]
# ### Resizing Video

# %%
import os
import subprocess

def resize_video(video_path, width, height, save_dir):
    """
    Resize a video to the specified width and height using ffmpeg,
    with debug‐level output.

    Parameters:
    - video_path: str, path to the input video file
    - width: int, target width in pixels
    - height: int, target height in pixels
    - save_dir: str, directory where the resized video will be saved

    The output filename will be: <original_basename>_<width>x<height>.mp4
    """
    # Ensure the save directory exists
    os.makedirs(save_dir, exist_ok=True)

    # Derive output filename from input basename
    base_name = os.path.splitext(os.path.basename(video_path))[0]
    output_filename = f"{base_name}.mp4"   # f"{base_name}_{width}x{height}.mp4"
    output_path = os.path.join(save_dir, output_filename)

    # Build ffmpeg command with debug-level logging
    cmd = [
        "ffmpeg",
        "-y",                   # overwrite output if it exists
        "-loglevel", "debug",   # show full debug output
        "-i", video_path,
        "-vf", f"scale={width}:{height}",
        "-c:v", "libx264",
        "-crf", "18",
        "-preset", "slow",
        output_path
    ]

    # Run ffmpeg and capture stdout/stderr
    result = subprocess.run(cmd, capture_output=True, text=True)

    # Print debug output
    # print("=== ffmpeg stdout ===")
    # print(result.stdout)
    # print("=== ffmpeg stderr ===")
    # print(result.stderr)

    # Check return code and report
    if result.returncode == 0:
        print(f"Resizing succeeded, output saved to: {output_path}")
    else:
        print(f"ffmpeg failed with return code {result.returncode}")

    return output_path if result.returncode == 0 else None

# %%
view_videos = {
    'video_mix': concat_dict['video_mix'],  
    'plot': concat_dict['plot'],    
    'joint_Hips': concat_dict['joint_Hips'],
    'drum_dot': concat_dict['drum_dot'],
    'dance_dot': concat_dict['dance_dot'],
    
    'front_view': concat_dict['front_view'],
    # 'left_view': concat_dict['left_view'],
    # 'right_view': concat_dict['right_view'],
    # 'top_view': concat_dict['top_view'],
}

canvas_w, canvas_h = 1920, 1080 
composite_layout_1 = [
    # Top row - side by side
    {'view': 'video_mix', 'x': 0, 'y': 0, 'width': 960, 'height': 540},
    {'view': 'front_view', 'x': 960, 'y': 0, 'width': 960, 'height': 540},
    
    # Bottom row - stacked vertically
    {'view': 'joint_Hips', 'x': 0, 'y': 540, 'width': 1920, 'height': 270},
    {'view': 'plot', 'x': 0, 'y': 810, 'width': 1920, 'height': 270},
]

composite_layout_2 = [
    # Top row - side by side
    {'view': 'video_mix', 'x': 0, 'y': 0, 'width': 960, 'height': 540},
    {'view': 'front_view', 'x': 960, 'y': 0, 'width': 960, 'height': 540},
    
    # Bottom row - stacked vertically
    {'view': 'joint_Hips', 'x': 0, 'y': 540, 'width': 960, 'height': 270},
    {'view': 'plot', 'x': 0, 'y': 810, 'width': 960, 'height': 270},
    
    # {'view': 'drum_dot', 'x': 960, 'y': 540, 'width': 960, 'height': 540},
    {'view': 'drum_dot', 'x': 960, 'y': 540, 'width': 960, 'height': 270},
    {'view': 'dance_dot', 'x': 960, 'y': 810, 'width': 960, 'height': 270},
]


saved_resized_dir = os.path.join(base_output_dir, "temp_resized")
os.makedirs(saved_resized_dir, exist_ok=True)

composite_video_elements = []

for video_element in composite_layout_2:
    video_path = view_videos[video_element['view']]
    v_width, v_height = video_element['width'], video_element['height']
    x_pos_pxl, y_pos_pxl = video_element['x'], video_element['y']
    
    resized_path = resize_video(video_path, v_width, v_height, saved_resized_dir)
    
    composite_video_elements.append({"view": video_element['view'], 
                           "vid_path": resized_path,
                           "x_pos_pxl": x_pos_pxl,
                           "y_pos_pxl": y_pos_pxl,
                           })
# Out:
# Resizing succeeded, output saved to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\temp_resized\video_mix_concat.mp4
# Resizing succeeded, output saved to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\temp_resized\front_view_concat.mp4
# Resizing succeeded, output saved to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\temp_resized\joint_Hips_concat.mp4
# Resizing succeeded, output saved to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\temp_resized\plot_concat.mp4
# Resizing succeeded, output saved to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\temp_resized\drum_dot_concat.mp4
# Resizing succeeded, output saved to: composite_videos\BKO_E1_D1_02_Maraka_31.08_58.95\temp_resized\dance_dot_concat.mp4

# %%
# Create a list of dictionaries with just the paths and positions
video_positions = []
for element in composite_video_elements:
    video_positions.append({
        'path': element['vid_path'],
        'x': element['x_pos_pxl'],
        'y': element['y_pos_pxl']
    })

# Build the ffmpeg command
ffmpeg_inputs = []
for pos in video_positions:
    ffmpeg_inputs.extend(['-i', pos['path']])

# Create the xstack layout string
# Format: xstack=inputs=4:layout=0_0|w0_0|0_h0|w0_h0
layout = []
for pos in video_positions:
    layout.append(f"{pos['x']}_{pos['y']}")

xstack_layout = "|".join(layout)

final_out = os.path.join(base_output_dir, f"{file_name}_{start_time:.2f}_{end_time:.2f}.mp4")
ffmpeg_cmd = [
    'ffmpeg', '-y',
    *ffmpeg_inputs,
    '-filter_complex', f'xstack=inputs={len(video_positions)}:layout={xstack_layout}[v]',
    '-map', '[v]',
    '-map', '0:a?', '-c:a', 'aac', '-b:a', '192k',
    '-c:v', 'libx264',   #'libx264',
    '-crf', '23',
    '-preset', 'ultrafast',
    final_out
]

# Execute the command

try:
    subprocess.run(ffmpeg_cmd, check=True)
    print("Video successfully created as final_output.mp4")
except subprocess.CalledProcessError as e:
    print(f"Error creating video: {e}")
# Out:
# Video successfully created as final_output.mp4
